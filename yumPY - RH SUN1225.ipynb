# %% [markdown]
# <h1>YumPy</h1>
#
# <b>Group Members:</b>
# <ul>
# <li>Randi Howell</li>
# <li>Kyrus Wankadiya</li>
# <li>Catherine Safrit</li>
# <li>Monica Sehgal</li>
# </ul>

# %% [markdown]
# <h3>Data Used</h3>
# <ul>
# <li>Income: https://www.kaggle.com/muonneutrino/us-census-demographic-data/data   </li>
# <li>Education: https://www.ers.usda.gov/data-products/county-level-data-sets/</li>
# <li>Yelp Fusion API: https://www.yelp.com/fusion</li>
# </ul>

# %% [markdown]
# <h1>From the top!</h1>
#
# We decided to use the Yelp api, demographic census information, and education data to explore potential correlations. Below is an outline of our projec:
#
# <ul>
# <li>Import dependencies</li>
# <li>Read in CSV data files</li>
# <li>Define US regions based on states</li>
# <li>Create main DataFrame (res_df)</li>
# <li>Coded a for loop to make our API calls and append to res_df</li>
# <li>Exported res_df to a CSV file</li>
# <li>Cleaned up res_df (ex: combine American (new) and American (Traditional) </li>
# <li>Merged our res_df and our counties CSV file</li>
# <li>Examine category distribution across the US</li>
# <li>KYRUS? </li>
# <li>KYRUS?</li>
# <li>Display pie charts for each county thay show restaurant category distribution</li>
# <li>Examined price breakdown based on region and restaurant category</li>
# <li>Produced graphs to illustrate our findings</li>
# <li>MONICA - Compared Pricing and Income?</li>
# <li>MONICA - </li>
# <li>Catherine - EDUCATION</li>
# <li>Conclusions</li>
# <li>Limitations </li>
# <li>If we only had more time...</li>
# </ul>

# %% [markdown]
# <h3>Part 1: Initial Setup</h3>
#
# Below, we imported all of our dependencies including the yelpapi needed for the project. Next, we brought in all of our outside data files, These files include county data, census data, and education data. These were all source from government websites and were CSV files.
#
# Once the CSV files were read in, we modified them as needed to fit in out dataframe. To check the formatting, we used a print statement.

# %%
import yelpapi
import json
import requests
from  pprint import  pprint
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

#reading in county data
counties=pd.read_csv("acs2015_county_data.csv")
counties["county_string"] = counties["County"] + " County, " + counties["State"]
listofcounties = counties["county_string"].tolist()
#reading in zipcodes
zipcodes=pd.read_csv("zip_codes_states.csv")
zipcodes["county_string"] = zipcodes["county"] + " County, " + zipcodes["state"]
listofzipcodes=zipcodes["county_string"].unique().tolist()
counties.to_csv("counties.csv")
zipcodes.to_csv("zcs.csv")
fullcountylist = list(set(listofcounties) & set(listofzipcodes))
counties.head(1)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
#
#    Native           ...             OtherTransp  WorkAtHome  MeanCommute  \
# 0     0.4           ...                     1.3         1.8         26.5
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0     23986         73.6        20.9           5.5         0.0           7.6
#
#              county_string
# 0  Autauga County, Alabama
#
# [1 rows x 38 columns]

# %% [markdown]
# <h3>Part 1: County Setup</h3>
#
# In the framework portion, we established regions of the US that we will use later, created a new dataframe that holds out counties, and created a list to hold all the randomly generated countries. This will be more important later.

# %%
#creating regions
WC = ["Washington","Oregon","California","Nevada","Idaho"]
MW = ["Montana","Wyoming","North Dakota","South Dakota","Nebraska","Kansas","Minnesota","Iowa","Missouri",
      "Wisconsin","Illinois","Michigan","Indiana","Ohio","Kentucky"]
SW = ["Arizona","Utah","Colorado","New Mexico","Oklahoma","Texas"]
SE = ["Arkansas","Louisiana","Mississippi","Alabama","Tennessee","Virginia","West Virginia","North Carolina","South Carolina","Georgia","Florida"]
NE = ["District of Columbia","Pennsylvania","Maryland","Delaware","New Jersey","New York","Maine","New Hampshire","Vermont","Massachusetts","Rhode Island","Connecticut"]
counties["Region"]= np.where(counties["State"].isin(WC),'WC',
                    np.where(counties["State"].isin(MW),'MW',
                    np.where(counties["State"].isin(SW),'SW',
                    np.where(counties["State"].isin(SE),'SE',
                    np.where(counties["State"].isin(NE),'NE', 
                             'other')))))

# %%
#counties.groupby(["Region"]).sum()["TotalPop"]
cdf = pd.DataFrame(counties,columns=["county_string","Region"])
WClist = (cdf.groupby("Region").get_group("WC")["county_string"]).tolist()
MWlist = (cdf.groupby("Region").get_group("MW")["county_string"]).tolist()
SWlist = (cdf.groupby("Region").get_group("SW")["county_string"]).tolist()
SElist = (cdf.groupby("Region").get_group("SE")["county_string"]).tolist()
NElist = (cdf.groupby("Region").get_group("NE")["county_string"]).tolist()

sample_list = ["Mecklenburg County, North Carolina"]
sample_list.extend(random.sample(list(set(WClist) & set(fullcountylist)),10))
sample_list.extend(random.sample(list(set(MWlist) & set(fullcountylist)),10))
sample_list.extend(random.sample(list(set(SWlist) & set(fullcountylist)),10))
sample_list.extend(random.sample(list(set(SElist) & set(fullcountylist)),9))
sample_list.extend(random.sample(list(set(NElist) & set(fullcountylist)),10))
sample_list
# Out:
# ['Mecklenburg County, North Carolina',
#  'Shoshone County, Idaho',
#  'Pend Oreille County, Washington',
#  'Linn County, Oregon',
#  'Morrow County, Oregon',
#  'Kitsap County, Washington',
#  'Jefferson County, Washington',
#  'Wasco County, Oregon',
#  'Clackamas County, Oregon',
#  'Santa Cruz County, California',
#  'San Benito County, California',
#  'Rice County, Minnesota',
#  'Boone County, Missouri',
#  'Hamilton County, Kansas',
#  'Moody County, South Dakota',
#  'Barry County, Missouri',
#  'Summit County, Ohio',
#  'Gallia County, Ohio',
#  'Montgomery County, Kansas',
#  'Scott County, Indiana',
#  'Graves County, Kentucky',
#  'Osage County, Oklahoma',
#  'Schleicher County, Texas',
#  'Runnels County, Texas',
#  'Henderson County, Texas',
#  'Bee County, Texas',
#  'Wood County, Texas',
#  'Pueblo County, Colorado',
#  'Hamilton County, Texas',
#  'Texas County, Oklahoma',
#  'Randall County, Texas',
#  'Warren County, Tennessee',
#  'Glascock County, Georgia',
#  'Franklin County, Florida',
#  'East Feliciana County, Louisiana',
#  'Crockett County, Tennessee',
#  'Geneva County, Alabama',
#  'Yazoo County, Mississippi',
#  'Buncombe County, North Carolina',
#  'Citrus County, Florida',
#  'Erie County, New York',
#  'Columbia County, New York',
#  'Sussex County, Delaware',
#  'Westmoreland County, Pennsylvania',
#  'Providence County, Rhode Island',
#  'Essex County, New York',
#  'Strafford County, New Hampshire',
#  'Kent County, Delaware',
#  'Crawford County, Pennsylvania',
#  'Pike County, Pennsylvania']

# %% [markdown]
# <h3>Part 1: Establishing the Main DataFrame</h3>
#
# After reading in the county data and creating regions, we established our primary dataframe. We named the dataframe res_df. This dataframe will be used throughout the project.

# %%
res_df = pd.DataFrame(columns=["name","zipcode","county_string","rating","review_count","category","price","region"])
res_df
# Out:
# Empty DataFrame
# Columns: [name, zipcode, county_string, rating, review_count, category, price, region]
# Index: []

# %% [markdown]
# <h3>Part 1: The Framework - Kyrus For Loop</h3>
#
# Kyrus was able to build the primary framework for our project. With multiple nested for loops, Kyrus was able to make the Yelp API call, loop through the first 50 pages for each restuarunt type, then red in that data and append it to the res_df dataframe.
#
# Kyrus also included a try/ecxcept option as a way to check or verify the code was working and pulling in the data correctly.

# %%
term = ["Italian","Mexican","Chinese","American (Traditional)","American (New)","Indian"]
r = 0
for c in sample_list:
    county_string = str(c)
    if 1==1:
        #we are allowed 5000 queries per 24 hours. if we run out, we can create another. till then, use this
        yelpkey="IXRN_1GI8f8J9Kj5O5GciqeyFSWR5RMh41_rADGy1KrtQ5ZABGGZEkWwot5mOka0NlzlNxXPmzYXLWk88oOV0N_YxD1MSW4kQRfJnFrwfHLtKrr2HcsjLo6uWBzAWnYx"
        if 1==1:
            
            for offset in range(0,49):
                
                response = requests.get(url="https://api.yelp.com/v3/businesses/search", 
                       params= {"location": county_string, "limit":"20", "offset": offset*20},#"term": term}, 
                       headers={'Authorization': 'bearer %s' % yelpkey})
                responsejson = response.json()
                print(offset*20)
                if 1==1:
                    count=0
                    for x in range(0,len(responsejson["businesses"])):
                        
                        try:
                            if((responsejson["businesses"][x]["review_count"] > 0)):
                                zc = int(responsejson["businesses"][x]["location"]["zip_code"])
                                
                                try:
                                    
                                    if (zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0]== county_string):
                                        for y in range(0,len(responsejson["businesses"][x]["categories"])):
                                            if 1==1:
                                                print("\n",responsejson["businesses"][x]["name"],
                                                        responsejson["businesses"][x]["location"]["zip_code"],
                                                        zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0],
                                                        responsejson["businesses"][x]["rating"],
                                                        responsejson["businesses"][x]["review_count"],
                                                        responsejson["businesses"][x]["categories"][y]["title"])
                                                if str(responsejson["businesses"][x]["categories"][y]["title"]) in (term):
                                                    res_df.loc[r]=[responsejson["businesses"][x]["name"],
                                                        str(zc),
                                                        county_string,
                                                        responsejson["businesses"][x]["rating"],
                                                        responsejson["businesses"][x]["review_count"],
                                                        responsejson["businesses"][x]["categories"][y]["title"],
                                                        responsejson["businesses"][x]["price"],
                                                        "region"
                                                    ]
                                        
                                                    r += 1
                                                count += 1
                                            
                                            #except:
                                            #    print("")
                                            #    break
                                except:
                                    print("ERROR1")
                                #    break
                                    
                        except:
                            print("ERROR2")
                        #    break
                #except:
                #    print("ERROR3")
                #    break
    
                #print("End of list. Found", count, term, "restaurants in", county_string)
        #except:
        #    print("ERROR4: this one should never happen")
        #    break
# Out:
# 0
#
#  Amélie's French Bakery & Café 28205 Mecklenburg County, North Carolina 4.0 1376 Breakfast & Brunch
#
#  Amélie's French Bakery & Café 28205 Mecklenburg County, North Carolina 4.0 1376 Cafes
#
#  Amélie's French Bakery & Café 28205 Mecklenburg County, North Carolina 4.0 1376 Patisserie/Cake Shop
#
#  Le's Sandwiches & Cafe 28213 Mecklenburg County, North Carolina 4.5 313 Vietnamese
#
#  Le's Sandwiches & Cafe 28213 Mecklenburg County, North Carolina 4.5 313 Sandwiches
#
#  Cabo Fish Taco 28205 Mecklenburg County, North Carolina 4.0 990 Latin American
#
#  Cabo Fish Taco 28205 Mecklenburg County, North Carolina 4.0 990 Mexican
#
#  Smelly Cat Coffee 28205 Mecklenburg County, North Carolina 4.5 366 Coffee & Tea
#
#  Smelly Cat Coffee 28205 Mecklenburg County, North Carolina 4.5 366 Breakfast & Brunch
#
#  Midwood Smokehouse 28205 Mecklenburg County, North Carolina 4.5 1281 Barbeque
#
#  Midwood Smokehouse 28205 Mecklenburg County, North Carolina 4.5 1281 Smokehouse
#
#  Midwood Smokehouse 28205 Mecklenburg County, North Carolina 4.5 1281 American (Traditional)
#
#  Haberdish 28205 Mecklenburg County, North Carolina 4.5 402 Southern
#
#  Haberdish 28205 Mecklenburg County, North Carolina 4.5 402 Cocktail Bars
#
#  Viva Chicken 28204 Mecklenburg County, North Carolina 4.5 797 Peruvian
#
#  Soul Gastrolounge 28205 Mecklenburg County, North Carolina 4.0 863 Tapas Bars
#
#  Soul Gastrolounge 28205 Mecklenburg County, North Carolina 4.0 863 Lounges
#
#  Not Just Coffee - 7th Street 28202 Mecklenburg County, North Carolina 4.5 437 Coffee & Tea
#
#  Crêpe Cellar 28205 Mecklenburg County, North Carolina 4.0 338 Creperies
#
#  Crêpe Cellar 28205 Mecklenburg County, North Carolina 4.0 338 Modern European
#
#  Crêpe Cellar 28205 Mecklenburg County, North Carolina 4.0 338 Gastropubs
#
#  Sabor Latin Street Grill 28204 Mecklenburg County, North Carolina 4.5 682 Latin American
#
#  Sabor Latin Street Grill 28204 Mecklenburg County, North Carolina 4.5 682 Mexican
#
#  Benny Pennello's 28205 Mecklenburg County, North Carolina 4.0 234 Pizza
#
#  Benny Pennello's 28205 Mecklenburg County, North Carolina 4.0 234 Italian
#
#  JackBeagles 28205 Mecklenburg County, North Carolina 4.0 292 Pubs
#
#  JackBeagles 28205 Mecklenburg County, North Carolina 4.0 292 American (Traditional)
#
#  JackBeagles 28205 Mecklenburg County, North Carolina 4.0 292 Breakfast & Brunch
#
#  Noda Bodega 28205 Mecklenburg County, North Carolina 4.5 129 Sandwiches
#
#  Noda Bodega 28205 Mecklenburg County, North Carolina 4.5 129 Delis
#
#  The Cellar At Duckworth's 28202 Mecklenburg County, North Carolina 4.5 361 Cocktail Bars
#
#  The Cellar At Duckworth's 28202 Mecklenburg County, North Carolina 4.5 361 American (New)
#
#  The Cellar At Duckworth's 28202 Mecklenburg County, North Carolina 4.5 361 Tapas Bars
#
#  Pinky's Westside Grill 28208 Mecklenburg County, North Carolina 4.0 856 Burgers
#
#  Pinky's Westside Grill 28208 Mecklenburg County, North Carolina 4.0 856 American (Traditional)
#
#  Pinky's Westside Grill 28208 Mecklenburg County, North Carolina 4.0 856 Salad
#
#  Futo Buta 28203 Mecklenburg County, North Carolina 4.0 792 Ramen
#
#  The Fig Tree Restaurant 28204 Mecklenburg County, North Carolina 4.5 343 American (New)
#
#  The Fig Tree Restaurant 28204 Mecklenburg County, North Carolina 4.5 343 French
#
#  The Fig Tree Restaurant 28204 Mecklenburg County, North Carolina 4.5 343 Italian
#
#  VBGB Beer Hall and Garden 28206 Mecklenburg County, North Carolina 4.5 326 Bars
#
#  VBGB Beer Hall and Garden 28206 Mecklenburg County, North Carolina 4.5 326 American (New)
#
#  VBGB Beer Hall and Garden 28206 Mecklenburg County, North Carolina 4.5 326 Beer Gardens
#
#  Dandelion Market 28202 Mecklenburg County, North Carolina 4.0 553 Bars
#
#  Dandelion Market 28202 Mecklenburg County, North Carolina 4.0 553 American (New)
#
#  Dandelion Market 28202 Mecklenburg County, North Carolina 4.0 553 Tapas/Small Plates
# 20
#
#  Bistro La Bon 28205 Mecklenburg County, North Carolina 4.0 450 Mediterranean
#
#  Bistro La Bon 28205 Mecklenburg County, North Carolina 4.0 450 Breakfast & Brunch
#
#  Lang Van Vietnamese 28215 Mecklenburg County, North Carolina 4.5 306 Vietnamese
#
#  Growlers Pourhouse 28205 Mecklenburg County, North Carolina 4.0 201 American (Traditional)
#
#  Growlers Pourhouse 28205 Mecklenburg County, North Carolina 4.0 201 Beer Bar
#
#  Bang Bang Burgers 28204 Mecklenburg County, North Carolina 4.5 508 Burgers
#
#  Alexander Michael's 28202 Mecklenburg County, North Carolina 4.5 331 American (Traditional)
#
#  Alexander Michael's 28202 Mecklenburg County, North Carolina 4.5 331 Pubs
#
#  Alexander Michael's 28202 Mecklenburg County, North Carolina 4.5 331 Cajun/Creole
#
#  Sabor Latin Street Grill - Noda 28205 Mecklenburg County, North Carolina 4.5 155 Mexican
#
#  Sabor Latin Street Grill - Noda 28205 Mecklenburg County, North Carolina 4.5 155 Latin American
#
#  The Capital Grille 28202 Mecklenburg County, North Carolina 4.5 358 Steakhouses
#
#  The Capital Grille 28202 Mecklenburg County, North Carolina 4.5 358 Seafood
#
#  The Capital Grille 28202 Mecklenburg County, North Carolina 4.5 358 Wine Bars
#
#  Chili Man 28202 Mecklenburg County, North Carolina 5.0 130 Hot Dogs
#
#  Chili Man 28202 Mecklenburg County, North Carolina 5.0 130 Street Vendors
#
#  Amélie's French Bakery & Café 28202 Mecklenburg County, North Carolina 4.0 430 Cafes
#
#  Amélie's French Bakery & Café 28202 Mecklenburg County, North Carolina 4.0 430 Bakeries
#
#  Brooks Sandwich House 28205 Mecklenburg County, North Carolina 4.5 125 Sandwiches
#
#  Brooks Sandwich House 28205 Mecklenburg County, North Carolina 4.5 125 Burgers
#
#  Cajun Queen 28204 Mecklenburg County, North Carolina 4.0 595 Cajun/Creole
#
#  Cajun Queen 28204 Mecklenburg County, North Carolina 4.0 595 Jazz & Blues
#
#  Cajun Queen 28204 Mecklenburg County, North Carolina 4.0 595 Seafood
#
#  Hazelnuts Creperie 28202 Mecklenburg County, North Carolina 4.5 295 Creperies
#
#  Hazelnuts Creperie 28202 Mecklenburg County, North Carolina 4.5 295 Breakfast & Brunch
#
#  Hazelnuts Creperie 28202 Mecklenburg County, North Carolina 4.5 295 Cafes
#
#  Duck Donuts 28203 Mecklenburg County, North Carolina 4.5 393 Donuts
#
#  Duck Donuts 28203 Mecklenburg County, North Carolina 4.5 393 Coffee & Tea
#
#  Duck Donuts 28203 Mecklenburg County, North Carolina 4.5 393 Breakfast & Brunch
#
#  Little Village Grill 28202 Mecklenburg County, North Carolina 4.5 184 Greek
#
#  Little Village Grill 28202 Mecklenburg County, North Carolina 4.5 184 Mediterranean
#
#  Trade And Lore 28205 Mecklenburg County, North Carolina 4.5 69 Coffee & Tea
#
#  Mert's Heart & Soul 28202 Mecklenburg County, North Carolina 3.5 803 Southern
#
#  Mert's Heart & Soul 28202 Mecklenburg County, North Carolina 3.5 803 Soul Food
#
#  Mert's Heart & Soul 28202 Mecklenburg County, North Carolina 3.5 803 Breakfast & Brunch
#
#  Tupelo Honey 28203 Mecklenburg County, North Carolina 4.0 1180 Southern
#
#  Tupelo Honey 28203 Mecklenburg County, North Carolina 4.0 1180 American (New)
#
#  Tupelo Honey 28203 Mecklenburg County, North Carolina 4.0 1180 Breakfast & Brunch
#
#  The King's Kitchen 28202 Mecklenburg County, North Carolina 4.0 484 American (Traditional)
#
#  The King's Kitchen 28202 Mecklenburg County, North Carolina 4.0 484 Southern
#
#  The King's Kitchen 28202 Mecklenburg County, North Carolina 4.0 484 Soul Food
#
#  Dish 28205 Mecklenburg County, North Carolina 4.0 455 Southern
#
#  The Common Market 28205 Mecklenburg County, North Carolina 4.5 219 Delis
#
#  The Common Market 28205 Mecklenburg County, North Carolina 4.5 219 Beer, Wine & Spirits
#
#  The Common Market 28205 Mecklenburg County, North Carolina 4.5 219 Sandwiches
# 40
#
#  Seoul Food Meat Company 28203 Mecklenburg County, North Carolina 4.0 628 Barbeque
#
#  Seoul Food Meat Company 28203 Mecklenburg County, North Carolina 4.0 628 Asian Fusion
#
#  Seoul Food Meat Company 28203 Mecklenburg County, North Carolina 4.0 628 Chicken Wings
#
#  Davidson Street Public House 28205 Mecklenburg County, North Carolina 4.0 136 American (New)
#
#  Davidson Street Public House 28205 Mecklenburg County, North Carolina 4.0 136 Beer, Wine & Spirits
#
#  Davidson Street Public House 28205 Mecklenburg County, North Carolina 4.0 136 Breweries
#
#  Zablong 28202 Mecklenburg County, North Carolina 4.5 176 Pizza
#
#  Three Amigos Mexican Restaurant and Cantina 28205 Mecklenburg County, North Carolina 4.0 375 Mexican
#
#  Boudreaux's Louisiana Kitchen 28205 Mecklenburg County, North Carolina 3.5 274 Cajun/Creole
#
#  Boudreaux's Louisiana Kitchen 28205 Mecklenburg County, North Carolina 3.5 274 Breakfast & Brunch
#
#  The Workman's Friend 28205 Mecklenburg County, North Carolina 4.5 178 Irish Pub
#
#  300 East 28203 Mecklenburg County, North Carolina 4.0 582 American (New)
#
#  300 East 28203 Mecklenburg County, North Carolina 4.0 582 Wine Bars
#
#  Central Coffee Company 28204 Mecklenburg County, North Carolina 4.5 200 Coffee & Tea
#
#  Pure Pizza 28202 Mecklenburg County, North Carolina 4.0 249 Pizza
#
#  Pure Pizza 28202 Mecklenburg County, North Carolina 4.0 249 Vegetarian
#
#  Pure Pizza 28202 Mecklenburg County, North Carolina 4.0 249 Gluten-Free
#
#  Rooster's Uptown 28202 Mecklenburg County, North Carolina 4.0 402 American (New)
#
#  Cowbell Burger & Whiskey Bar 28202 Mecklenburg County, North Carolina 4.0 469 Burgers
#
#  Cowbell Burger & Whiskey Bar 28202 Mecklenburg County, North Carolina 4.0 469 Whiskey Bars
#
#  Las Lupitas 28213 Mecklenburg County, North Carolina 4.5 49 Mexican
#
#  Krazy Fish 28205 Mecklenburg County, North Carolina 4.0 394 Seafood
#  Krazy Fish 28205 Mecklenburg County, North Carolina 4.0 394 Asian Fusion
#
#  Krazy Fish 28205 Mecklenburg County, North Carolina 4.0 394 Breakfast & Brunch
#
#  Sea Level NC 28202 Mecklenburg County, North Carolina 4.0 292 Seafood
#
#  Sea Level NC 28202 Mecklenburg County, North Carolina 4.0 292 Cocktail Bars
#
#  Sea Level NC 28202 Mecklenburg County, North Carolina 4.0 292 Breakfast & Brunch
#
#  5Church 28202 Mecklenburg County, North Carolina 3.5 575 American (New)
#
#  5Church 28202 Mecklenburg County, North Carolina 3.5 575 Bars
#
#  Noda Company Store 28205 Mecklenburg County, North Carolina 4.5 45 Beer Bar
#
#  Noda Company Store 28205 Mecklenburg County, North Carolina 4.5 45 Art Galleries
#
#  Noda Company Store 28205 Mecklenburg County, North Carolina 4.5 45 Wine Bars
#
#  Living Kitchen 28203 Mecklenburg County, North Carolina 4.5 356 Vegetarian
#
#  Living Kitchen 28203 Mecklenburg County, North Carolina 4.5 356 Vegan
#
#  Dressler's - Charlotte 28204 Mecklenburg County, North Carolina 4.5 288 Seafood
#
#  Dressler's - Charlotte 28204 Mecklenburg County, North Carolina 4.5 288 Steakhouses
#
#  Dressler's - Charlotte 28204 Mecklenburg County, North Carolina 4.5 288 Wine Bars
#
#  Good Food on Montford 28209 Mecklenburg County, North Carolina 4.5 582 American (New)
#
#  Good Food on Montford 28209 Mecklenburg County, North Carolina 4.5 582 Tapas/Small Plates
#
#  Good Food on Montford 28209 Mecklenburg County, North Carolina 4.5 582 Cocktail Bars
#
#  Mimosa Grill 28202 Mecklenburg County, North Carolina 4.0 426 Southern
#
#  Mimosa Grill 28202 Mecklenburg County, North Carolina 4.0 426 American (New)
# 60
#
#  Chima Steakhouse 28202 Mecklenburg County, North Carolina 4.0 415 Steakhouses
#
#  Chima Steakhouse 28202 Mecklenburg County, North Carolina 4.0 415 Brazilian
#
#  Chima Steakhouse 28202 Mecklenburg County, North Carolina 4.0 415 Cocktail Bars
#
#  Basil Thai Cuisine 28202 Mecklenburg County, North Carolina 3.5 507 Thai
#
#  Basil Thai Cuisine 28202 Mecklenburg County, North Carolina 3.5 507 Seafood
#
#  The Asbury 28202 Mecklenburg County, North Carolina 4.0 205 Southern
#
#  The Asbury 28202 Mecklenburg County, North Carolina 4.0 205 American (New)
#
#  Intermezzo Pizzeria and Cafe 28204 Mecklenburg County, North Carolina 4.0 260 Pizza
#
#  Intermezzo Pizzeria and Cafe 28204 Mecklenburg County, North Carolina 4.0 260 Cafes
#
#  Midnight Diner 28202 Mecklenburg County, North Carolina 4.0 612 Diners
#
#  Midnight Diner 28202 Mecklenburg County, North Carolina 4.0 612 Breakfast & Brunch
#
#  Midnight Diner 28202 Mecklenburg County, North Carolina 4.0 612 American (Traditional)
#
#  Pho Hoa Restaurant 28205 Mecklenburg County, North Carolina 4.5 196 Vietnamese
#
#  The Dog Bar 28205 Mecklenburg County, North Carolina 4.0 92 Bars
#
#  Mama Ricotta's 28204 Mecklenburg County, North Carolina 4.0 415 Italian
#
#  Mama Ricotta's 28204 Mecklenburg County, North Carolina 4.0 415 Venues & Event Spaces
#
#  Bad Daddy's Burger Bar 28203 Mecklenburg County, North Carolina 4.0 456 Burgers
#
#  Bad Daddy's Burger Bar 28203 Mecklenburg County, North Carolina 4.0 456 Salad
#
#  Bad Daddy's Burger Bar 28203 Mecklenburg County, North Carolina 4.0 456 Bars
#
#  Earl's Grocery 28204 Mecklenburg County, North Carolina 4.5 168 Breakfast & Brunch
#
#  Earl's Grocery 28204 Mecklenburg County, North Carolina 4.5 168 Food Trucks
#
#  Earl's Grocery 28204 Mecklenburg County, North Carolina 4.5 168 Sandwiches
#
#  Kickstand Burgers & Bar 28204 Mecklenburg County, North Carolina 4.0 278 Burgers
#
#  Kickstand Burgers & Bar 28204 Mecklenburg County, North Carolina 4.0 278 Bars
#
#  Papi Queso 28202 Mecklenburg County, North Carolina 4.5 127 Food Trucks
#
#  Papi Queso 28202 Mecklenburg County, North Carolina 4.5 127 American (New)
#
#  Papi Queso 28202 Mecklenburg County, North Carolina 4.5 127 Sandwiches
#
#  Abugida Ethiopian Cafe & Restaurant 28205 Mecklenburg County, North Carolina 5.0 75 Ethiopian
#
#  Sunflour Baking Company 28204 Mecklenburg County, North Carolina 4.0 238 Bakeries
#
#  Sunflour Baking Company 28204 Mecklenburg County, North Carolina 4.0 238 Cafes
#
#  Sunflour Baking Company 28204 Mecklenburg County, North Carolina 4.0 238 Sandwiches
#
#  Le Kebab Grill 28262 Mecklenburg County, North Carolina 4.0 331 Mediterranean
#
#  Le Kebab Grill 28262 Mecklenburg County, North Carolina 4.0 331 Middle Eastern
#
#  Le Kebab Grill 28262 Mecklenburg County, North Carolina 4.0 331 Halal
#
#  Local Loaf 28202 Mecklenburg County, North Carolina 4.0 230 Bakeries
#
#  Local Loaf 28202 Mecklenburg County, North Carolina 4.0 230 Breakfast & Brunch
#
#  Local Loaf 28202 Mecklenburg County, North Carolina 4.0 230 Sandwiches
#
#  Halcyon 28202 Mecklenburg County, North Carolina 4.0 259 Cocktail Bars
#
#  Halcyon 28202 Mecklenburg County, North Carolina 4.0 259 Modern European
#
#  Original Pancake House 28204 Mecklenburg County, North Carolina 4.0 254 Breakfast & Brunch
#
#  Lebowski's Neighborhood Grill 28203 Mecklenburg County, North Carolina 4.5 335 Pubs
#
#  Lebowski's Neighborhood Grill 28203 Mecklenburg County, North Carolina 4.5 335 Sports Bars
#
#  Lebowski's Neighborhood Grill 28203 Mecklenburg County, North Carolina 4.5 335 American (Traditional)
#
#  Carpe Diem Restaurant & Caterers 28204 Mecklenburg County, North Carolina 4.0 174 American (New)
#
#  Carpe Diem Restaurant & Caterers 28204 Mecklenburg County, North Carolina 4.0 174 Lounges
#
#  Carpe Diem Restaurant & Caterers 28204 Mecklenburg County, North Carolina 4.0 174 Venues & Event Spaces
# 80
#
#  JJ's Red Hots - Dilworth 28203 Mecklenburg County, North Carolina 4.0 349 Hot Dogs
#
#  JJ's Red Hots - Dilworth 28203 Mecklenburg County, North Carolina 4.0 349 American (Traditional)
#
#  Zada Jane's Corner Cafe 28205 Mecklenburg County, North Carolina 3.5 543 Breakfast & Brunch
#
#  Zada Jane's Corner Cafe 28205 Mecklenburg County, North Carolina 3.5 543 Salad
#
#  Zada Jane's Corner Cafe 28205 Mecklenburg County, North Carolina 3.5 543 Sandwiches
#
#  Moo & Brew 28205 Mecklenburg County, North Carolina 4.0 218 Bars
#
#  Moo & Brew 28205 Mecklenburg County, North Carolina 4.0 218 Burgers
#
#  Moo & Brew 28205 Mecklenburg County, North Carolina 4.0 218 Beer Gardens
#
#  Pisces Sushi Bar & Lounge 28204 Mecklenburg County, North Carolina 4.0 384 Sushi Bars
#
#  Pisces Sushi Bar & Lounge 28204 Mecklenburg County, North Carolina 4.0 384 Japanese
#
#  Vivace 28204 Mecklenburg County, North Carolina 3.5 400 Italian
#
#  Vivace 28204 Mecklenburg County, North Carolina 3.5 400 Tapas/Small Plates
#
#  Owen's Bagel & Deli 28203 Mecklenburg County, North Carolina 4.5 277 Bagels
#
#  Owen's Bagel & Deli 28203 Mecklenburg County, North Carolina 4.5 277 Delis
#
#  Owen's Bagel & Deli 28203 Mecklenburg County, North Carolina 4.5 277 Coffee & Tea
#
#  Bakersfield 28203 Mecklenburg County, North Carolina 4.0 345 Bars
#
#  Bakersfield 28203 Mecklenburg County, North Carolina 4.0 345 Tacos
#
#  Rhino Market & Deli 28208 Mecklenburg County, North Carolina 4.5 175 Delis
#
#  Rhino Market & Deli 28208 Mecklenburg County, North Carolina 4.5 175 Breakfast & Brunch
#
#  Rhino Market & Deli 28208 Mecklenburg County, North Carolina 4.5 175 Sandwiches
#
#  Luce Restaurant & Bar 28202 Mecklenburg County, North Carolina 4.0 170 Italian
#
#  Deejai NoDa 28205 Mecklenburg County, North Carolina 4.5 71 Thai
#
#  Deejai NoDa 28205 Mecklenburg County, North Carolina 4.5 71 Noodles
#
#  Price's Chicken Coop 28203 Mecklenburg County, North Carolina 4.0 348 Southern
#
#  The Thirsty Beaver 28204 Mecklenburg County, North Carolina 4.5 117 Dive Bars
#
#  La Shish Kabob 28205 Mecklenburg County, North Carolina 4.5 255 Middle Eastern
#
#  Soul Central 28205 Mecklenburg County, North Carolina 4.5 115 Soul Food
#
#  Soul Central 28205 Mecklenburg County, North Carolina 4.5 115 Caribbean
#
#  Pizzeria Omaggio 28204 Mecklenburg County, North Carolina 4.5 169 Pizza
#
#  Pizzeria Omaggio 28204 Mecklenburg County, North Carolina 4.5 169 Italian
#
#  Tea Fusion Cafe 28262 Mecklenburg County, North Carolina 4.5 140 Desserts
#
#  Tea Fusion Cafe 28262 Mecklenburg County, North Carolina 4.5 140 Bubble Tea
#
#  Tea Fusion Cafe 28262 Mecklenburg County, North Carolina 4.5 140 Cafes
#
#  Luciano's Ristorante Italiano 28203 Mecklenburg County, North Carolina 4.0 275 Italian
#
#  Essex Bar & Bistro 28280 Mecklenburg County, North Carolina 4.0 294 Gastropubs
#
#  Essex Bar & Bistro 28280 Mecklenburg County, North Carolina 4.0 294 Cocktail Bars
#
#  Essex Bar & Bistro 28280 Mecklenburg County, North Carolina 4.0 294 Mediterranean
#
#  Banh Mi Brothers 28262 Mecklenburg County, North Carolina 4.5 153 Vietnamese
#
#  Banh Mi Brothers 28262 Mecklenburg County, North Carolina 4.5 153 Bubble Tea
#
#  Banh Mi Brothers 28262 Mecklenburg County, North Carolina 4.5 153 Juice Bars & Smoothies
#
#  Fern 28203 Mecklenburg County, North Carolina 4.0 331 Vegetarian
#
#  Fern 28203 Mecklenburg County, North Carolina 4.0 331 Vegan
# 100
#
#  Tamales La Pasadita 28205 Mecklenburg County, North Carolina 5.0 41 Tacos
#
#  Tamales La Pasadita 28205 Mecklenburg County, North Carolina 5.0 41 Latin American
#
#  Yama Izakaya 28205 Mecklenburg County, North Carolina 4.0 210 Ramen
#
#  Yama Izakaya 28205 Mecklenburg County, North Carolina 4.0 210 Sushi Bars
#
#  Yama Izakaya 28205 Mecklenburg County, North Carolina 4.0 210 Izakaya
#
#  Hattie's Tap & Tavern 28205 Mecklenburg County, North Carolina 5.0 40 Dive Bars
#
#  Hattie's Tap & Tavern 28205 Mecklenburg County, North Carolina 5.0 40 Pubs
#
#  Aria 28202 Mecklenburg County, North Carolina 3.5 322 Italian
#
#  Aria 28202 Mecklenburg County, North Carolina 3.5 322 American (New)
#
#  Queen City Q 28202 Mecklenburg County, North Carolina 3.5 313 Barbeque
#
#  Queen City Q 28202 Mecklenburg County, North Carolina 3.5 313 Southern
#
#  Queen City Q 28202 Mecklenburg County, North Carolina 3.5 313 Bars
#
#  Jasmine Grill 28217 Mecklenburg County, North Carolina 4.5 411 Mediterranean
#
#  Jasmine Grill 28217 Mecklenburg County, North Carolina 4.5 411 Middle Eastern
#
#  Jasmine Grill 28217 Mecklenburg County, North Carolina 4.5 411 Halal
#
#  Not Just Coffee- Packard Place 28202 Mecklenburg County, North Carolina 4.5 60 Coffee & Tea
#
#  Diamond Restaurant 28205 Mecklenburg County, North Carolina 3.5 328 Southern
#
#  Diamond Restaurant 28205 Mecklenburg County, North Carolina 3.5 328 American (New)
#
#  Vapiano 28202 Mecklenburg County, North Carolina 3.5 390 Italian
#
#  Vapiano 28202 Mecklenburg County, North Carolina 3.5 390 Pizza
#
#  Vapiano 28202 Mecklenburg County, North Carolina 3.5 390 Bars
#
#  Pio Pio 28203 Mecklenburg County, North Carolina 4.0 327 Peruvian
#
#  Pio Pio 28203 Mecklenburg County, North Carolina 4.0 327 Colombian
#
#  Sandwich Max 28204 Mecklenburg County, North Carolina 4.5 113 American (Traditional)
#
#  Room 112 28284 Mecklenburg County, North Carolina 3.5 239 Asian Fusion
#
#  Room 112 28284 Mecklenburg County, North Carolina 3.5 239 Sushi Bars
#
#  Room 112 28284 Mecklenburg County, North Carolina 3.5 239 Soup
#
#  Crave Dessert Bar 28202 Mecklenburg County, North Carolina 3.5 376 Lounges
#
#  Crave Dessert Bar 28202 Mecklenburg County, North Carolina 3.5 376 Desserts
#
#  Crave Dessert Bar 28202 Mecklenburg County, North Carolina 3.5 376 Hookah Bars
#
#  Reigning Doughnuts 28205 Mecklenburg County, North Carolina 4.5 39 Donuts
#
#  Reigning Doughnuts 28205 Mecklenburg County, North Carolina 4.5 39 Coffee & Tea
#
#  Romare Bearden Park 28202 Mecklenburg County, North Carolina 4.5 70 Parks
#
#  Freedom Park 28203 Mecklenburg County, North Carolina 4.5 137 Parks
#
#  Solstice Tavern 28205 Mecklenburg County, North Carolina 3.5 129 American (Traditional)
#
#  Solstice Tavern 28205 Mecklenburg County, North Carolina 3.5 129 Sports Bars
#
#  The Blind Pig 28205 Mecklenburg County, North Carolina 3.5 95 Dive Bars
#
#  The Blind Pig 28205 Mecklenburg County, North Carolina 3.5 95 Pubs
#
#  Abari Game Bar 28206 Mecklenburg County, North Carolina 4.0 82 Bars
#
#  Abari Game Bar 28206 Mecklenburg County, North Carolina 4.0 82 Arcades
#
#  Murphy's Kitchen & Tap 28202 Mecklenburg County, North Carolina 4.5 101 Irish Pub
#
#  Murphy's Kitchen & Tap 28202 Mecklenburg County, North Carolina 4.5 101 Irish
# 120
#
#  Fleming's Prime Steakhouse - Charlotte 28202 Mecklenburg County, North Carolina 3.5 229 Steakhouses
#
#  Fleming's Prime Steakhouse - Charlotte 28202 Mecklenburg County, North Carolina 3.5 229 Wine Bars
#
#  Euro Grill & Cafe 28205 Mecklenburg County, North Carolina 4.5 56 Turkish
#
#  Euro Grill & Cafe 28205 Mecklenburg County, North Carolina 4.5 56 Mediterranean
#
#  Euro Grill & Cafe 28205 Mecklenburg County, North Carolina 4.5 56 Modern European
#
#  Lumiere French Kitchen 28207 Mecklenburg County, North Carolina 4.5 140 French
#
#  Ru San's 28203 Mecklenburg County, North Carolina 4.0 514 Sushi Bars
#
#  Ru San's 28203 Mecklenburg County, North Carolina 4.0 514 Japanese
#
#  Yafo Kitchen 28211 Mecklenburg County, North Carolina 4.5 318 Middle Eastern
#
#  Yafo Kitchen 28211 Mecklenburg County, North Carolina 4.5 318 Mediterranean
#
#  Yafo Kitchen 28211 Mecklenburg County, North Carolina 4.5 318 Greek
#
#  Copper 28203 Mecklenburg County, North Carolina 4.0 332 Indian
#
#  Copper 28203 Mecklenburg County, North Carolina 4.0 332 Wine Bars
#
#  Kid Cashew 28203 Mecklenburg County, North Carolina 4.0 308 Mediterranean
#
#  Kid Cashew 28203 Mecklenburg County, North Carolina 4.0 308 American (New)
#
#  Coco and the Director 28202 Mecklenburg County, North Carolina 4.0 108 Coffee & Tea
#
#  Coco and the Director 28202 Mecklenburg County, North Carolina 4.0 108 Lounges
#
#  Coco and the Director 28202 Mecklenburg County, North Carolina 4.0 108 Sandwiches
#
#  Paco's Tacos & Tequila 28211 Mecklenburg County, North Carolina 4.0 553 Tex-Mex
#
#  Paco's Tacos & Tequila 28211 Mecklenburg County, North Carolina 4.0 553 Tacos
#
#  Paco's Tacos & Tequila 28211 Mecklenburg County, North Carolina 4.0 553 Bars
#
#  Valhalla Pub and Eatery 28202 Mecklenburg County, North Carolina 4.0 192 Pubs
#
#  Valhalla Pub and Eatery 28202 Mecklenburg County, North Carolina 4.0 192 Scandinavian
#
#  Valhalla Pub and Eatery 28202 Mecklenburg County, North Carolina 4.0 192 Breakfast & Brunch
#
#  Pure Pizza 28205 Mecklenburg County, North Carolina 4.0 130 Pizza
#
#  Pure Pizza 28205 Mecklenburg County, North Carolina 4.0 130 Vegetarian
#
#  Pure Pizza 28205 Mecklenburg County, North Carolina 4.0 130 Gluten-Free
#
#  Lupie's Cafe 28205 Mecklenburg County, North Carolina 4.0 201 American (Traditional)
#
#  Enat Ethiopian Restaurant 28215 Mecklenburg County, North Carolina 5.0 29 Ethiopian
# ERROR1
#
#  The Evening Muse 28205 Mecklenburg County, North Carolina 4.0 59 Music Venues
#
#  The Evening Muse 28205 Mecklenburg County, North Carolina 4.0 59 Bars
#
#  Bean Vegan Cuisine 28205 Mecklenburg County, North Carolina 4.0 280 Vegetarian
#
#  Bean Vegan Cuisine 28205 Mecklenburg County, North Carolina 4.0 280 Vegan
#
#  Bean Vegan Cuisine 28205 Mecklenburg County, North Carolina 4.0 280 Gluten-Free
#
#  Fahrenheit 28202 Mecklenburg County, North Carolina 3.0 569 American (New)
#
#  Letty's 28205 Mecklenburg County, North Carolina 4.0 73 American (New)
#
#  Letty's 28205 Mecklenburg County, North Carolina 4.0 73 Sandwiches
#
#  Roaming Fork 28204 Mecklenburg County, North Carolina 4.5 63 Street Vendors
#
#  Roaming Fork 28204 Mecklenburg County, North Carolina 4.5 63 Soul Food
#
#  Yamazaru 28203 Mecklenburg County, North Carolina 4.5 149 Sushi Bars
#
#  Yamazaru 28203 Mecklenburg County, North Carolina 4.5 149 Ramen
#
#  Yamazaru 28203 Mecklenburg County, North Carolina 4.5 149 Izakaya
# 140
#
#  Thai House - University 28262 Mecklenburg County, North Carolina 4.0 283 Thai
#
#  Thai House - University 28262 Mecklenburg County, North Carolina 4.0 283 Bars
#
#  Thai House - University 28262 Mecklenburg County, North Carolina 4.0 283 Seafood
#
#  Blaze Fast-Fire'd Pizza 28203 Mecklenburg County, North Carolina 4.0 221 Salad
#
#  Blaze Fast-Fire'd Pizza 28203 Mecklenburg County, North Carolina 4.0 221 Pizza
#
#  Blaze Fast-Fire'd Pizza 28203 Mecklenburg County, North Carolina 4.0 221 Fast Food
#
#  McKoy's Smokehouse & Saloon 28217 Mecklenburg County, North Carolina 4.0 486 Barbeque
#
#  McKoy's Smokehouse & Saloon 28217 Mecklenburg County, North Carolina 4.0 486 Southern
#
#  McKoy's Smokehouse & Saloon 28217 Mecklenburg County, North Carolina 4.0 486 Chicken Wings
#
#  Ruth's Chris Steak House 28202 Mecklenburg County, North Carolina 4.0 161 Steakhouses
#
#  Pint Central 28204 Mecklenburg County, North Carolina 4.0 175 American (New)
#
#  Pint Central 28204 Mecklenburg County, North Carolina 4.0 175 Tapas Bars
#
#  Pint Central 28204 Mecklenburg County, North Carolina 4.0 175 Beer Gardens
#
#  Vida Mexican Kitchen y Cantina 28202 Mecklenburg County, North Carolina 3.5 364 Mexican
#
#  Crispy Crepe 28203 Mecklenburg County, North Carolina 4.0 267 Breakfast & Brunch
#
#  Crispy Crepe 28203 Mecklenburg County, North Carolina 4.0 267 Creperies
#
#  Crispy Crepe 28203 Mecklenburg County, North Carolina 4.0 267 Bakeries
#
#  Portofino's Italian Restaurant & Pizzeria 28205 Mecklenburg County, North Carolina 4.0 143 Italian
#
#  Portofino's Italian Restaurant & Pizzeria 28205 Mecklenburg County, North Carolina 4.0 143 Pizza
#
#  Stoke Charlotte 28202 Mecklenburg County, North Carolina 4.0 133 American (New)
#
#  Stoke Charlotte 28202 Mecklenburg County, North Carolina 4.0 133 Cocktail Bars
#
#  The Flying Biscuit Cafe - Charlotte 28209 Mecklenburg County, North Carolina 4.0 518 Breakfast & Brunch
#
#  The Flying Biscuit Cafe - Charlotte 28209 Mecklenburg County, North Carolina 4.0 518 Southern
#
#  The Flying Biscuit Cafe - Charlotte 28209 Mecklenburg County, North Carolina 4.0 518 Soul Food
#
#  The Melting Pot - Charlotte 28204 Mecklenburg County, North Carolina 4.5 125 Fondue
#
#  Malabar 28202 Mecklenburg County, North Carolina 3.5 185 Spanish
#
#  Ri Ra 28202 Mecklenburg County, North Carolina 3.5 276 Irish
#
#  Ri Ra 28202 Mecklenburg County, North Carolina 3.5 276 Pubs
#
#  Thomas Street Tavern 28205 Mecklenburg County, North Carolina 4.0 147 Pubs
#
#  Thomas Street Tavern 28205 Mecklenburg County, North Carolina 4.0 147 American (Traditional)
#
#  Savor Cafe & Catering 28208 Mecklenburg County, North Carolina 4.0 164 Burgers
#
#  Savor Cafe & Catering 28208 Mecklenburg County, North Carolina 4.0 164 American (New)
#
#  Savor Cafe & Catering 28208 Mecklenburg County, North Carolina 4.0 164 Soul Food
#
#  The Dumpling Lady 28205 Mecklenburg County, North Carolina 4.5 72 Food Trucks
#
#  The Dumpling Lady 28205 Mecklenburg County, North Carolina 4.5 72 Chinese
#
#  The Dumpling Lady 28205 Mecklenburg County, North Carolina 4.5 72 Noodles
#
#  Hawthorne's NY Pizza & Bar 28204 Mecklenburg County, North Carolina 4.0 173 Pizza
#
#  Hawthorne's NY Pizza & Bar 28204 Mecklenburg County, North Carolina 4.0 173 Bars
#
#  Hawthorne's NY Pizza & Bar 28204 Mecklenburg County, North Carolina 4.0 173 Italian
#
#  Rai Lay 28203 Mecklenburg County, North Carolina 4.0 130 Sushi Bars
#
#  Rai Lay 28203 Mecklenburg County, North Carolina 4.0 130 Thai
#
#  Rai Lay 28203 Mecklenburg County, North Carolina 4.0 130 Asian Fusion
#
#  Customshop Handcrafted Food 28204 Mecklenburg County, North Carolina 4.0 183 American (New)
#
#  Customshop Handcrafted Food 28204 Mecklenburg County, North Carolina 4.0 183 Seafood
#
#  O-Ku Sushi 28203 Mecklenburg County, North Carolina 4.0 200 Sushi Bars
#
#  O-Ku Sushi 28203 Mecklenburg County, North Carolina 4.0 200 Japanese
#
#  O-Ku Sushi 28203 Mecklenburg County, North Carolina 4.0 200 Seafood
# 160
#
#  Napa on Providence 28207 Mecklenburg County, North Carolina 4.0 199 American (New)
#
#  Napa on Providence 28207 Mecklenburg County, North Carolina 4.0 199 Bars
#
#  Napa on Providence 28207 Mecklenburg County, North Carolina 4.0 199 Breakfast & Brunch
#
#  Zen Asian Fusion 28203 Mecklenburg County, North Carolina 4.0 182 Asian Fusion
#
#  Zen Asian Fusion 28203 Mecklenburg County, North Carolina 4.0 182 Tapas Bars
#
#  Zen Asian Fusion 28203 Mecklenburg County, North Carolina 4.0 182 Noodles
#
#  Whiskey Warehouse 28203 Mecklenburg County, North Carolina 3.5 266 Pubs
#
#  Whiskey Warehouse 28203 Mecklenburg County, North Carolina 3.5 266 American (New)
#
#  Whiskey Warehouse 28203 Mecklenburg County, North Carolina 3.5 266 Whiskey Bars
#
#  Crispy Banh Mi 28217 Mecklenburg County, North Carolina 4.5 205 Vietnamese
#
#  Crispy Banh Mi 28217 Mecklenburg County, North Carolina 4.5 205 Sandwiches
#
#  Crispy Banh Mi 28217 Mecklenburg County, North Carolina 4.5 205 Juice Bars & Smoothies
#
#  Deejai Thai 28207 Mecklenburg County, North Carolina 4.0 239 Thai
#
#  Deejai Thai 28207 Mecklenburg County, North Carolina 4.0 239 Sushi Bars
#
#  Deejai Thai 28207 Mecklenburg County, North Carolina 4.0 239 Asian Fusion
#
#  Rock Bottom Restaurant & Brewery 28202 Mecklenburg County, North Carolina 3.0 310 American (Traditional)
#
#  Rock Bottom Restaurant & Brewery 28202 Mecklenburg County, North Carolina 3.0 310 American (New)
#
#  Rock Bottom Restaurant & Brewery 28202 Mecklenburg County, North Carolina 3.0 310 Pubs
#
#  The Peculiar Rabbit 28205 Mecklenburg County, North Carolina 3.0 443 American (New)
#
#  The Peculiar Rabbit 28205 Mecklenburg County, North Carolina 3.0 443 Gastropubs
#
#  The Peculiar Rabbit 28205 Mecklenburg County, North Carolina 3.0 443 British
#
#  Rush Espresso 28202 Mecklenburg County, North Carolina 4.5 64 Coffee & Tea
#
#  Rush Espresso 28202 Mecklenburg County, North Carolina 4.5 64 Bakeries
#
#  Rush Espresso 28202 Mecklenburg County, North Carolina 4.5 64 Wine Bars
#
#  Pho Real Vietnamese Restaurant and Bar 28262 Mecklenburg County, North Carolina 3.5 268 Vietnamese
#
#  Pho Real Vietnamese Restaurant and Bar 28262 Mecklenburg County, North Carolina 3.5 268 Bubble Tea
#
#  Pho Real Vietnamese Restaurant and Bar 28262 Mecklenburg County, North Carolina 3.5 268 Cocktail Bars
#
#  The Summit Room 28203 Mecklenburg County, North Carolina 4.0 133 Bars
#
#  The Summit Room 28203 Mecklenburg County, North Carolina 4.0 133 Southern
#
#  Babalu Tapas & Tacos 28203 Mecklenburg County, North Carolina 4.0 257 Latin American
#
#  Babalu Tapas & Tacos 28203 Mecklenburg County, North Carolina 4.0 257 Tapas Bars
#
#  Babalu Tapas & Tacos 28203 Mecklenburg County, North Carolina 4.0 257 Cuban
#
#  Que Onda Tacos Uptown 28202 Mecklenburg County, North Carolina 4.0 136 Mexican
#
#  Que Onda Tacos Uptown 28202 Mecklenburg County, North Carolina 4.0 136 Bars
#
#  Flying Saucer Draught Emporium 28262 Mecklenburg County, North Carolina 4.0 241 Pubs
#
#  Flying Saucer Draught Emporium 28262 Mecklenburg County, North Carolina 4.0 241 American (Traditional)
#
#  Hazelnuts Creperie 28202 Mecklenburg County, North Carolina 4.5 64 Desserts
#
#  Hazelnuts Creperie 28202 Mecklenburg County, North Carolina 4.5 64 Breakfast & Brunch
#
#  Hazelnuts Creperie 28202 Mecklenburg County, North Carolina 4.5 64 Creperies
#
#  Poboy's Low Country Seafood Market 28208 Mecklenburg County, North Carolina 4.5 87 Cajun/Creole
#
#  Poboy's Low Country Seafood Market 28208 Mecklenburg County, North Carolina 4.5 87 Seafood Markets
#
#  Poboy's Low Country Seafood Market 28208 Mecklenburg County, North Carolina 4.5 87 Sandwiches
#
#  Snug Harbor 28205 Mecklenburg County, North Carolina 4.5 58 Bars
#
#  Snug Harbor 28205 Mecklenburg County, North Carolina 4.5 58 Music Venues
#
#  The Belfast Mill 28202 Mecklenburg County, North Carolina 4.5 57 Irish Pub
#
#  The Belfast Mill 28202 Mecklenburg County, North Carolina 4.5 57 Cocktail Bars
#
#  Sauceman's 28203 Mecklenburg County, North Carolina 3.5 259 Barbeque
#
#  Sauceman's 28203 Mecklenburg County, North Carolina 3.5 259 Southern
#
#  Sauceman's 28203 Mecklenburg County, North Carolina 3.5 259 Sandwiches
#
#  The Pizza Peel 28205 Mecklenburg County, North Carolina 3.5 136 Pizza
#
#  The Pizza Peel 28205 Mecklenburg County, North Carolina 3.5 136 Italian
#
#  Wooden Vine Wine Bar & Bistro 28202 Mecklenburg County, North Carolina 3.5 136 Wine Bars
#
#  Wooden Vine Wine Bar & Bistro 28202 Mecklenburg County, North Carolina 3.5 136 American (New)
# 180
#
#  The Liberty 28203 Mecklenburg County, North Carolina 3.5 380 Gastropubs
#
#  The Liberty 28203 Mecklenburg County, North Carolina 3.5 380 Burgers
#
#  Eddie's Place 28211 Mecklenburg County, North Carolina 4.0 270 Breakfast & Brunch
#
#  Eddie's Place 28211 Mecklenburg County, North Carolina 4.0 270 American (Traditional)
#
#  Eddie's Place 28211 Mecklenburg County, North Carolina 4.0 270 Bars
#
#  204 North Kitchen & Cocktails 28202 Mecklenburg County, North Carolina 3.5 176 Cocktail Bars
#
#  204 North Kitchen & Cocktails 28202 Mecklenburg County, North Carolina 3.5 176 American (New)
#
#  204 North Kitchen & Cocktails 28202 Mecklenburg County, North Carolina 3.5 176 Venues & Event Spaces
#
#  Fenwick's 28207 Mecklenburg County, North Carolina 4.0 109 American (Traditional)
#
#  Thai Taste 28203 Mecklenburg County, North Carolina 3.5 258 Thai
#
#  DeSano Pizzeria Napoletana 28204 Mecklenburg County, North Carolina 4.0 96 Pizza
#
#  DeSano Pizzeria Napoletana 28204 Mecklenburg County, North Carolina 4.0 96 Italian
#
#  Pasta & Provisions 28207 Mecklenburg County, North Carolina 4.5 100 Pasta Shops
#
#  Pasta & Provisions 28207 Mecklenburg County, North Carolina 4.5 100 Delis
#
#  Pasta & Provisions 28207 Mecklenburg County, North Carolina 4.5 100 Soup
#
#  Mortimer's Cafe and Pub 28202 Mecklenburg County, North Carolina 3.5 164 American (Traditional)
#
#  Mortimer's Cafe and Pub 28202 Mecklenburg County, North Carolina 3.5 164 Pubs
#
#  Mortimer's Cafe and Pub 28202 Mecklenburg County, North Carolina 3.5 164 Wraps
#
#  Duckworth's Grill & Taphouse 28202 Mecklenburg County, North Carolina 3.5 248 American (Traditional)
#
#  Duckworth's Grill & Taphouse 28202 Mecklenburg County, North Carolina 3.5 248 Cheesesteaks
#
#  Duckworth's Grill & Taphouse 28202 Mecklenburg County, North Carolina 3.5 248 Sports Bars
#
#  Poppy's Bagels & More 28211 Mecklenburg County, North Carolina 4.0 215 Bagels
#
#  Poppy's Bagels & More 28211 Mecklenburg County, North Carolina 4.0 215 Breakfast & Brunch
#
#  Johnny Burrito 28282 Mecklenburg County, North Carolina 4.5 88 Mexican
#
#  Johnny Burrito 28282 Mecklenburg County, North Carolina 4.5 88 Tex-Mex
#
#  Akahana Asian Bistro 28205 Mecklenburg County, North Carolina 3.5 230 Asian Fusion
#
#  Akahana Asian Bistro 28205 Mecklenburg County, North Carolina 3.5 230 Sushi Bars
#
#  Akahana Asian Bistro 28205 Mecklenburg County, North Carolina 3.5 230 Vietnamese
#
#  The Mayobird 28203 Mecklenburg County, North Carolina 4.0 140 Salad
#
#  The Mayobird 28203 Mecklenburg County, North Carolina 4.0 140 Soup
#
#  The Mayobird 28203 Mecklenburg County, North Carolina 4.0 140 Sandwiches
#
#  Chopt Creative Salad Co. 28209 Mecklenburg County, North Carolina 4.0 234 Salad
#
#  8.2.0 Bar/Restaurant 28206 Mecklenburg County, North Carolina 4.0 50 Pizza
#
#  8.2.0 Bar/Restaurant 28206 Mecklenburg County, North Carolina 4.0 50 Karaoke
#
#  8.2.0 Bar/Restaurant 28206 Mecklenburg County, North Carolina 4.0 50 Venues & Event Spaces
#
#  Sullivan's Steakhouse 28203 Mecklenburg County, North Carolina 4.0 233 Steakhouses
#
#  Bentley's on 27 28244 Mecklenburg County, North Carolina 4.0 115 Seafood
#
#  Bentley's on 27 28244 Mecklenburg County, North Carolina 4.0 115 French
#
#  Bentley's on 27 28244 Mecklenburg County, North Carolina 4.0 115 Venues & Event Spaces
#
#  Stagioni Four Seasons of Food 28207 Mecklenburg County, North Carolina 4.0 131 Italian
#
#  Stagioni Four Seasons of Food 28207 Mecklenburg County, North Carolina 4.0 131 Bars
#
#  Hex Coffee 28203 Mecklenburg County, North Carolina 4.5 58 Coffee & Tea
#
#  Laurel Market 28207 Mecklenburg County, North Carolina 4.5 83 Delis
#
#  Laurel Market 28207 Mecklenburg County, North Carolina 4.5 83 Sandwiches
#
#  Laurel Market 28207 Mecklenburg County, North Carolina 4.5 83 Coffee & Tea
# 200
#
#  Food Truck Friday Charlotte 28203 Mecklenburg County, North Carolina 4.5 76 Food Trucks
#
#  Food Truck Friday Charlotte 28203 Mecklenburg County, North Carolina 4.5 76 Local Flavor
#
#  Passage To India 28213 Mecklenburg County, North Carolina 4.0 260 Indian
#
#  The Roasting Company 28209 Mecklenburg County, North Carolina 4.0 284 Southern
#
#  The Roasting Company 28209 Mecklenburg County, North Carolina 4.0 284 Chicken Wings
#
#  Bernardin's Restaurant 28202 Mecklenburg County, North Carolina 4.0 114 American (New)
#
#  Bernardin's Restaurant 28202 Mecklenburg County, North Carolina 4.0 114 Bars
#
#  Dino's Family Restaurant 28213 Mecklenburg County, North Carolina 3.5 40 Breakfast & Brunch
#
#  Famous Toastery 28203 Mecklenburg County, North Carolina 3.5 281 Breakfast & Brunch
#
#  Famous Toastery 28203 Mecklenburg County, North Carolina 3.5 281 Coffee & Tea
#
#  Not Just Coffee - South End 28203 Mecklenburg County, North Carolina 4.5 95 Coffee & Tea
#
#  Bonsai Fusion 28202 Mecklenburg County, North Carolina 4.0 72 Sushi Bars
#
#  Bonsai Fusion 28202 Mecklenburg County, North Carolina 4.0 72 Asian Fusion
#
#  Lucky Dog Bark & Brew 28208 Mecklenburg County, North Carolina 4.5 64 Dog Parks
#
#  Lucky Dog Bark & Brew 28208 Mecklenburg County, North Carolina 4.5 64 Pet Sitting
#
#  Landmark Diner Restaurant 28205 Mecklenburg County, North Carolina 3.5 235 Diners
#
#  Landmark Diner Restaurant 28205 Mecklenburg County, North Carolina 3.5 235 Breakfast & Brunch
#
#  Pike's Old Fashioned Soda Shop 28203 Mecklenburg County, North Carolina 3.5 272 American (Traditional)
#
#  Pike's Old Fashioned Soda Shop 28203 Mecklenburg County, North Carolina 3.5 272 Ice Cream & Frozen Yogurt
#
#  Pike's Old Fashioned Soda Shop 28203 Mecklenburg County, North Carolina 3.5 272 Breakfast & Brunch
#
#  Your Pie 28203 Mecklenburg County, North Carolina 4.5 65 Pizza
#
#  Your Pie 28203 Mecklenburg County, North Carolina 4.5 65 Salad
#
#  Your Pie 28203 Mecklenburg County, North Carolina 4.5 65 Fast Food
#
#  Draught 28202 Mecklenburg County, North Carolina 3.5 205 Sports Bars
#
#  Draught 28202 Mecklenburg County, North Carolina 3.5 205 American (New)
#
#  Zoës Kitchen 28204 Mecklenburg County, North Carolina 3.5 175 Mediterranean
#
#  Zoës Kitchen 28204 Mecklenburg County, North Carolina 3.5 175 Southern
#
#  Zoës Kitchen 28204 Mecklenburg County, North Carolina 3.5 175 Greek
#
#  Julia's Café and Books 28211 Mecklenburg County, North Carolina 4.5 71 Coffee & Tea
#
#  Julia's Café and Books 28211 Mecklenburg County, North Carolina 4.5 71 Bookstores
#
#  Mr. K's Soft Ice Cream & Drive In 28203 Mecklenburg County, North Carolina 4.0 137 Burgers
#
#  Mr. K's Soft Ice Cream & Drive In 28203 Mecklenburg County, North Carolina 4.0 137 Ice Cream & Frozen Yogurt
#
#  The Sanctuary 28205 Mecklenburg County, North Carolina 4.0 28 Pubs
#
#  City Smoke 28202 Mecklenburg County, North Carolina 3.5 194 Barbeque
#
#  City Smoke 28202 Mecklenburg County, North Carolina 3.5 194 American (Traditional)
#
#  Cantina 1511 28209 Mecklenburg County, North Carolina 3.5 460 Mexican
#
#  Cantina 1511 28209 Mecklenburg County, North Carolina 3.5 460 Bars
#
#  Cantina 1511 28209 Mecklenburg County, North Carolina 3.5 460 Breakfast & Brunch
#
#  Morton's The Steakhouse 28202 Mecklenburg County, North Carolina 4.0 116 Steakhouses
#
#  Morton's The Steakhouse 28202 Mecklenburg County, North Carolina 4.0 116 American (Traditional)
#  Morton's The Steakhouse 28202 Mecklenburg County, North Carolina 4.0 116 Bars
# 220
#
#  Pita Pit 28202 Mecklenburg County, North Carolina 4.0 79 Sandwiches
#
#  Pita Pit 28202 Mecklenburg County, North Carolina 4.0 79 Mediterranean
#
#  Pita Pit 28202 Mecklenburg County, North Carolina 4.0 79 Fast Food
#
#  Mac's Speed Shop 28203 Mecklenburg County, North Carolina 4.0 192 Barbeque
#
#  Mac's Speed Shop 28203 Mecklenburg County, North Carolina 4.0 192 Sports Bars
#
#  Mac's Speed Shop 28203 Mecklenburg County, North Carolina 4.0 192 American (Traditional)
#
#  Zack's Hamburgers 28209 Mecklenburg County, North Carolina 4.0 149 Burgers
#
#  Bar Cocoa 28202 Mecklenburg County, North Carolina 4.0 79 Chocolatiers & Shops
#
#  Bar Cocoa 28202 Mecklenburg County, North Carolina 4.0 79 Breakfast & Brunch
#
#  Bricktop's Restaurant 28211 Mecklenburg County, North Carolina 4.0 277 Breakfast & Brunch
#
#  Bricktop's Restaurant 28211 Mecklenburg County, North Carolina 4.0 277 Desserts
#
#  Bricktop's Restaurant 28211 Mecklenburg County, North Carolina 4.0 277 Sushi Bars
#
#  Dilworth Tasting Room 28203 Mecklenburg County, North Carolina 4.5 98 Wine Bars
#
#  Dilworth Tasting Room 28203 Mecklenburg County, North Carolina 4.5 98 Tapas/Small Plates
#
#  Zio Casual Italian 28207 Mecklenburg County, North Carolina 4.0 111 Italian
#
#  Zio Casual Italian 28207 Mecklenburg County, North Carolina 4.0 111 Pizza
#
#  Saigon Bay 28262 Mecklenburg County, North Carolina 4.0 130 Vietnamese
#
#  Saigon Bay 28262 Mecklenburg County, North Carolina 4.0 130 Cocktail Bars
#
#  Pho Plus 28202 Mecklenburg County, North Carolina 4.0 112 Vietnamese
#
#  Famous Toastery 28262 Mecklenburg County, North Carolina 4.0 146 Salad
#
#  Famous Toastery 28262 Mecklenburg County, North Carolina 4.0 146 Soup
#
#  Famous Toastery 28262 Mecklenburg County, North Carolina 4.0 146 Breakfast & Brunch
#
#  The Improper Pig 28211 Mecklenburg County, North Carolina 4.0 228 Barbeque
#
#  The Improper Pig 28211 Mecklenburg County, North Carolina 4.0 228 Bars
#
#  The Improper Pig 28211 Mecklenburg County, North Carolina 4.0 228 Korean
#
#  Hasaki Grill 28202 Mecklenburg County, North Carolina 4.0 113 Sushi Bars
#
#  Hasaki Grill 28202 Mecklenburg County, North Carolina 4.0 113 Japanese
#
#  KO Sushi 28202 Mecklenburg County, North Carolina 4.0 101 Sushi Bars
#
#  KO Sushi 28202 Mecklenburg County, North Carolina 4.0 101 Japanese
#
#  Soho Bistro 28202 Mecklenburg County, North Carolina 3.5 137 Chinese
#
#  Renaissance Patisserie 28209 Mecklenburg County, North Carolina 4.5 67 Bakeries
#
#  Renaissance Patisserie 28209 Mecklenburg County, North Carolina 4.5 67 French
#
#  Duckworth's Kitchen & Taphouse 28209 Mecklenburg County, North Carolina 4.0 290 American (Traditional)
#
#  Duckworth's Kitchen & Taphouse 28209 Mecklenburg County, North Carolina 4.0 290 Beer Bar
#
#  Truc Vietnamese Cuisine 28213 Mecklenburg County, North Carolina 4.0 39 Vietnamese
#
#  Fran's Filling Station 28203 Mecklenburg County, North Carolina 4.0 201 American (New)
#
#  Fran's Filling Station 28203 Mecklenburg County, North Carolina 4.0 201 Sandwiches
#
#  Fran's Filling Station 28203 Mecklenburg County, North Carolina 4.0 201 American (Traditional)
#
#  Fonda Las Cazuelas 28213 Mecklenburg County, North Carolina 4.0 38 Mexican
#
#  Brixx Wood Fired Pizza 28202 Mecklenburg County, North Carolina 3.5 127 Pizza
#
#  Brixx Wood Fired Pizza 28202 Mecklenburg County, North Carolina 3.5 127 Italian
# 240
#
#  Cuzzo's Cuisine 28208 Mecklenburg County, North Carolina 4.5 68 Southern
#
#  Cuzzo's Cuisine 28208 Mecklenburg County, North Carolina 4.5 68 Seafood
#
#  Cuzzo's Cuisine 28208 Mecklenburg County, North Carolina 4.5 68 Chicken Wings
#
#  El Pulgarcito De America 28205 Mecklenburg County, North Carolina 4.0 75 Latin American
#
#  Leroy Fox 28211 Mecklenburg County, North Carolina 3.5 280 Southern
#
#  Leroy Fox 28211 Mecklenburg County, North Carolina 3.5 280 American (New)
#
#  Leroy Fox 28211 Mecklenburg County, North Carolina 3.5 280 Sandwiches
#
#  RuRu's Tacos + Tequila 28207 Mecklenburg County, North Carolina 3.5 274 Mexican
#
#  RuRu's Tacos + Tequila 28207 Mecklenburg County, North Carolina 3.5 274 Tex-Mex
#
#  RuRu's Tacos + Tequila 28207 Mecklenburg County, North Carolina 3.5 274 Cocktail Bars
#
#  Sunflour Baking Company 28203 Mecklenburg County, North Carolina 4.0 113 Cafes
#
#  Sunflour Baking Company 28203 Mecklenburg County, North Carolina 4.0 113 Bakeries
#
#  Sunflour Baking Company 28203 Mecklenburg County, North Carolina 4.0 113 Sandwiches
#
#  Seafood Connection 28212 Mecklenburg County, North Carolina 4.0 101 Seafood
#
#  Mango's Caribbean Restaurant 28205 Mecklenburg County, North Carolina 4.0 43 Caribbean
#
#  Sub One Hoagie House 28202 Mecklenburg County, North Carolina 4.5 43 Sandwiches
#
#  Taziki's Mediterranean Cafe 28204 Mecklenburg County, North Carolina 4.0 95 Mediterranean
#
#  Dim Sum Chinese Restaurant 28205 Mecklenburg County, North Carolina 3.0 181 Dim Sum
#
#  Matt's Chicago Dog 28202 Mecklenburg County, North Carolina 4.0 71 Hot Dogs
#
#  Matt's Chicago Dog 28202 Mecklenburg County, North Carolina 4.0 71 Sandwiches
#
#  Matt's Chicago Dog 28202 Mecklenburg County, North Carolina 4.0 71 Burgers
#
#  Ninety's Ice Cream & Sandwiches 28262 Mecklenburg County, North Carolina 4.0 99 Ice Cream & Frozen Yogurt
#
#  Ninety's Ice Cream & Sandwiches 28262 Mecklenburg County, North Carolina 4.0 99 Sandwiches
#
#  Ninety's Ice Cream & Sandwiches 28262 Mecklenburg County, North Carolina 4.0 99 Juice Bars & Smoothies
#
#  Inizio Pizza Napoletana 28203 Mecklenburg County, North Carolina 4.5 84 Pizza
#
#  Nothing But Noodles 28204 Mecklenburg County, North Carolina 4.0 79 Italian
#
#  Nothing But Noodles 28204 Mecklenburg County, North Carolina 4.0 79 Asian Fusion
#
#  Nothing But Noodles 28204 Mecklenburg County, North Carolina 4.0 79 Noodles
#
#  Queen City Burgers & Crafts, QCBC 28202 Mecklenburg County, North Carolina 4.5 58 Burgers
#
#  Queen City Burgers & Crafts, QCBC 28202 Mecklenburg County, North Carolina 4.5 58 Bars
#
#  The Imperial 28202 Mecklenburg County, North Carolina 4.0 48 Lounges
#
#  The Imperial 28202 Mecklenburg County, North Carolina 4.0 48 Jazz & Blues
#
#  The Imperial 28202 Mecklenburg County, North Carolina 4.0 48 Cocktail Bars
#
#  Ink N Ivy CLT 28202 Mecklenburg County, North Carolina 3.0 299 American (New)
#
#  Ink N Ivy CLT 28202 Mecklenburg County, North Carolina 3.0 299 Pubs
#
#  Tyber Creek Pub 28203 Mecklenburg County, North Carolina 4.0 143 Irish
#
#  Tyber Creek Pub 28203 Mecklenburg County, North Carolina 4.0 143 Irish Pub
#
#  Vietnam Grille 28217 Mecklenburg County, North Carolina 4.0 330 Vietnamese
#
#  CO 28209 Mecklenburg County, North Carolina 4.0 281 Vietnamese
#
#  CO 28209 Mecklenburg County, North Carolina 4.0 281 Asian Fusion
#
#  CO 28209 Mecklenburg County, North Carolina 4.0 281 Sushi Bars
# 260
#
#  Viva Chicken 28209 Mecklenburg County, North Carolina 4.5 103 Peruvian
#
#  Pop the Top Craft Beer Shop 28203 Mecklenburg County, North Carolina 5.0 25 Beer Bar
#
#  Sunflower Family Restaurant 28269 Mecklenburg County, North Carolina 4.5 41 Diners
#
#  BLT Steak 28202 Mecklenburg County, North Carolina 4.0 65 Bars
#
#  Nakato Japanese Steakhouse 28262 Mecklenburg County, North Carolina 3.5 139 Japanese
#
#  Nakato Japanese Steakhouse 28262 Mecklenburg County, North Carolina 3.5 139 Sushi Bars
#
#  Mi Barrio's Halal Cart 28202 Mecklenburg County, North Carolina 4.0 49 Food Trucks
#
#  Mi Barrio's Halal Cart 28202 Mecklenburg County, North Carolina 4.0 49 Halal
#
#  Freshwaters 28202 Mecklenburg County, North Carolina 4.0 73 Southern
#
#  Freshwaters 28202 Mecklenburg County, North Carolina 4.0 73 Cajun/Creole
#
#  Freshwaters 28202 Mecklenburg County, North Carolina 4.0 73 Soul Food
#
#  The Mad Greek of Charlotte - An Authentic Greek Cafe 28217 Mecklenburg County, North Carolina 4.0 179 Greek
#
#  The Mad Greek of Charlotte - An Authentic Greek Cafe 28217 Mecklenburg County, North Carolina 4.0 179 Breakfast & Brunch
#
#  The Mad Greek of Charlotte - An Authentic Greek Cafe 28217 Mecklenburg County, North Carolina 4.0 179 Mediterranean
#
#  Redeye Diner 28202 Mecklenburg County, North Carolina 3.5 192 Diners
#
#  Redeye Diner 28202 Mecklenburg County, North Carolina 3.5 192 Breakfast & Brunch
#
#  Ginbu 401 28207 Mecklenburg County, North Carolina 3.5 172 Sushi Bars
#
#  Ginbu 401 28207 Mecklenburg County, North Carolina 3.5 172 Chinese
#
#  McCormick & Schmick's Seafood & Steaks 28202 Mecklenburg County, North Carolina 3.0 205 Seafood
#
# ...
#
#  KFC 19934 Kent County, Delaware 1.0 5 Chicken Wings
#
#  Little Italy 19901 Kent County, Delaware 1.0 1 Pizza
#
#  Little Italy 19901 Kent County, Delaware 1.0 1 Italian
# ERROR1
#
#  Wendy's 19901 Kent County, Delaware 1.0 16 Fast Food
#
#  Wendy's 19901 Kent County, Delaware 1.0 16 Burgers
#
#  Brownstone Cafe 19904 Kent County, Delaware 2.0 1 Cafes
#
#  McDonald's 19934 Kent County, Delaware 1.5 2 Fast Food
#
#  McDonald's 19934 Kent County, Delaware 1.5 2 Coffee & Tea
#
#  McDonald's 19934 Kent County, Delaware 1.5 2 Burgers
#
#  La Ortolana Pizza & Ristorante 19934 Kent County, Delaware 1.0 2 Food Delivery Services
#
#  La Ortolana Pizza & Ristorante 19934 Kent County, Delaware 1.0 2 Pizza
#
#  La Ortolana Pizza & Ristorante 19934 Kent County, Delaware 1.0 2 Sandwiches
#
#  Food Lion Store 1385 19904 Kent County, Delaware 2.0 1 Delis
#
#  Gevalia Kaffe 19905 Kent County, Delaware 1.0 3 Coffee & Tea
#
#  The Boulevard 19977 Kent County, Delaware 1.0 1 American (New)
# ERROR1
#
#  Papa John's Pizza 19901 Kent County, Delaware 1.5 3 Pizza
#
#  China Wok 19901 Kent County, Delaware 3.0 1 Chinese
# ERROR1
#
#  Sbarro's Pizzeria 19901 Kent County, Delaware 2.0 1 Pizza
#
#  Dunkin' Donuts 19901 Kent County, Delaware 3.0 2 Donuts
#
#  Dunkin' Donuts 19901 Kent County, Delaware 3.0 2 Coffee & Tea
#
#  Race & Sports Book Pub 19901 Kent County, Delaware 1.0 1 Pizza
#
#  Race & Sports Book Pub 19901 Kent County, Delaware 1.0 1 Sports Bars
#
#  Papa John's Pizza 19904 Kent County, Delaware 1.0 1 Pizza
# 200
#
#  House of Coffi 19901 Kent County, Delaware 5.0 1 Coffee & Tea
#
#  Puffster 19904 Kent County, Delaware 5.0 1 Tobacco Shops
#
#  Puffster 19904 Kent County, Delaware 5.0 1 Hookah Bars
#
#  Puffster 19904 Kent County, Delaware 5.0 1 Vape Shops
#
#  Ming Tree 19901 Kent County, Delaware 1.0 1 Food Court
#
#  Ming Tree 19901 Kent County, Delaware 1.0 1 Chinese
# ERROR1
#
#  The Hungry Spork 19904 Kent County, Delaware 5.0 1 Gluten-Free
#
#  The Hungry Spork 19904 Kent County, Delaware 5.0 1 Food Trucks
#
#  The Hungry Spork 19904 Kent County, Delaware 5.0 1 American (New)
# ERROR1
# ERROR2
#
#  Subway 19901 Kent County, Delaware 5.0 1 Sandwiches
#
#  Subway 19901 Kent County, Delaware 5.0 1 Fast Food
#
#  Marimonti Ristorante & Pizzeria 19904 Kent County, Delaware 1.0 1 Pizza
#
#  KFC 19904 Kent County, Delaware 2.0 4 Fast Food
#
#  KFC 19904 Kent County, Delaware 2.0 4 Chicken Wings
#
#  McDonald's 19901 Kent County, Delaware 1.0 1 Fast Food
#
#  McDonald's 19901 Kent County, Delaware 1.0 1 Burgers
#
#  McDonald's 19901 Kent County, Delaware 1.0 1 Coffee & Tea
#
#  Gr8 Burgers & Shakes 19901 Kent County, Delaware 3.0 1 Burgers
#
#  Gr8 Burgers & Shakes 19901 Kent County, Delaware 3.0 1 Ice Cream & Frozen Yogurt
#
#  Gr8 Burgers & Shakes 19901 Kent County, Delaware 3.0 1 Hot Dogs
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 0
#
#  Smoky Martins BBQ 16335 Crawford County, Pennsylvania 5.0 19 Pizza
#
#  Smoky Martins BBQ 16335 Crawford County, Pennsylvania 5.0 19 Barbeque
#
#  Smoky Martins BBQ 16335 Crawford County, Pennsylvania 5.0 19 Chicken Wings
#
#  Cannon's Chophouse 16335 Crawford County, Pennsylvania 4.0 72 Steakhouses
#
#  Cannon's Chophouse 16335 Crawford County, Pennsylvania 4.0 72 Seafood
#
#  Cannon's Chophouse 16335 Crawford County, Pennsylvania 4.0 72 Breakfast & Brunch
#
#  Chovy's Italian Casual 16335 Crawford County, Pennsylvania 3.5 57 Caterers
#
#  Chovy's Italian Casual 16335 Crawford County, Pennsylvania 3.5 57 Italian
#
#  Roff School Tavern 16335 Crawford County, Pennsylvania 4.0 13 Gastropubs
#
#  Market House Grille 16335 Crawford County, Pennsylvania 4.0 23 Breakfast & Brunch
#
#  Market House Grille 16335 Crawford County, Pennsylvania 4.0 23 Burgers
#
#  Market House Grille 16335 Crawford County, Pennsylvania 4.0 23 American (Traditional)
#
#  Julian's Bar & Grill 16335 Crawford County, Pennsylvania 4.0 21 Steakhouses
#
#  Julian's Bar & Grill 16335 Crawford County, Pennsylvania 4.0 21 Burgers
#
#  Julian's Bar & Grill 16335 Crawford County, Pennsylvania 4.0 21 American (Traditional)
#
#  Timber Creek Tap & Table 16335 Crawford County, Pennsylvania 3.5 89 American (Traditional)
#
#  Timber Creek Tap & Table 16335 Crawford County, Pennsylvania 3.5 89 Pubs
#
#  Timber Creek Tap & Table 16335 Crawford County, Pennsylvania 3.5 89 Breweries
#
#  Grace Asian Restaurant 16335 Crawford County, Pennsylvania 3.5 17 Asian Fusion
#
#  Pennsylvania Sandwich Company 16335 Crawford County, Pennsylvania 4.5 18 Sandwiches
#
#  Pennsylvania Sandwich Company 16335 Crawford County, Pennsylvania 4.5 18 Pizza
#
#  Mannino Italian Garden 16335 Crawford County, Pennsylvania 4.5 11 Italian
#
#  Creative Crust Bakery 16335 Crawford County, Pennsylvania 4.0 13 Bakeries
#
#  Creative Crust Bakery 16335 Crawford County, Pennsylvania 4.0 13 Coffee & Tea
#
#  Creative Crust Bakery 16335 Crawford County, Pennsylvania 4.0 13 Cafes
#
#  Rosa's Legacy 16335 Crawford County, Pennsylvania 5.0 8 Dominican
#
#  The Other Place - Penny Bar 16335 Crawford County, Pennsylvania 4.5 6 Bars
#
#  The Whole Darn Thing Sub Shop 16335 Crawford County, Pennsylvania 3.5 18 Sandwiches
#
#  Cracker Barrel Old Country Store 16335 Crawford County, Pennsylvania 3.0 23 Breakfast & Brunch
#
#  Cracker Barrel Old Country Store 16335 Crawford County, Pennsylvania 3.0 23 American (Traditional)
#
#  Cracker Barrel Old Country Store 16335 Crawford County, Pennsylvania 3.0 23 Southern
#
#  Grounds For Change 16335 Crawford County, Pennsylvania 5.0 4 Coffee & Tea
#
#  Grounds For Change 16335 Crawford County, Pennsylvania 5.0 4 Venues & Event Spaces
#
#  Grounds For Change 16335 Crawford County, Pennsylvania 5.0 4 Community Service/Non-Profit
#
#  Pizza Villa 16335 Crawford County, Pennsylvania 4.0 10 Pizza
#
#  Tarot Bean Roasting Co. 16335 Crawford County, Pennsylvania 5.0 5 Coffee & Tea
#
#  Tarot Bean Roasting Co. 16335 Crawford County, Pennsylvania 5.0 5 Bakeries
#
#  Tarot Bean Roasting Co. 16335 Crawford County, Pennsylvania 5.0 5 Coffee Roasteries
#
#  Valenza Restaurant 16335 Crawford County, Pennsylvania 4.0 11 Italian
# 20
#
#  Chippers Pub 16335 Crawford County, Pennsylvania 3.5 8 Bars
#
#  Col Crawford Park 16335 Crawford County, Pennsylvania 5.0 1 Parks
#
#  Super China Buffet 16335 Crawford County, Pennsylvania 3.5 7 Chinese
#
#  E-Street Eatery 16335 Crawford County, Pennsylvania 4.5 3 Breakfast & Brunch
#
#  E-Street Eatery 16335 Crawford County, Pennsylvania 4.5 3 Burgers
#
#  E-Street Eatery 16335 Crawford County, Pennsylvania 4.5 3 American (Traditional)
# ERROR1
#
#  Safari Bar 16335 Crawford County, Pennsylvania 3.5 9 Restaurants
#
#  Safari Bar 16335 Crawford County, Pennsylvania 3.5 9 Golf
#
#  Hoss's Steak & Sea House 16335 Crawford County, Pennsylvania 3.0 8 Seafood
#
#  Hoss's Steak & Sea House 16335 Crawford County, Pennsylvania 3.0 8 Steakhouses
#
#  Firehouse Tap & Grille 16335 Crawford County, Pennsylvania 4.0 8 American (Traditional)
#
#  Firehouse Tap & Grille 16335 Crawford County, Pennsylvania 4.0 8 Bars
#
#  Firehouse Tap & Grille 16335 Crawford County, Pennsylvania 4.0 8 Smokehouse
#
#  Earl J's Restaurant 16335 Crawford County, Pennsylvania 4.5 3 Pizza
#
#  Earl J's Restaurant 16335 Crawford County, Pennsylvania 4.5 3 Chicken Wings
#
#  Earl J's Restaurant 16335 Crawford County, Pennsylvania 4.5 3 Sandwiches
#
#  Hunter's Inn 16335 Crawford County, Pennsylvania 5.0 8 Bars
#
#  Hunter's Inn 16335 Crawford County, Pennsylvania 5.0 8 American (Traditional)
#
#  Hunter's Inn 16335 Crawford County, Pennsylvania 5.0 8 Chicken Wings
#
#  Chestnut St Pub & Grill 16335 Crawford County, Pennsylvania 4.5 3 American (Traditional)
#
#  Chestnut St Pub & Grill 16335 Crawford County, Pennsylvania 4.5 3 Sports Bars
#
#  Dave's Place 16360 Crawford County, Pennsylvania 4.5 4 American (Traditional)
#
#  Dave's Place 16360 Crawford County, Pennsylvania 4.5 4 Fast Food
#
#  Dave's Place 16360 Crawford County, Pennsylvania 4.5 4 Ice Cream & Frozen Yogurt
#
#  Compadres Mexican Restaurant 16335 Crawford County, Pennsylvania 3.5 13 Mexican
# ERROR1
#
#  McDonald's 16335 Crawford County, Pennsylvania 3.5 4 Burgers
#
#  McDonald's 16335 Crawford County, Pennsylvania 3.5 4 Fast Food
#
#  McDonald's 16335 Crawford County, Pennsylvania 3.5 4 Coffee & Tea
#
#  The Soup Den 16335 Crawford County, Pennsylvania 5.0 1 Soup
#
#  Drogo N Tuck Artisan Cafe 16335 Crawford County, Pennsylvania 5.0 1 Coffee & Tea
#
#  Drogo N Tuck Artisan Cafe 16335 Crawford County, Pennsylvania 5.0 1 Cafes
#
#  Applebee's Grill + Bar 16335 Crawford County, Pennsylvania 3.0 9 American (Traditional)
#
#  Applebee's Grill + Bar 16335 Crawford County, Pennsylvania 3.0 9 Sports Bars
#
#  Applebee's Grill + Bar 16335 Crawford County, Pennsylvania 3.0 9 Burgers
#
#  Vocelli Pizza 16335 Crawford County, Pennsylvania 3.5 4 Pizza
#
#  Time Out Tavern 16335 Crawford County, Pennsylvania 3.5 2 Sports Bars
#
#  Pizza Hut 16335 Crawford County, Pennsylvania 2.5 3 Pizza
#
#  Pizza Hut 16335 Crawford County, Pennsylvania 2.5 3 Italian
#
#  Pizza Hut 16335 Crawford County, Pennsylvania 2.5 3 Chicken Wings
#
#  Hailwood Golf Course 16335 Crawford County, Pennsylvania 4.0 1 Restaurants
#
#  Hailwood Golf Course 16335 Crawford County, Pennsylvania 4.0 1 Golf
# 40
#
#  Dairy Queen 16335 Crawford County, Pennsylvania 2.5 3 Fast Food
#
#  Dairy Queen 16335 Crawford County, Pennsylvania 2.5 3 Ice Cream & Frozen Yogurt
#
#  Deer Head Inn 16335 Crawford County, Pennsylvania 3.0 3 Sports Bars
#
#  Deer Head Inn 16335 Crawford County, Pennsylvania 3.0 3 American (Traditional)
#
#  Deer Head Inn 16335 Crawford County, Pennsylvania 3.0 3 Chicken Wings
#
#  Ranz Bar & Grill 16335 Crawford County, Pennsylvania 4.0 2 American (New)
# ERROR1
#
#  New Imperial Chinese Buffet 16335 Crawford County, Pennsylvania 2.0 5 Chinese
#
#  Factory Restaurant 16433 Crawford County, Pennsylvania 3.5 4 Diners
#
#  Factory Restaurant 16433 Crawford County, Pennsylvania 3.5 4 Breakfast & Brunch
#
#  Domino's Pizza 16335 Crawford County, Pennsylvania 4.0 1 Pizza
#
#  Domino's Pizza 16335 Crawford County, Pennsylvania 4.0 1 Chicken Wings
#
#  Domino's Pizza 16335 Crawford County, Pennsylvania 4.0 1 Sandwiches
#
#  Valenza 16335 Crawford County, Pennsylvania 2.5 2 Pizza
#
#  Tim Horton's 16335 Crawford County, Pennsylvania 2.0 8 Coffee & Tea
#
#  Red Lobster 16335 Crawford County, Pennsylvania 3.5 5 Seafood
#
#  Red Lobster 16335 Crawford County, Pennsylvania 3.5 5 American (Traditional)
#
#  Perkins Restaurant & Bakery 16335 Crawford County, Pennsylvania 3.0 5 Bakeries
#
#  Perkins Restaurant & Bakery 16335 Crawford County, Pennsylvania 3.0 5 Breakfast & Brunch
#
#  Perkins Restaurant & Bakery 16335 Crawford County, Pennsylvania 3.0 5 American (Traditional)
#
#  Neon Cactus Restaurant & Lounge 16335 Crawford County, Pennsylvania 3.0 1 Dance Clubs
#
#  Neon Cactus Restaurant & Lounge 16335 Crawford County, Pennsylvania 3.0 1 Lounges
#
#  Burger King 16335 Crawford County, Pennsylvania 2.0 1 Burgers
#
#  Pizza Villa 16433 Crawford County, Pennsylvania 2.5 4 Pizza
#
#  Pizza Villa 16433 Crawford County, Pennsylvania 2.5 4 Salad
#
#  Pizza Villa 16433 Crawford County, Pennsylvania 2.5 4 Mexican
# ERROR1
#
#  McDonald's 16335 Crawford County, Pennsylvania 1.0 1 Fast Food
#
#  McDonald's 16335 Crawford County, Pennsylvania 1.0 1 Burgers
#
#  McDonald's 16335 Crawford County, Pennsylvania 1.0 1 Coffee & Tea
#
#  KFC 16335 Crawford County, Pennsylvania 1.5 3 Fast Food
#
#  KFC 16335 Crawford County, Pennsylvania 1.5 3 Chicken Wings
#
#  Wendy's 16335 Crawford County, Pennsylvania 1.0 3 Fast Food
#
#  Wendy's 16335 Crawford County, Pennsylvania 1.0 3 Burgers
#
#  Burger King 16335 Crawford County, Pennsylvania 2.0 1 Burgers
#
#  Natalie's Sports Garden 16335 Crawford County, Pennsylvania 5.0 1 Sports Bars
#
#  Natalie's Sports Garden 16335 Crawford County, Pennsylvania 5.0 1 Dance Clubs
#
#  Taco Bell 16335 Crawford County, Pennsylvania 5.0 1 Fast Food
#
#  Taco Bell 16335 Crawford County, Pennsylvania 5.0 1 Mexican
#
#  Taco Bell 16335 Crawford County, Pennsylvania 5.0 1 Tex-Mex
#
#  South Station 9 16335 Crawford County, Pennsylvania 4.0 1 Bars
# 60
#
#  Willy G's 16335 Crawford County, Pennsylvania 4.5 2 Pizza
#
#  Willy G's 16335 Crawford County, Pennsylvania 4.5 2 Burgers
#
#  Willy G's 16335 Crawford County, Pennsylvania 4.5 2 Sandwiches
#
#  Owl's Nest 16433 Crawford County, Pennsylvania 2.5 2 Bars
#
#  Pizza Joe's 16433 Crawford County, Pennsylvania 3.0 2 Pizza
#
#  Conneaut Lake Volunteer Fire Department Station 3 16316 Crawford County, Pennsylvania 2.0 1 Restaurants
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 0
#
#  Peter's Europa House 18458 Pike County, Pennsylvania 4.5 53 Italian
#
#  Peter's Europa House 18458 Pike County, Pennsylvania 4.5 53 Mediterranean
#
#  Ryan's Deli 18428 Pike County, Pennsylvania 4.0 27 Delis
#
#  Carini Pizza and Pasta 18428 Pike County, Pennsylvania 3.5 24 Pizza
#
#  Carini Pizza and Pasta 18428 Pike County, Pennsylvania 3.5 24 Italian
#
#  Carini Pizza and Pasta 18428 Pike County, Pennsylvania 3.5 24 Bars
#
#  Brother Bruno's Pizza 18428 Pike County, Pennsylvania 2.5 24 Pizza
#
#  The Forklift Cafe 18328 Pike County, Pennsylvania 4.5 34 Breakfast & Brunch
#
#  The Forklift Cafe 18328 Pike County, Pennsylvania 4.5 34 Coffee & Tea
#
#  The Forklift Cafe 18328 Pike County, Pennsylvania 4.5 34 Cafes
#
#  McDonald's 18428 Pike County, Pennsylvania 3.5 6 Fast Food
#
#  McDonald's 18428 Pike County, Pennsylvania 3.5 6 Burgers
#
#  McDonald's 18428 Pike County, Pennsylvania 3.5 6 Coffee & Tea
#
#  Dunkin' Donuts 18428 Pike County, Pennsylvania 4.0 3 Coffee & Tea
#
#  Dunkin' Donuts 18428 Pike County, Pennsylvania 4.0 3 Donuts
#
#  Failte 18328 Pike County, Pennsylvania 3.0 32 Bars
#
#  Failte 18328 Pike County, Pennsylvania 3.0 32 Irish
#
#  Failte 18328 Pike County, Pennsylvania 3.0 32 Music Venues
#
#  Ray & Charles 18337 Pike County, Pennsylvania 3.0 16 Diners
#
#  Ray & Charles 18337 Pike County, Pennsylvania 3.0 16 Breakfast & Brunch
#
#  Ray & Charles 18337 Pike County, Pennsylvania 3.0 16 Delis
#
#  Pie's On 18328 Pike County, Pennsylvania 3.0 30 American (New)
#
#  Pie's On 18328 Pike County, Pennsylvania 3.0 30 Italian
#
#  The White Pine Inn 18435 Pike County, Pennsylvania 4.0 12 Steakhouses
#
#  The White Pine Inn 18435 Pike County, Pennsylvania 4.0 12 Hotels
#
#  The White Pine Inn 18435 Pike County, Pennsylvania 4.0 12 American (Traditional)
#
#  Ellen's Deli 18428 Pike County, Pennsylvania 2.5 7 Delis
#
#  Chris & Ginas Café 18328 Pike County, Pennsylvania 4.5 13 Sandwiches
#
#  Chris & Ginas Café 18328 Pike County, Pennsylvania 4.5 13 Cafes
#
#  Chris & Ginas Café 18328 Pike County, Pennsylvania 4.5 13 American (Traditional)
#
#  Panda Garden 18428 Pike County, Pennsylvania 3.0 7 Chinese
#
#  Pete Pizza 18337 Pike County, Pennsylvania 3.5 3 Pizza
#
#  Side Street Tavern 18328 Pike County, Pennsylvania 4.0 5 Pubs
#
#  Good Time Pizza 18328 Pike County, Pennsylvania 3.0 20 Pizza
#
#  Subway 18428 Pike County, Pennsylvania 1.0 6 Sandwiches
#
#  Subway 18428 Pike County, Pennsylvania 1.0 6 Fast Food
#
#  The 402 Cafe 18428 Pike County, Pennsylvania 2.0 17 American (Traditional)
#
#  The 402 Cafe 18428 Pike County, Pennsylvania 2.0 17 Diners
#
#  Lakeview Plaza Market and Dairy Bar 18328 Pike County, Pennsylvania 2.5 10 Delis
#
#  Lakeview Plaza Market and Dairy Bar 18328 Pike County, Pennsylvania 2.5 10 Grocery
#
#  Lakeview Plaza Market and Dairy Bar 18328 Pike County, Pennsylvania 2.5 10 Ice Cream & Frozen Yogurt
# 20
#
#  China Delight 18328 Pike County, Pennsylvania 2.0 13 Chinese
#
#  Sisters Corner Deli & Convenience Store 18328 Pike County, Pennsylvania 2.5 6 Convenience Stores
#
#  Sisters Corner Deli & Convenience Store 18328 Pike County, Pennsylvania 2.5 6 Delis
#
#  China Dynasty Restaurant 18428 Pike County, Pennsylvania 3.0 2 Chinese
#
#  Dingmans Choice Bridge 18328 Pike County, Pennsylvania 4.5 2 Landmarks & Historical Buildings
#
#  The Historic Greeley Inn 18425 Pike County, Pennsylvania 5.0 1 Bars
#
#  The Historic Greeley Inn 18425 Pike County, Pennsylvania 5.0 1 Bed & Breakfast
#
#  The Historic Greeley Inn 18425 Pike County, Pennsylvania 5.0 1 Karaoke
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960

# %% [markdown]
# <h3>Part 1: Cleaning the Data</h3>
#
# After waiting forever for the Kyrus for loop to finish, we needed to clean up the data. Early on, we noticed that res_df displayed \$, \$\$, and \$\$\$ in the price column, but would not show \$\$\$\$. After several attempts, we decided to replace the dollar signs with equivalent numerical value. Thus, we ended up with the following:
#
# <ul>
# <li>\$ = 1 </li>
# <li>\$\$= 2 </li>
# <li>\$\$\$ = 3 </li>
# <li>\$\$\$\$ = 4 </li>
# </ul>
#
# Additionally, we realized the Yelp does not have an American category. Instead, Yelp uses American (New) and American (Traditional). After some research, we realized that we were not entirely sure what the exact difference between the two American sub-categories were, so we opted to merge the two category types into one - American.
#
# After these corrections, we saved the changes to the res_df dataframe.

# %%
res_df.to_csv("output201804080249.csv")
try:
    res_df.price.replace(["$","$$","$$$","$$$$"],[1,2,3,4],inplace=True)
except:
    print("Already done")
try:
    res_df.category.replace(["American (New)","American (Traditional)"],["American","American"],inplace=True)
except:
    print("Already done")
res_df=res_df.drop_duplicates(subset=["name","zipcode","rating","review_count"],keep="first")
res_df
# Out:
#                                              name zipcode  \
# 0                                  Cabo Fish Taco   28205
# 1                              Midwood Smokehouse   28205
# 2                        Sabor Latin Street Grill   28204
# 3                                Benny Pennello's   28205
# 4                                     JackBeagles   28205
# 5                       The Cellar At Duckworth's   28202
# 6                          Pinky's Westside Grill   28208
# 7                         The Fig Tree Restaurant   28204
# 9                       VBGB Beer Hall and Garden   28206
# 10                               Dandelion Market   28202
# 11                             Growlers Pourhouse   28205
# 12                            Alexander Michael's   28202
# 13                Sabor Latin Street Grill - Noda   28205
# 14                                   Tupelo Honey   28203
# 15                             The King's Kitchen   28202
# 16                   Davidson Street Public House   28205
# 17    Three Amigos Mexican Restaurant and Cantina   28205
# 18                                       300 East   28203
# 19                               Rooster's Uptown   28202
# 20                                    Las Lupitas   28213
# 21                                        5Church   28202
# 22                          Good Food on Montford   28209
# 23                                   Mimosa Grill   28202
# 24                                     The Asbury   28202
# 25                                 Midnight Diner   28202
# 26                                 Mama Ricotta's   28204
# 27                                     Papi Queso   28202
# 28                  Lebowski's Neighborhood Grill   28203
# 29               Carpe Diem Restaurant & Caterers   28204
# 30                       JJ's Red Hots - Dilworth   28203
# ...                                           ...     ...
# 2102                                    Pizza Hut   19901
# 2103                                Panda Express   19901
# 2104                       Chovy's Italian Casual   16335
# 2105                          Market House Grille   16335
# 2106                         Julian's Bar & Grill   16335
# 2107                     Timber Creek Tap & Table   16335
# 2108                       Mannino Italian Garden   16335
# 2109             Cracker Barrel Old Country Store   16335
# 2110                           Valenza Restaurant   16335
# 2111                           Super China Buffet   16335
# 2112                       Firehouse Tap & Grille   16335
# 2113                                 Hunter's Inn   16335
# 2114                      Chestnut St Pub & Grill   16335
# 2115                                 Dave's Place   16360
# 2116                       Applebee's Grill + Bar   16335
# 2117                                    Pizza Hut   16335
# 2118                                Deer Head Inn   16335
# 2119                  New Imperial Chinese Buffet   16335
# 2120                                  Red Lobster   16335
# 2121                  Perkins Restaurant & Bakery   16335
# 2122                                    Taco Bell   16335
# 2123                         Peter's Europa House   18458
# 2124                       Carini Pizza and Pasta   18428
# 2125                                     Pie's On   18328
# 2127                           The White Pine Inn   18435
# 2128                           Chris & Ginas Café   18328
# 2129                                 Panda Garden   18428
# 2130                                 The 402 Cafe   18428
# 2131                                China Delight   18328
# 2132                     China Dynasty Restaurant   18428
#
#                            county_string  rating review_count  category  \
# 0     Mecklenburg County, North Carolina     4.0          990   Mexican
# 1     Mecklenburg County, North Carolina     4.5         1281  American
# 2     Mecklenburg County, North Carolina     4.5          682   Mexican
# 3     Mecklenburg County, North Carolina     4.0          234   Italian
# 4     Mecklenburg County, North Carolina     4.0          292  American
# 5     Mecklenburg County, North Carolina     4.5          361  American
# 6     Mecklenburg County, North Carolina     4.0          856  American
# 7     Mecklenburg County, North Carolina     4.5          343  American
# 9     Mecklenburg County, North Carolina     4.5          326  American
# 10    Mecklenburg County, North Carolina     4.0          553  American
# 11    Mecklenburg County, North Carolina     4.0          201  American
# 12    Mecklenburg County, North Carolina     4.5          331  American
# 13    Mecklenburg County, North Carolina     4.5          155   Mexican
# 14    Mecklenburg County, North Carolina     4.0         1180  American
# 15    Mecklenburg County, North Carolina     4.0          484  American
# 16    Mecklenburg County, North Carolina     4.0          136  American
# 17    Mecklenburg County, North Carolina     4.0          375   Mexican
# 18    Mecklenburg County, North Carolina     4.0          582  American
# 19    Mecklenburg County, North Carolina     4.0          402  American
# 20    Mecklenburg County, North Carolina     4.5           49   Mexican
# 21    Mecklenburg County, North Carolina     3.5          575  American
# 22    Mecklenburg County, North Carolina     4.5          582  American
# 23    Mecklenburg County, North Carolina     4.0          426  American
# 24    Mecklenburg County, North Carolina     4.0          205  American
# 25    Mecklenburg County, North Carolina     4.0          612  American
# 26    Mecklenburg County, North Carolina     4.0          415   Italian
# 27    Mecklenburg County, North Carolina     4.5          127  American
# 28    Mecklenburg County, North Carolina     4.5          335  American
# 29    Mecklenburg County, North Carolina     4.0          174  American
# 30    Mecklenburg County, North Carolina     4.0          349  American
# ...                                  ...     ...          ...       ...
# 2102               Kent County, Delaware     2.0           12   Italian
# 2103               Kent County, Delaware     2.0            9   Chinese
# 2104       Crawford County, Pennsylvania     3.5           57   Italian
# 2105       Crawford County, Pennsylvania     4.0           23  American
# 2106       Crawford County, Pennsylvania     4.0           21  American
# 2107       Crawford County, Pennsylvania     3.5           89  American
# 2108       Crawford County, Pennsylvania     4.5           11   Italian
# 2109       Crawford County, Pennsylvania     3.0           23  American
# 2110       Crawford County, Pennsylvania     4.0           11   Italian
# 2111       Crawford County, Pennsylvania     3.5            7   Chinese
# 2112       Crawford County, Pennsylvania     4.0            8  American
# 2113       Crawford County, Pennsylvania     5.0            8  American
# 2114       Crawford County, Pennsylvania     4.5            3  American
# 2115       Crawford County, Pennsylvania     4.5            4  American
# 2116       Crawford County, Pennsylvania     3.0            9  American
# 2117       Crawford County, Pennsylvania     2.5            3   Italian
# 2118       Crawford County, Pennsylvania     3.0            3  American
# 2119       Crawford County, Pennsylvania     2.0            5   Chinese
# 2120       Crawford County, Pennsylvania     3.5            5  American
# 2121       Crawford County, Pennsylvania     3.0            5  American
# 2122       Crawford County, Pennsylvania     5.0            1   Mexican
# 2123           Pike County, Pennsylvania     4.5           53   Italian
# 2124           Pike County, Pennsylvania     3.5           24   Italian
# 2125           Pike County, Pennsylvania     3.0           30  American
# 2127           Pike County, Pennsylvania     4.0           12  American
# 2128           Pike County, Pennsylvania     4.5           13  American
# 2129           Pike County, Pennsylvania     3.0            7   Chinese
# 2130           Pike County, Pennsylvania     2.0           17  American
# 2131           Pike County, Pennsylvania     2.0           13   Chinese
# 2132           Pike County, Pennsylvania     3.0            2   Chinese
#
#       price  region
# 0         2  region
# 1         2  region
# 2         1  region
# 3         1  region
# 4         1  region
# 5         2  region
# 6         1  region
# 7         3  region
# 9         2  region
# 10        2  region
# 11        2  region
# 12        2  region
# 13        1  region
# 14        2  region
# 15        2  region
# 16        2  region
# 17        1  region
# 18        2  region
# 19        2  region
# 20        1  region
# 21        2  region
# 22        2  region
# 23        2  region
# 24        2  region
# 25        1  region
# 26        2  region
# 27        1  region
# 28        2  region
# 29        3  region
# 30        1  region
# ...     ...     ...
# 2102      2  region
# 2103      1  region
# 2104      2  region
# 2105      1  region
# 2106      2  region
# 2107      2  region
# 2108      2  region
# 2109      2  region
# 2110      1  region
# 2111      1  region
# 2112      3  region
# 2113      2  region
# 2114      1  region
# 2115      1  region
# 2116      2  region
# 2117      1  region
# 2118      1  region
# 2119      1  region
# 2120      3  region
# 2121      2  region
# 2122      1  region
# 2123      2  region
# 2124      2  region
# 2125      2  region
# 2127      2  region
# 2128      2  region
# 2129      2  region
# 2130      2  region
# 2131      1  region
# 2132      1  region
#
# [2081 rows x 8 columns]

# %% [markdown]
# <h3>Part 1: ???</h3>

# %%
res_df.groupby("category").mean().plot(kind="bar",figsize=(16,9))
plt.xlabel("Category")
plt.ylabel("Ratings / Price")
plt.title("Comparing Price and Ratings Per Restaurant Type")
plt.savefig("Comparing_price_and_ratingcourt.png")
plt.show()

# %% [markdown]
# <h3>Part 1: Merging Data</h3>
#
# Since a large part of our project revolved around correlationg geograpic location and Yelp restaurant data, we needed to merge all the necessary information into one larger dataframe. Thus, we merged res_df with our counties data on the county_string column. This allowed us to pull in and use all the data from both sources.
#
# Up until this point, if you noticed above, we had not inserted our regions, only created a placeholder column. In merging the two datasets, we were also able to populate our region column accordingly.
#
# We then printed res_df as a check to verify contents.

# %%
res_df= pd.merge(res_df,counties,how="left",on="county_string")
res_df.head()
# Out:
#                        name zipcode                       county_string  \
# 0            Cabo Fish Taco   28205  Mecklenburg County, North Carolina
# 1        Midwood Smokehouse   28205  Mecklenburg County, North Carolina
# 2  Sabor Latin Street Grill   28204  Mecklenburg County, North Carolina
# 3          Benny Pennello's   28205  Mecklenburg County, North Carolina
# 4               JackBeagles   28205  Mecklenburg County, North Carolina
#
#    rating review_count  category  price  region  CensusId           State  \
# 0     4.0          990   Mexican      2  region     37119  North Carolina
# 1     4.5         1281  American      2  region     37119  North Carolina
# 2     4.5          682   Mexican      1  region     37119  North Carolina
# 3     4.0          234   Italian      1  region     37119  North Carolina
# 4     4.0          292  American      1  region     37119  North Carolina
#
#     ...   OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0   ...           1.3         6.1         25.3    502455         86.0
# 1   ...           1.3         6.1         25.3    502455         86.0
# 2   ...           1.3         6.1         25.3    502455         86.0
# 3   ...           1.3         6.1         25.3    502455         86.0
# 4   ...           1.3         6.1         25.3    502455         86.0
#
#    PublicWork  SelfEmployed  FamilyWork  Unemployment  Region
# 0         9.1           4.8         0.1           8.9      SE
# 1         9.1           4.8         0.1           8.9      SE
# 2         9.1           4.8         0.1           8.9      SE
# 3         9.1           4.8         0.1           8.9      SE
# 4         9.1           4.8         0.1           8.9      SE
#
# [5 rows x 46 columns]

# %% [markdown]
# <h3>IDK - KYRUS can fill this part in. </h3>
# <h3>Part 2: Examining category distribution across the US </h3>

# %%
itadf = res_df.groupby(res_df["category"]).get_group("Italian")
mexdf = res_df.groupby(res_df["category"]).get_group("Mexican")
chndf = res_df.groupby(res_df["category"]).get_group("Chinese")
usadf = res_df.groupby(res_df["category"]).get_group("American")
inddf = res_df.groupby(res_df["category"]).get_group("Indian")
res_df
# CHA = res_df.groupby(res_df["county_string"]).get_group("Mecklenburg County, North Carolina")
# CHAbreakdown = pd.DataFrame(CHA["category"].value_counts()).T.reset_index()
# CHAbreakdown["county_string"]="Mecklenburg County, North Carolina"
# CHA_price_avg = CHA.groupby(res_df["price"]).mean()
# CHA_price_count = CHA["price"].value_counts()

# RAL = res_df.groupby(res_df["county_string"]).get_group("Wake County, North Carolina")
# RALbreakdown = pd.DataFrame(RAL["category"].value_counts()).T.reset_index()
# RALbreakdown["county_string"]="Wake County, North Carolina"
# RAL_price_avg = RAL.groupby(res_df["price"]).mean()
# RAL_price_count = RAL["price"].value_counts()

# ATL = res_df.groupby(res_df["county_string"]).get_group("Fulton County, Georgia")
# ATLbreakdown = pd.DataFrame(ATL["category"].value_counts()).T.reset_index()
# ATLbreakdown["county_string"]="Fulton County, Georgia"
# ATL_price_avg = ATL.groupby(res_df["price"]).mean()
# ATL_price_count = ATL["price"].value_counts()

# MEM = res_df.groupby(res_df["county_string"]).get_group("Shelby County, Tennessee")
# MEMbreakdown = pd.DataFrame(MEM["category"].value_counts()).T.reset_index()
# MEMbreakdown["county_string"]="Shelby County, Tennessee"
# MEM_price_avg = MEM.groupby(res_df["price"]).mean()
# MEM_price_count = MEM["price"].value_counts()


# ORL = res_df.groupby(res_df["county_string"]).get_group("Orange County, Florida")
# ORLbreakdown = pd.DataFrame(ORL["category"].value_counts()).T.reset_index()
# ORLbreakdown["county_string"]="Orange County, Florida"
# ORL_price_avg = ORL.groupby(res_df["price"]).mean()
# ORL_price_count = ORL["price"].value_counts()

# MIL = res_df.groupby(res_df["county_string"]).get_group("Milwaukee County, Wisconsin")
# MILbreakdown = pd.DataFrame(MIL["category"].value_counts()).T.reset_index()
# MILbreakdown["county_string"]="Milwaukee County, Wisconsin"
# MIL_price_avg = MIL.groupby(res_df["price"]).mean()
# MIL_price_count = MIL["price"].value_counts()

# SFC = res_df.groupby(res_df["county_string"]).get_group("San Francisco County, California")
# SFCbreakdown = pd.DataFrame(SFC["category"].value_counts()).T.reset_index()
# SFCbreakdown["county_string"]="San Francisco County, California"
# SFC_price_avg = SFC.groupby(res_df["price"]).mean()
# SFC_price_count = SFC["price"].value_counts()

# AUS = res_df.groupby(res_df["county_string"]).get_group("Travis County, Texas")
# AUSbreakdown = pd.DataFrame(AUS["category"].value_counts()).T.reset_index()
# AUSbreakdown["county_string"]="Travis County, Texas"
# AUS_price_avg = AUS.groupby(res_df["price"]).mean()
# AUS_price_count = AUS["price"].value_counts()

# PIT = res_df.groupby(res_df["county_string"]).get_group("Allegheny County, Pennsylvania")
# PITbreakdown = pd.DataFrame(PIT["category"].value_counts()).T.reset_index()
# PITbreakdown["county_string"]="Allegheny County, Pennsylvania"
# PIT_price_avg = PIT.groupby(res_df["price"]).mean()
# PIT_price_count = PIT["price"].value_counts()
# Out:
#                                              name zipcode  \
# 0                                  Cabo Fish Taco   28205
# 1                              Midwood Smokehouse   28205
# 2                        Sabor Latin Street Grill   28204
# 3                                Benny Pennello's   28205
# 4                                     JackBeagles   28205
# 5                       The Cellar At Duckworth's   28202
# 6                          Pinky's Westside Grill   28208
# 7                         The Fig Tree Restaurant   28204
# 8                       VBGB Beer Hall and Garden   28206
# 9                                Dandelion Market   28202
# 10                             Growlers Pourhouse   28205
# 11                            Alexander Michael's   28202
# 12                Sabor Latin Street Grill - Noda   28205
# 13                                   Tupelo Honey   28203
# 14                             The King's Kitchen   28202
# 15                   Davidson Street Public House   28205
# 16    Three Amigos Mexican Restaurant and Cantina   28205
# 17                                       300 East   28203
# 18                               Rooster's Uptown   28202
# 19                                    Las Lupitas   28213
# 20                                        5Church   28202
# 21                          Good Food on Montford   28209
# 22                                   Mimosa Grill   28202
# 23                                     The Asbury   28202
# 24                                 Midnight Diner   28202
# 25                                 Mama Ricotta's   28204
# 26                                     Papi Queso   28202
# 27                  Lebowski's Neighborhood Grill   28203
# 28               Carpe Diem Restaurant & Caterers   28204
# 29                       JJ's Red Hots - Dilworth   28203
# ...                                           ...     ...
# 2051                                    Pizza Hut   19901
# 2052                                Panda Express   19901
# 2053                       Chovy's Italian Casual   16335
# 2054                          Market House Grille   16335
# 2055                         Julian's Bar & Grill   16335
# 2056                     Timber Creek Tap & Table   16335
# 2057                       Mannino Italian Garden   16335
# 2058             Cracker Barrel Old Country Store   16335
# 2059                           Valenza Restaurant   16335
# 2060                           Super China Buffet   16335
# 2061                       Firehouse Tap & Grille   16335
# 2062                                 Hunter's Inn   16335
# 2063                      Chestnut St Pub & Grill   16335
# 2064                                 Dave's Place   16360
# 2065                       Applebee's Grill + Bar   16335
# 2066                                    Pizza Hut   16335
# 2067                                Deer Head Inn   16335
# 2068                  New Imperial Chinese Buffet   16335
# 2069                                  Red Lobster   16335
# 2070                  Perkins Restaurant & Bakery   16335
# 2071                                    Taco Bell   16335
# 2072                         Peter's Europa House   18458
# 2073                       Carini Pizza and Pasta   18428
# 2074                                     Pie's On   18328
# 2075                           The White Pine Inn   18435
# 2076                           Chris & Ginas Café   18328
# 2077                                 Panda Garden   18428
# 2078                                 The 402 Cafe   18428
# 2079                                China Delight   18328
# 2080                     China Dynasty Restaurant   18428
#
#                            county_string  rating review_count  category  \
# 0     Mecklenburg County, North Carolina     4.0          990   Mexican
# 1     Mecklenburg County, North Carolina     4.5         1281  American
# 2     Mecklenburg County, North Carolina     4.5          682   Mexican
# 3     Mecklenburg County, North Carolina     4.0          234   Italian
# 4     Mecklenburg County, North Carolina     4.0          292  American
# 5     Mecklenburg County, North Carolina     4.5          361  American
# 6     Mecklenburg County, North Carolina     4.0          856  American
# 7     Mecklenburg County, North Carolina     4.5          343  American
# 8     Mecklenburg County, North Carolina     4.5          326  American
# 9     Mecklenburg County, North Carolina     4.0          553  American
# 10    Mecklenburg County, North Carolina     4.0          201  American
# 11    Mecklenburg County, North Carolina     4.5          331  American
# 12    Mecklenburg County, North Carolina     4.5          155   Mexican
# 13    Mecklenburg County, North Carolina     4.0         1180  American
# 14    Mecklenburg County, North Carolina     4.0          484  American
# 15    Mecklenburg County, North Carolina     4.0          136  American
# 16    Mecklenburg County, North Carolina     4.0          375   Mexican
# 17    Mecklenburg County, North Carolina     4.0          582  American
# 18    Mecklenburg County, North Carolina     4.0          402  American
# 19    Mecklenburg County, North Carolina     4.5           49   Mexican
# 20    Mecklenburg County, North Carolina     3.5          575  American
# 21    Mecklenburg County, North Carolina     4.5          582  American
# 22    Mecklenburg County, North Carolina     4.0          426  American
# 23    Mecklenburg County, North Carolina     4.0          205  American
# 24    Mecklenburg County, North Carolina     4.0          612  American
# 25    Mecklenburg County, North Carolina     4.0          415   Italian
# 26    Mecklenburg County, North Carolina     4.5          127  American
# 27    Mecklenburg County, North Carolina     4.5          335  American
# 28    Mecklenburg County, North Carolina     4.0          174  American
# 29    Mecklenburg County, North Carolina     4.0          349  American
# ...                                  ...     ...          ...       ...
# 2051               Kent County, Delaware     2.0           12   Italian
# 2052               Kent County, Delaware     2.0            9   Chinese
# 2053       Crawford County, Pennsylvania     3.5           57   Italian
# 2054       Crawford County, Pennsylvania     4.0           23  American
# 2055       Crawford County, Pennsylvania     4.0           21  American
# 2056       Crawford County, Pennsylvania     3.5           89  American
# 2057       Crawford County, Pennsylvania     4.5           11   Italian
# 2058       Crawford County, Pennsylvania     3.0           23  American
# 2059       Crawford County, Pennsylvania     4.0           11   Italian
# 2060       Crawford County, Pennsylvania     3.5            7   Chinese
# 2061       Crawford County, Pennsylvania     4.0            8  American
# 2062       Crawford County, Pennsylvania     5.0            8  American
# 2063       Crawford County, Pennsylvania     4.5            3  American
# 2064       Crawford County, Pennsylvania     4.5            4  American
# 2065       Crawford County, Pennsylvania     3.0            9  American
# 2066       Crawford County, Pennsylvania     2.5            3   Italian
# 2067       Crawford County, Pennsylvania     3.0            3  American
# 2068       Crawford County, Pennsylvania     2.0            5   Chinese
# 2069       Crawford County, Pennsylvania     3.5            5  American
# 2070       Crawford County, Pennsylvania     3.0            5  American
# 2071       Crawford County, Pennsylvania     5.0            1   Mexican
# 2072           Pike County, Pennsylvania     4.5           53   Italian
# 2073           Pike County, Pennsylvania     3.5           24   Italian
# 2074           Pike County, Pennsylvania     3.0           30  American
# 2075           Pike County, Pennsylvania     4.0           12  American
# 2076           Pike County, Pennsylvania     4.5           13  American
# 2077           Pike County, Pennsylvania     3.0            7   Chinese
# 2078           Pike County, Pennsylvania     2.0           17  American
# 2079           Pike County, Pennsylvania     2.0           13   Chinese
# 2080           Pike County, Pennsylvania     3.0            2   Chinese
#
#       price  region  CensusId           State   ...   OtherTransp  WorkAtHome  \
# 0         2  region     37119  North Carolina   ...           1.3         6.1
# 1         2  region     37119  North Carolina   ...           1.3         6.1
# 2         1  region     37119  North Carolina   ...           1.3         6.1
# 3         1  region     37119  North Carolina   ...           1.3         6.1
# 4         1  region     37119  North Carolina   ...           1.3         6.1
# 5         2  region     37119  North Carolina   ...           1.3         6.1
# 6         1  region     37119  North Carolina   ...           1.3         6.1
# 7         3  region     37119  North Carolina   ...           1.3         6.1
# 8         2  region     37119  North Carolina   ...           1.3         6.1
# 9         2  region     37119  North Carolina   ...           1.3         6.1
# 10        2  region     37119  North Carolina   ...           1.3         6.1
# 11        2  region     37119  North Carolina   ...           1.3         6.1
# 12        1  region     37119  North Carolina   ...           1.3         6.1
# 13        2  region     37119  North Carolina   ...           1.3         6.1
# 14        2  region     37119  North Carolina   ...           1.3         6.1
# 15        2  region     37119  North Carolina   ...           1.3         6.1
# 16        1  region     37119  North Carolina   ...           1.3         6.1
# 17        2  region     37119  North Carolina   ...           1.3         6.1
# 18        2  region     37119  North Carolina   ...           1.3         6.1
# 19        1  region     37119  North Carolina   ...           1.3         6.1
# 20        2  region     37119  North Carolina   ...           1.3         6.1
# 21        2  region     37119  North Carolina   ...           1.3         6.1
# 22        2  region     37119  North Carolina   ...           1.3         6.1
# 23        2  region     37119  North Carolina   ...           1.3         6.1
# 24        1  region     37119  North Carolina   ...           1.3         6.1
# 25        2  region     37119  North Carolina   ...           1.3         6.1
# 26        1  region     37119  North Carolina   ...           1.3         6.1
# 27        2  region     37119  North Carolina   ...           1.3         6.1
# 28        3  region     37119  North Carolina   ...           1.3         6.1
# 29        1  region     37119  North Carolina   ...           1.3         6.1
# ...     ...     ...       ...             ...   ...           ...         ...
# 2051      2  region     10001        Delaware   ...           1.0         3.6
# 2052      1  region     10001        Delaware   ...           1.0         3.6
# 2053      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2054      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2055      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2056      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2057      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2058      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2059      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2060      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2061      3  region     42039    Pennsylvania   ...           1.4         4.5
# 2062      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2063      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2064      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2065      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2066      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2067      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2068      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2069      3  region     42039    Pennsylvania   ...           1.4         4.5
# 2070      2  region     42039    Pennsylvania   ...           1.4         4.5
# 2071      1  region     42039    Pennsylvania   ...           1.4         4.5
# 2072      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2073      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2074      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2075      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2076      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2077      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2078      2  region     42103    Pennsylvania   ...           0.7         4.2
# 2079      1  region     42103    Pennsylvania   ...           0.7         4.2
# 2080      1  region     42103    Pennsylvania   ...           0.7         4.2
#
#       MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0            25.3    502455         86.0         9.1           4.8
# 1            25.3    502455         86.0         9.1           4.8
# 2            25.3    502455         86.0         9.1           4.8
# 3            25.3    502455         86.0         9.1           4.8
# 4            25.3    502455         86.0         9.1           4.8
# 5            25.3    502455         86.0         9.1           4.8
# 6            25.3    502455         86.0         9.1           4.8
# 7            25.3    502455         86.0         9.1           4.8
# 8            25.3    502455         86.0         9.1           4.8
# 9            25.3    502455         86.0         9.1           4.8
# 10           25.3    502455         86.0         9.1           4.8
# 11           25.3    502455         86.0         9.1           4.8
# 12           25.3    502455         86.0         9.1           4.8
# 13           25.3    502455         86.0         9.1           4.8
# 14           25.3    502455         86.0         9.1           4.8
# 15           25.3    502455         86.0         9.1           4.8
# 16           25.3    502455         86.0         9.1           4.8
# 17           25.3    502455         86.0         9.1           4.8
# 18           25.3    502455         86.0         9.1           4.8
# 19           25.3    502455         86.0         9.1           4.8
# 20           25.3    502455         86.0         9.1           4.8
# 21           25.3    502455         86.0         9.1           4.8
# 22           25.3    502455         86.0         9.1           4.8
# 23           25.3    502455         86.0         9.1           4.8
# 24           25.3    502455         86.0         9.1           4.8
# 25           25.3    502455         86.0         9.1           4.8
# 26           25.3    502455         86.0         9.1           4.8
# 27           25.3    502455         86.0         9.1           4.8
# 28           25.3    502455         86.0         9.1           4.8
# 29           25.3    502455         86.0         9.1           4.8
# ...           ...       ...          ...         ...           ...
# 2051         26.1     75246         73.4        22.4           3.9
# 2052         26.1     75246         73.4        22.4           3.9
# 2053         21.7     37783         80.0        11.2           8.5
# 2054         21.7     37783         80.0        11.2           8.5
# 2055         21.7     37783         80.0        11.2           8.5
# 2056         21.7     37783         80.0        11.2           8.5
# 2057         21.7     37783         80.0        11.2           8.5
# 2058         21.7     37783         80.0        11.2           8.5
# 2059         21.7     37783         80.0        11.2           8.5
# 2060         21.7     37783         80.0        11.2           8.5
# 2061         21.7     37783         80.0        11.2           8.5
# 2062         21.7     37783         80.0        11.2           8.5
# 2063         21.7     37783         80.0        11.2           8.5
# 2064         21.7     37783         80.0        11.2           8.5
# 2065         21.7     37783         80.0        11.2           8.5
# 2066         21.7     37783         80.0        11.2           8.5
# 2067         21.7     37783         80.0        11.2           8.5
# 2068         21.7     37783         80.0        11.2           8.5
# 2069         21.7     37783         80.0        11.2           8.5
# 2070         21.7     37783         80.0        11.2           8.5
# 2071         21.7     37783         80.0        11.2           8.5
# 2072         44.0     24320         78.1        13.6           8.0
# 2073         44.0     24320         78.1        13.6           8.0
# 2074         44.0     24320         78.1        13.6           8.0
# 2075         44.0     24320         78.1        13.6           8.0
# 2076         44.0     24320         78.1        13.6           8.0
# 2077         44.0     24320         78.1        13.6           8.0
# 2078         44.0     24320         78.1        13.6           8.0
# 2079         44.0     24320         78.1        13.6           8.0
# 2080         44.0     24320         78.1        13.6           8.0
#
#       FamilyWork  Unemployment  Region
# 0            0.1           8.9      SE
# 1            0.1           8.9      SE
# 2            0.1           8.9      SE
# 3            0.1           8.9      SE
# 4            0.1           8.9      SE
# 5            0.1           8.9      SE
# 6            0.1           8.9      SE
# 7            0.1           8.9      SE
# 8            0.1           8.9      SE
# 9            0.1           8.9      SE
# 10           0.1           8.9      SE
# 11           0.1           8.9      SE
# 12           0.1           8.9      SE
# 13           0.1           8.9      SE
# 14           0.1           8.9      SE
# 15           0.1           8.9      SE
# 16           0.1           8.9      SE
# 17           0.1           8.9      SE
# 18           0.1           8.9      SE
# 19           0.1           8.9      SE
# 20           0.1           8.9      SE
# 21           0.1           8.9      SE
# 22           0.1           8.9      SE
# 23           0.1           8.9      SE
# 24           0.1           8.9      SE
# 25           0.1           8.9      SE
# 26           0.1           8.9      SE
# 27           0.1           8.9      SE
# 28           0.1           8.9      SE
# 29           0.1           8.9      SE
# ...          ...           ...     ...
# 2051         0.3           8.4      NE
# 2052         0.3           8.4      NE
# 2053         0.3           7.2      NE
# 2054         0.3           7.2      NE
# 2055         0.3           7.2      NE
# 2056         0.3           7.2      NE
# 2057         0.3           7.2      NE
# 2058         0.3           7.2      NE
# 2059         0.3           7.2      NE
# 2060         0.3           7.2      NE
# 2061         0.3           7.2      NE
# 2062         0.3           7.2      NE
# 2063         0.3           7.2      NE
# 2064         0.3           7.2      NE
# 2065         0.3           7.2      NE
# 2066         0.3           7.2      NE
# 2067         0.3           7.2      NE
# 2068         0.3           7.2      NE
# 2069         0.3           7.2      NE
# 2070         0.3           7.2      NE
# 2071         0.3           7.2      NE
# 2072         0.3          11.6      NE
# 2073         0.3          11.6      NE
# 2074         0.3          11.6      NE
# 2075         0.3          11.6      NE
# 2076         0.3          11.6      NE
# 2077         0.3          11.6      NE
# 2078         0.3          11.6      NE
# 2079         0.3          11.6      NE
# 2080         0.3          11.6      NE
#
# [2081 rows x 46 columns]

# %% [markdown]
# <h3>IDK - KYRUS can fill this part in. </h3>
# <h3>Part 2: Examining category distribution across the US </h3>

# %%
TOTAL_price_avg = res_df.groupby(["price"]).mean()
rescount = res_df.groupby(["county_string"]).count()["name"].reset_index()
rescount.columns=['county_string', 'restaurant_count']
TOTAL_county_reviews = res_df.groupby(["county_string"]).review_count.sum().reset_index()
TOTAL_county_reviews.columns=["county_string","review_count"]
TOTAL_county_avg = res_df.groupby(res_df["county_string"]).mean().reset_index()

county_stats = TOTAL_county_avg.merge(TOTAL_county_reviews, on="county_string")
csdf = county_stats.merge(counties, on="county_string")
c_df = rescount.merge(csdf, on="county_string")
c_df
# Out:
#                          county_string  restaurant_count    rating     price  \
# 0               Barry County, Missouri                 4  3.750000  1.250000
# 1                    Bee County, Texas                10  3.200000  1.600000
# 2               Boone County, Missouri               123  3.418699  1.601626
# 3      Buncombe County, North Carolina               201  3.753731  1.691542
# 4               Citrus County, Florida                51  3.647059  1.549020
# 5             Clackamas County, Oregon                31  4.064516  1.645161
# 6            Columbia County, New York                21  3.452381  1.666667
# 7        Crawford County, Pennsylvania                19  3.684211  1.631579
# 8           Crockett County, Tennessee                 1  3.000000  2.000000
# 9     East Feliciana County, Louisiana                 3  3.833333  1.333333
# 10               Erie County, New York               109  3.532110  1.715596
# 11              Essex County, New York                 3  3.333333  1.666667
# 12            Franklin County, Florida                 3  3.500000  1.333333
# 13                 Gallia County, Ohio                 3  3.666667  1.333333
# 14              Geneva County, Alabama                 1  2.500000  2.000000
# 15             Graves County, Kentucky                10  3.650000  1.500000
# 16             Hamilton County, Kansas                 2  4.500000  1.000000
# 17              Hamilton County, Texas                 6  4.333333  1.000000
# 18             Henderson County, Texas                26  3.596154  1.538462
# 19        Jefferson County, Washington                 2  4.250000  2.000000
# 20               Kent County, Delaware                67  3.283582  1.686567
# 21           Kitsap County, Washington                78  3.455128  1.705128
# 22                 Linn County, Oregon                39  3.833333  1.641026
# 23  Mecklenburg County, North Carolina               334  3.591317  1.658683
# 24           Montgomery County, Kansas                 5  3.900000  1.800000
# 25          Moody County, South Dakota                 1  3.000000  1.000000
# 26               Morrow County, Oregon                 6  3.583333  1.333333
# 27              Osage County, Oklahoma                 4  4.000000  1.500000
# 28     Pend Oreille County, Washington                 9  3.944444  1.555556
# 29           Pike County, Pennsylvania                 9  3.277778  1.777778
# 30     Providence County, Rhode Island               238  3.766807  1.663866
# 31             Pueblo County, Colorado                 3  2.833333  1.333333
# 32               Randall County, Texas                 9  3.222222  1.333333
# 33              Rice County, Minnesota                25  3.880000  1.520000
# 34               Runnels County, Texas                 6  4.083333  1.333333
# 35       San Benito County, California                32  3.843750  1.656250
# 36       Santa Cruz County, California               184  3.529891  1.706522
# 37               Scott County, Indiana                10  3.150000  1.400000
# 38              Shoshone County, Idaho                20  4.050000  1.750000
# 39     Strafford County, New Hampshire                30  3.233333  1.633333
# 40                 Summit County, Ohio               224  3.448661  1.584821
# 41             Sussex County, Delaware                17  3.852941  1.529412
# 42              Texas County, Oklahoma                10  3.500000  1.500000
# 43            Warren County, Tennessee                14  3.285714  1.357143
# 44                Wasco County, Oregon                 3  4.166667  2.000000
# 45   Westmoreland County, Pennsylvania                66  3.681818  1.848485
# 46                  Wood County, Texas                 3  4.166667  1.333333
# 47           Yazoo County, Mississippi                 6  3.750000  1.500000
#
#     CensusId_x  TotalPop_x     Men_x   Women_x  Hispanic_x  White_x   ...    \
# 0      29009.0     35726.0   17905.0   17821.0         8.5     87.2   ...
# 1      48025.0     32659.0   19722.0   12937.0        57.3     33.1   ...
# 2      29019.0    170770.0   82533.0   88237.0         3.2     80.0   ...
# 3      37021.0    247336.0  118950.0  128386.0         6.4     83.8   ...
# 4      12017.0    139654.0   67381.0   72273.0         5.1     88.9   ...
# 5      41005.0    389438.0  191639.0  197799.0         8.2     83.4   ...
# 6      36021.0     62195.0   31244.0   30951.0         4.3     87.5   ...
# 7      42039.0     87343.0   42688.0   44655.0         1.2     95.2   ...
# 8      47033.0     14600.0    6906.0    7694.0         9.5     75.7   ...
# 9      22037.0     19855.0   10666.0    9189.0         1.3     52.8   ...
# 10     36029.0    921584.0  445761.0  475823.0         5.0     76.6   ...
# 11     36031.0     38912.0   20283.0   18629.0         3.0     92.2   ...
# 12     12037.0     11628.0    6800.0    4828.0         5.0     78.6   ...
# 13     39053.0     30565.0   14900.0   15665.0         1.2     93.7   ...
# 14      1061.0     26815.0   13174.0   13641.0         3.6     84.0   ...
# 15     21083.0     37502.0   18263.0   19239.0         5.9     87.2   ...
# 16     20075.0      2586.0    1342.0    1244.0        33.7     64.7   ...
# 17     48193.0      8266.0    4040.0    4226.0        11.2     86.4   ...
# 18     48213.0     79016.0   38598.0   40418.0        11.7     79.5   ...
# 19     53031.0     30083.0   14850.0   15233.0         3.4     88.7   ...
# 20     10001.0    169509.0   81716.0   87793.0         6.5     63.7   ...
# 21     53035.0    255441.0  130126.0  125315.0         7.1     77.7   ...
# 22     41043.0    118971.0   58803.0   60168.0         8.3     86.4   ...
# 23     37119.0    990288.0  476765.0  513523.0        12.5     49.1   ...
# 24     20125.0     34184.0   16851.0   17333.0         6.0     80.4   ...
# 25     46101.0      6439.0    3227.0    3212.0         3.0     79.1   ...
# 26     41049.0     11204.0    5800.0    5404.0        34.0     62.0   ...
# 27     40113.0     48054.0   24068.0   23986.0         3.2     64.3   ...
# 28     53051.0     12968.0    6665.0    6303.0         3.5     89.2   ...
# 29     42103.0     56632.0   28249.0   28383.0         9.9     81.8   ...
# 30     44007.0    630459.0  305247.0  325212.0        20.3     64.0   ...
# 31      8101.0    161519.0   79535.0   81984.0        42.3     53.0   ...
# 32     48381.0    126782.0   62256.0   64526.0        18.8     75.0   ...
# 33     27131.0     64886.0   33038.0   31848.0         7.8     84.4   ...
# 34     48399.0     10445.0    5181.0    5264.0        33.6     62.8   ...
# 35      6069.0     57557.0   28773.0   28784.0        57.9     36.6   ...
# 36      6087.0    269278.0  133714.0  135564.0        32.9     58.3   ...
# 37     18143.0     23783.0   11685.0   12098.0         1.7     96.4   ...
# 38     16079.0     12571.0    6324.0    6247.0         3.3     92.4   ...
# 39     33017.0    125273.0   61104.0   64169.0         2.1     91.9   ...
# 40     39153.0    541847.0  262467.0  279380.0         1.8     78.6   ...
# 41     10005.0    207302.0  100782.0  106520.0         9.2     74.8   ...
# 42     40139.0     21588.0   11340.0   10248.0        45.2     47.7   ...
# 43     47177.0     40015.0   19801.0   20214.0         8.4     86.5   ...
# 44     41065.0     25492.0   12634.0   12858.0        16.5     76.1   ...
# 45     42129.0    361251.0  176227.0  185024.0         1.0     94.3   ...
# 46     48499.0     42712.0   21159.0   21553.0         9.4     83.7   ...
# 47     28163.0     27911.0   15460.0   12451.0         4.8     36.5   ...
#
#     OtherTransp_y  WorkAtHome_y  MeanCommute_y  Employed_y  PrivateWork_y  \
# 0             1.0           4.2           22.5       14259           78.2
# 1             1.5           1.9           23.0       10451           70.5
# 2             2.0           3.9           18.1       90949           71.4
# 3             1.0           7.1           20.3      117252           79.0
# 4             2.5           5.6           24.9       43486           78.2
# 5             1.5           7.2           27.7      185660           80.9
# 6             0.7           6.7           26.0       29962           71.0
# 7             1.4           4.5           21.7       37783           80.0
# 8             0.5           3.7           23.4        5766           77.7
# 9             0.6           2.7           33.0        7165           68.3
# 10            1.3           2.6           21.2      441369           79.2
# 11            3.7           5.3           20.8       17769           70.2
# 12            3.2           5.4           20.3        4331           58.9
# 13            1.1           3.0           26.8       11344           81.3
# 14            1.8           3.4           25.8       10419           75.7
# 15            1.5           4.9           23.2       15840           77.0
# 16            0.0           8.3           12.5        1322           64.8
# 17            0.5           3.6           21.0        3279           72.9
# 18            0.7           3.8           28.5       30441           75.6
# 19            2.6           8.7           22.6       11518           66.9
# 20            1.0           3.6           26.1       75246           73.4
# 21            2.3           6.9           29.9      107745           65.3
# 22            2.0           5.8           22.8       48892           77.7
# 23            1.3           6.1           25.3      502455           86.0
# 24            1.7           1.8           16.8       14514           77.9
# 25            2.5           7.9           19.2        3379           66.0
# 26            1.0           6.7           18.6        4827           77.3
# 27            1.0           2.2           24.7       19274           77.0
# 28            1.4           7.8           30.7        4217           62.5
# 29            0.7           4.2           44.0       24320           78.1
# 30            1.9           3.0           23.9      301318           84.6
# 31            1.2           3.0           21.1       65300           76.6
# 32            0.7           2.7           19.1       65270           75.4
# 33            2.1          13.2           22.7       33503           82.4
# 34            0.4           4.3           18.1        4292           67.7
# 35            1.5           3.5           31.8       26261           76.4
# 36            6.6           7.3           25.9      131321           73.1
# 37            1.7           2.5           24.9        9803           84.6
# 38            1.9           5.7           18.4        4992           76.9
# 39            1.4           4.3           26.8       66369           79.0
# 40            0.5           2.9           22.9      258416           84.2
# 41            1.6           4.9           25.0       90239           78.8
# 42            1.0           1.6           17.5       11144           78.7
# 43            1.1           3.3           24.0       16304           77.3
# 44            1.6           7.5           16.0       10907           74.8
# 45            0.7           3.6           26.7      173533           85.4
# 46            1.1           6.1           29.0       15868           75.0
# 47            0.5           3.0           28.0        8382           70.4
#
#     PublicWork_y  SelfEmployed_y  FamilyWork_y  Unemployment_y  Region
# 0           11.6            10.2           0.0            11.4      MW
# 1           22.7             6.7           0.2             7.0      SW
# 2           24.0             4.4           0.1             5.0      MW
# 3           12.4             8.4           0.3             7.0      SE
# 4           14.4             6.9           0.5            13.1      SE
# 5           11.1             7.8           0.2             8.3      WC
# 6           19.8             8.9           0.3             6.7      NE
# 7           11.2             8.5           0.3             7.2      NE
# 8           14.3             7.9           0.1             7.4      SE
# 9           26.1             5.6           0.0             6.5      SE
# 10          16.8             4.0           0.1             7.0      NE
# 11          20.4             9.2           0.3             7.9      NE
# 12          26.1            14.9           0.1             9.4      SE
# 13          13.1             5.5           0.2             7.5      MW
# 14          15.0             8.8           0.4            11.2      SE
# 15          14.3             8.6           0.0             7.2      MW
# 16          16.6            17.9           0.7             2.3      MW
# 17          17.8             7.5           1.9             5.9      SW
# 18          13.9            10.4           0.1             7.8      SW
# 19          18.2            14.8           0.1             9.5      WC
# 20          22.4             3.9           0.3             8.4      NE
# 21          27.6             7.0           0.1             8.0      WC
# 22          15.5             6.6           0.1            10.6      WC
# 23           9.1             4.8           0.1             8.9      SE
# 24          15.0             6.8           0.3             8.7      MW
# 25          18.6            14.8           0.5             6.1      MW
# 26          15.5             7.2           0.0             8.6      WC
# 27          17.1             5.9           0.0             7.1      SW
# 28          26.5            10.4           0.7            10.3      WC
# 29          13.6             8.0           0.3            11.6      NE
# 30          11.3             4.1           0.1             9.5      NE
# 31          18.7             4.5           0.2            10.8      SW
# 32          17.5             7.1           0.1             3.9      SW
# 33          10.8             6.5           0.3             5.6      MW
# 34          19.9            12.1           0.4             3.4      SW
# 35          16.3             7.1           0.3            12.2      WC
# 36          15.3            11.4           0.2             7.6      WC
# 37          11.7             3.4           0.3            11.0      MW
# 38          15.8             6.8           0.4            11.8      WC
# 39          15.6             5.3           0.0             6.5      NE
# 40          11.2             4.5           0.1             8.4      MW
# 41          14.7             6.4           0.1             8.0      NE
# 42          15.5             5.4           0.3             3.5      SW
# 43          14.1             8.1           0.5             8.0      SE
# 44          16.8             8.3           0.1             9.0      WC
# 45           9.3             5.2           0.1             5.6      NE
# 46          15.6             9.0           0.4             8.9      SW
# 47          21.1             8.1           0.3            19.8      SE
#
# [48 rows x 78 columns]

# %%
current_county="Mecklenburg County, North Carolina"
WCO = res_df.groupby(res_df["county_string"]).get_group(current_county)
WCObreakdown = pd.DataFrame(WCO["category"].value_counts()).T.reset_index()
WCOrate = pd.DataFrame(WCO["rating"].value_counts()).T.reset_index()
WCObreakdown["county_string"]=current_county
WCO_price_avg = WCO.groupby(res_df["price"]).mean()
WCO_price_count = WCO["price"].value_counts()
WCObreakdown
# Out:
#       index  American  Mexican  Italian  Chinese  Indian  \
# 0  category       176       70       42       33      13
#
#                         county_string
# 0  Mecklenburg County, North Carolina

# %%
comp_df = pd.DataFrame(columns=["Italian","Mexican","Chinese","American", "Indian","county_string"])
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.reset_index()
del comp_df["index"]
del comp_df["level_0"]
#comp_df["Totals"]=comp_df["Italian"]+comp_df["Mexican"]+comp_df["Chinese"]+comp_df["Indian"]+comp_df["American"]
comp_df
# Out:
#   American Chinese Indian Italian Mexican                       county_string
# 0      176      33     13      42      70  Mecklenburg County, North Carolina
# 1      176      33     13      42      70  Mecklenburg County, North Carolina
# 2      176      33     13      42      70  Mecklenburg County, North Carolina
# 3      176      33     13      42      70  Mecklenburg County, North Carolina
# 4      176      33     13      42      70  Mecklenburg County, North Carolina
# 5      176      33     13      42      70  Mecklenburg County, North Carolina
# 6      176      33     13      42      70  Mecklenburg County, North Carolina
# 7      176      33     13      42      70  Mecklenburg County, North Carolina
# 8      176      33     13      42      70  Mecklenburg County, North Carolina

# %% [markdown]
# <h3>Part 2: Examining category distribution across the US </h3>
#
# Next, Kyrus generated a for loop to create multiple pie charts representing the categorical breakdown by count

# %%
fig, axes = plt.subplots(3,3,figsize= (16,9))
for i, (idx, row) in enumerate(comp_df.set_index("county_string").iterrows()):
    ax = axes[i // 3, i % 3]
    row = row[row.gt(row.sum()*.01)]
    ax.pie(row, labels=row.index)
    ax.set_title(idx)
fig.subplots_adjust(wspace=1)

# %%
plt.show()

# %% [markdown]
# <h3>Part 3: Examining price breakdown based on region and restaurant category</h3>
#
# <b>The RQ:</b> How does price rating (\$, \$\$, \$\$\$, \$\$\$\$) breakdown for our randomly pulled cities? What is a the price rating breakdown by specific region and restaurant category? We expect higher income regions to have higher priced restaurants - ex: we would expect New York County  to have more 4\$ restaurants than a given county in the Midwest. We will see if the data of our randomly selected cities shows an even or uneven distribution based on price breakdown by category and by region.
#
# ---------------------------------
#
# After examining the categorical breakdown based on county, we moved on to determine the price breakdown by both region and restaurant category.
#
# This was Randi's portion of the project. We ran into some tricky stuff with the stacked bar charts. The primary issue was that the each bar's list needed to be the same length, that was fine, except when there was a restaurant for every price braket. Also, in all of her research Randi could not find how to make the stacked bars dynamic. In all the examples she found, the bar values were created manually. This is fine if you have a small dataset that you do not intend to run over and over again; however, this was not ideal for this project.
#
# <b>With some help from Mirko, Ryan, and Caleb, we figured it out! </b>
#
# First, we needed to define this list we would be looping through. For the first chart, Number of \$ per Category, we created a list named labels that contained all the different restaurant categories. Then, we created a second list with four empty lists. These four empty lists would represet 1\$, 2\$, 3\$, and 4\$. We then looped through our category list and found the count for each of the dollar ratings in said category. Once the loop determined how many 1\$, 2\$, 3\$, and 4\$ there were in each category it appended it to the corresponding empty list. If we did not find a 1\$, 2\$, 3\$, and 4\$ for a particular restaurant category, then the except argument kicked-in and instead appended a zero. Again, the goal was to make each of the four lists the same length.
#
# In the end, we ended up with a list corresponding to 1\$, 2\$, 3\$, and 4\$, with ratings per restaurant category.
#
# Once we created this loop and stored the counts in lists, we could call these lists in our chart creation; thereby, making the charts dynamic, changing with the number of pulls.

# %%
# Established the restaurant categories we will loop through
labels = ["Italian","Mexican","Chinese","American", "Indian"]

# Create and list of empty lists that will hold the count for $, $$, $$$, $$$$ per restaurant category
bars =[[],[],[],[]]

# Will first loop through the restaurant categories
for label in labels:
    df= res_df.loc[res_df["category"]==label, :]
    counts = df["price"].value_counts()
    
    # Now will loop through the price ranges and if there is a price, it will append it to the matching empty list
    # If there is no restaurant in that price range, then the we will use the except and append a zero
    for price in range(1,5):
        try:
            bars[price-1].append(counts[price])
        except: 
            bars[price-1].append(0)

# Check
print(bars[1])
# Out:
# [229, 146, 102, 681, 39]

# %%
from matplotlib import rc

# Establish our seaborn settings 
sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})

# set fig size
figsize= (100, 100, 50)
 
# Values for each stacked bar based on our above for loop 
# This make the bar values dynamic so we do not have to manually set the values 
bars1 = bars[0]
bars2 = bars[1]
bars3 = bars[2]
bars4 = bars[3]
x = np.arange(len(bars1))

# Plot our four bars from above values
four_dolla=plt.bar(x, bars4, color="plum")
three_dolla=plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dolla=plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dolla=plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

# Set our xticks based on categories
plt.xticks(x, ["Italian","Mexican","Chinese","American", "Indian"])

# Set our grid
plt.grid(axis='y')

# Set graph labels 
plt.xlabel("Category")
plt.ylabel('Count')
plt.title('Number of $ per Category')
    
# Set our legend
plt.legend((four_dolla[0], three_dolla[0],two_dolla[0], one_dolla[0]), ('4$', '3$','2$', '1$'), loc="best")


# Show graphic
plt.show()

# Save image
plt.savefig("stacked.png")

# %%
# Established the regions we will loop through
region = ["NE","MW","WC","SW","SE"]

# Create and list of empty lists that will hold the count for $, $$, $$$, $$$$ per region
r_bars =[[],[],[],[]]

# Will first loop through the regions
for r in region:
    reg_bars= res_df.loc[res_df["Region"]==r, :]
    reg_counts = reg_bars["price"].value_counts()
    
    # Now will loop through the price ranges and if there is a price, it will append it to the matching empty list
    # If there is no restaurant in that price range, then the we will use the except and append a zero
    for price in range(1,5):
        try:
            r_bars[price-1].append(reg_counts[price])
        except: 
            r_bars[price-1].append(0)

# Check            
print(r_bars)
# Out:
# [[195, 184, 140, 43, 251], [367, 213, 250, 34, 333], [17, 10, 14, 0, 24], [0, 0, 0, 0, 6]]

# %%
# Establish our seaborn settings 
sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})

# set fig size
figsize= (100, 100, 50)

# Values for each stacked bar based on our above for loop 
# This make the bar values dynamic so we do not have to manually set the values 
bars1 = r_bars[0]
bars2 = r_bars[1]
bars3 = r_bars[2]
bars4 = r_bars[3]
x = np.arange(len(bars1))

# Plot our four bars from above values
four_dol = plt.bar(x, bars4, color="plum")
three_dol =plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dol =plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dol =plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

# Set our xticks based on categories
plt.xticks(x, ["NE","MW","WC","SW","SE"])

# Set our grid
plt.grid(axis='y')

# Set graph labels 
plt.xlabel("Region")
plt.ylabel('Price Count')
plt.title('Number of $ per Region')

# Set graph legend 
plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")

# Show graphic
plt.show()

# Save image
plt.savefig("stacked2.png")

# %% [markdown]
# <h3>Part 3: Pie Chart</h3>
#
# With the dynamic stacked bar charts created, we thought it was relevant to also see the count of each dollar amount when comparing the counts by region or category. Thus, we created a pie chart (also dynamic) that shows the total of each restaurant category by dollar.

# %%
# Check our sums for pie chart
print(sum(bars1))
print(sum(bars2))
print(sum(bars3))
print(sum(bars4))

# %%
# Establish the auto percents
# Create definitions 
def make_autopct(sizes):
    def my_autopct(pct):
        total = sum(sizes)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:

# Establish our seaborn settings 
sns.set()
orgPalette = sns.color_palette("Set2")
sns.set_palette(orgPalette)
# sns.set_style("", {'legend.frameon':False})

# set fig size
plt.figure(figsize=(20,20))

# Set our labels, sizes, and explode values 
# We won't use labels because we will create a legend instead, but we could easily assign the labels

#labels = '4$', '3$','2$', '1$'
sizes = [sum(bars1),sum(bars2),sum(bars3),sum(bars4)]
explode = (0.03, 0.03, 0.03, 0.5)  # only "explode" the 2nd slice 


# Plot our pie chart with total sums by $ breakdown and place the percetages 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, colors=orgPalette, autopct=make_autopct(sizes),
        shadow=True, startangle=90) 

# Equal aspect ratio ensures that pie is drawn as a circle.
ax1.axis('equal')  

# Set graph title 
plt.title('Sum of each $ Amount')

# Set graph legend 
plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")


# Show graphic
plt.show()

# Save image
plt.savefig("pie_chart.jpg")

# %% [markdown]
# <h3>Part 4: MONICA</h3>

# %% [markdown]
# <h3>Part 5: CATHERINE</h3>

# %% [markdown]
# <h3>Part 6: Conclusions</h3>

# %% [markdown]
# <h3>Part 7: Limitations</h3>
#
# Initially, we wanted to find out if there wass there a relationship between income and type of dining (ie dine-in, carry-out, delivery)? Is this based on the number of restaurants that provide these options?
#
#
# Unfortunately, this didn’t work due to Yelp API limitations. Acoording to their website, currently, the transaction endpoint is "only supports food delivery in the US."
#
# Since the current Yelp Fusion API only supports the delivery option it isn’t very helpful for comparison or analysis purposes.

# %% [markdown]
# <h3>Part 8: If only we had more time...</h3>
#
# <ul>
# <li>Attempt to match user category input with local restaurant </li>
# <li>"Build a lunch recommendation Slack bot that can pull highest rated Yelp places around your location. You can build the script to respond to user input (ex. “Chinese, $”) or generate top-rated places randomly." This was just too ambitious for our timeframe </li>
# </ul>
