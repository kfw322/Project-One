# %%
# !pip install yelpapi
# !pip install numpy
import yelpapi
import json
import requests
from  pprint import  pprint
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

#reading in county data
counties=pd.read_csv("acs2015_county_data.csv")
counties["county_string"] = counties["County"] + " County, " + counties["State"]
listofcounties = counties["county_string"].tolist()
#reading in zipcodes
zipcodes=pd.read_csv("zip_codes_states.csv")
zipcodes["county_string"] = zipcodes["county"] + " County, " + zipcodes["state"]
listofzipcodes=zipcodes["county_string"].unique().tolist()
counties.to_csv("counties.csv")
zipcodes.to_csv("zcs.csv")
fullcountylist = list(set(listofcounties) & set(listofzipcodes))
counties.head(1)
# Out:
# Requirement already satisfied: yelpapi in /Users/randi/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: requests in /Users/randi/anaconda3/lib/python3.6/site-packages (from yelpapi)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: numpy in /Users/randi/anaconda3/lib/python3.6/site-packages
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
#
#    Native           ...             OtherTransp  WorkAtHome  MeanCommute  \
# 0     0.4           ...                     1.3         1.8         26.5
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0     23986         73.6        20.9           5.5         0.0           7.6
#
#              county_string
# 0  Autauga County, Alabama
#
# [1 rows x 38 columns]

# %%
#creating regions
WC = ["Washington","Oregon","California","Nevada","Idaho"]
MW = ["Montana","Wyoming","North Dakota","South Dakota","Nebraska","Kansas","Minnesota","Iowa","Missouri",
      "Wisconsin","Illinois","Michigan","Indiana","Ohio","Kentucky"]
SW = ["Arizona","Utah","Colorado","New Mexico","Oklahoma","Texas"]
SE = ["Arkansas","Louisiana","Mississippi","Alabama","Tennessee","Virginia","West Virginia","North Carolina","South Carolina","Georgia","Florida"]
NE = ["District of Columbia","Pennsylvania","Maryland","Delaware","New Jersey","New York","Maine","New Hampshire","Vermont","Massachusetts","Rhode Island","Connecticut"]
counties["Region"]= np.where(counties["State"].isin(WC),'WC',
                    np.where(counties["State"].isin(MW),'MW',
                    np.where(counties["State"].isin(SW),'SW',
                    np.where(counties["State"].isin(SE),'SE',
                    np.where(counties["State"].isin(NE),'NE', 
                             'other')))))

# %%
#counties.groupby(["Region"]).sum()["TotalPop"]
cdf = pd.DataFrame(counties,columns=["county_string","Region"])
WClist = (cdf.groupby("Region").get_group("WC")["county_string"]).tolist()
MWlist = (cdf.groupby("Region").get_group("MW")["county_string"]).tolist()
SWlist = (cdf.groupby("Region").get_group("SW")["county_string"]).tolist()
SElist = (cdf.groupby("Region").get_group("SE")["county_string"]).tolist()
NElist = (cdf.groupby("Region").get_group("NE")["county_string"]).tolist()

sample_list = []
sample_list.extend(random.sample(list(set(WClist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(MWlist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(SWlist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(SElist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(NElist) & set(fullcountylist)),2))
sample_list
# Out:
# ['Bannock County, Idaho',
#  'Storey County, Nevada',
#  'Benton County, Iowa',
#  'Brule County, South Dakota',
#  'Major County, Oklahoma',
#  'Conejos County, Colorado',
#  'Putnam County, Georgia',
#  'Lafayette County, Mississippi',
#  'Bradford County, Pennsylvania',
#  'Lehigh County, Pennsylvania']

# %%
res_df = pd.DataFrame(columns=["name","zipcode","county_string","rating","review_count","category","price","region"])
res_df
# Out:
# Empty DataFrame
# Columns: [name, zipcode, county_string, rating, review_count, category, price, region]
# Index: []

# %%
r = 0
for c in sample_list:
    county_string = str(c)
    for term in ["Italian","Mexican","Chinese","American (Traditional)","American (New)","Indian"]:
        #we are allowed 5000 queries per 24 hours. if we run out, we can create another. till then, use this
        yelpkey="IXRN_1GI8f8J9Kj5O5GciqeyFSWR5RMh41_rADGy1KrtQ5ZABGGZEkWwot5mOka0NlzlNxXPmzYXLWk88oOV0N_YxD1MSW4kQRfJnFrwfHLtKrr2HcsjLo6uWBzAWnYx"
        try:
            offset=0
            for loopcount in range(5):
                
                response = requests.get(url="https://api.yelp.com/v3/businesses/search", 
                       params= {"location": county_string,"term": term, "limit":"50", "offset": offset}, 
                       headers={'Authorization': 'bearer %s' % yelpkey})
                responsejson = response.json()
                offset += 50
                try:
                    count=0
            
                    for x in range(0,49):
                        for y in range(0,len(responsejson["businesses"][x]["categories"])):
                            if ((str(responsejson["businesses"][x]["categories"][y]["title"])==str(term)) and 
                                (responsejson["businesses"][x]["review_count"] > 0)):
                                zc = int(responsejson["businesses"][x]["location"]["zip_code"])
                                if (zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0]== county_string):
                                    
                                    print("\n",responsejson["businesses"][x]["name"],
                                        responsejson["businesses"][x]["location"]["zip_code"],
                                        zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0],
                                        responsejson["businesses"][x]["rating"],
                                        responsejson["businesses"][x]["review_count"],
                                        responsejson["businesses"][x]["categories"][y]["title"])
                                    res_df.loc[r]=[responsejson["businesses"][x]["name"],
                                        str(zc),
                                        county_string,
                                        responsejson["businesses"][x]["rating"],
                                        responsejson["businesses"][x]["review_count"],
                                        term,
                                        responsejson["businesses"][x]["price"],
                                        "region"
                                                  ]
                                    count += 1
                                    r += 1
                except:
                    
                    break
    
                print("End of list. Found", count, term, "restaurants in", county_string)
        except:
            print("Error: this shouldn't happen")
            break
# Out:
#  Cafe Tuscano 83201 Bannock County, Idaho 4.0 78 Italian
#
#  Buddy's Italian Restaurant 83201 Bannock County, Idaho 3.5 78 Italian
#
#  Villano's Italian 83204 Bannock County, Idaho 3.5 25 Italian
#
#  PV's Pasta & Vino 83201 Bannock County, Idaho 4.0 12 Italian
#
#  Pizza Hut 83201 Bannock County, Idaho 1.5 6 Italian
#
#  El Caporal 83201 Bannock County, Idaho 4.5 57 Mexican
#
#  El Herradero 83201 Bannock County, Idaho 4.0 103 Mexican
#
#  Señor Garcia's Puerto Vallarta 83201 Bannock County, Idaho 4.0 20 Mexican
#
#  Mama Inez 83201 Bannock County, Idaho 3.5 30 Mexican
#
#  Chapala Mexican Resturant 83202 Bannock County, Idaho 3.5 14 Mexican
#
#  Las Palomas Mexican Grill 83201 Bannock County, Idaho 5.0 2 Mexican
#
#  Chang's Garden 83201 Bannock County, Idaho 4.0 33 Chinese
#
#  Mandarin House 83201 Bannock County, Idaho 3.5 30 Chinese
#
#  New Hong Kong Restaurant 83201 Bannock County, Idaho 4.0 6 Chinese
#
#  The Little Rock Cafe 83250 Bannock County, Idaho 4.5 37 American (Traditional)
#
#  Sandbaggers Bar & Grill 83201 Bannock County, Idaho 4.5 8 American (Traditional)
#
#  Chuck Wagon Restaurant 83246 Bannock County, Idaho 3.5 78 American (Traditional)
#
#  Blue Heeler 83204 Bannock County, Idaho 4.0 4 American (Traditional)
#
#  Blue Moon Bar & Grill 83246 Bannock County, Idaho 4.0 22 American (Traditional)
#
#  78 Main Street Dining 83246 Bannock County, Idaho 3.0 71 American (Traditional)
#
#  Red Robin Gourmet Burgers 83202 Bannock County, Idaho 3.5 20 American (Traditional)
#
#  Elmer's Restaurant 83201 Bannock County, Idaho 4.0 123 American (Traditional)
#
#  Oliver's Restaurant 83201 Bannock County, Idaho 3.5 32 American (Traditional)
#
#  Butterburrs 83201 Bannock County, Idaho 3.5 92 American (Traditional)
#
#  Tom's Gyro and Burgers 83201 Bannock County, Idaho 3.5 37 American (Traditional)
#
#  The Sand Trap Grill 83204 Bannock County, Idaho 3.5 31 American (Traditional)
#
#  Press Box Sports Bar 83206 Bannock County, Idaho 3.5 14 American (Traditional)
#
#  MacKenzie River Pizza, Grill & Pub 83202 Bannock County, Idaho 4.0 78 American (Traditional)
#
#  Wingers 83201 Bannock County, Idaho 4.0 32 American (Traditional)
#
#  The Healthier Place To Eat 83204 Bannock County, Idaho 4.0 46 American (Traditional)
#
#  Applebee's Grill + Bar 83201 Bannock County, Idaho 3.0 28 American (Traditional)
#
#  Texas Roadhouse 83202 Bannock County, Idaho 3.0 55 American (Traditional)
#
#  Denny's 83202 Bannock County, Idaho 3.5 14 American (Traditional)
#
#  Perkins Restaurant & Bakery 83201 Bannock County, Idaho 3.0 29 American (Traditional)
#
#  Chili's 83201 Bannock County, Idaho 2.5 19 American (Traditional)
#
#  IHOP 83202 Bannock County, Idaho 1.5 17 American (Traditional)
#
#  Red Lobster 83202 Bannock County, Idaho 3.5 22 American (Traditional)
#
#  Brass Rail Steakhouse 83201 Bannock County, Idaho 2.5 5 American (Traditional)
#
#  Applebee's Grill + Bar 83202 Bannock County, Idaho 4.0 4 American (Traditional)
#
#  The Little Rock Cafe 83250 Bannock County, Idaho 4.5 37 American (New)
#
#  Portneuf Grille & Lounge 83246 Bannock County, Idaho 4.5 49 American (New)
#
#  Silver Grille 83246 Bannock County, Idaho 2.5 15 American (New)
#
#  The Bridge 83202 Bannock County, Idaho 3.5 61 American (New)
#
#  El Herradero 83201 Bannock County, Idaho 4.0 103 American (New)
#
#  Clydesdale Bar & Lounge 83201 Bannock County, Idaho 4.0 5 American (New)
#
#  A & W 83204 Bannock County, Idaho 3.5 3 American (New)
#
#  A Taste of India & Nepal 83204 Bannock County, Idaho 4.0 84 Indian
#
#  Nosh Mahal 83201 Bannock County, Idaho 3.5 34 Indian
#
#  The Cider Factory 89440 Storey County, Nevada 5.0 49 Italian
# End of list. Found 1 Italian restaurants in Storey County, Nevada
#
#  Virginia City Bar & Grill 89440 Storey County, Nevada 3.0 6 American (Traditional)
#
#  Gold Hill Preview Event 89440 Storey County, Nevada 4.5 2 American (Traditional)
# End of list. Found 0 Italian restaurants in Benton County, Iowa
# End of list. Found 0 Italian restaurants in Benton County, Iowa
# End of list. Found 0 Italian restaurants in Benton County, Iowa
#
#  La Renya 52349 Benton County, Iowa 4.0 12 Mexican
# End of list. Found 1 Mexican restaurants in Benton County, Iowa
#
#  Lotus Chinese Restaurant 52349 Benton County, Iowa 4.5 5 Chinese
#
#  The Crooked Antler 52346 Benton County, Iowa 4.5 8 American (Traditional)
#
#  The Crooked Antler 52346 Benton County, Iowa 4.5 8 American (New)
#
#  Upper Crust Pizza & Wings 57325 Brule County, South Dakota 4.0 31 Italian
#
#  Pizza Hut 57325 Brule County, South Dakota 2.5 7 Italian
#
#  Taco John's 57325 Brule County, South Dakota 4.0 13 Mexican
#
#  The Back 40 57355 Brule County, South Dakota 4.5 17 American (Traditional)
#
#  Upper Crust Pizza & Wings 57325 Brule County, South Dakota 4.0 31 American (Traditional)
#
#  Anchor Grille 57325 Brule County, South Dakota 3.5 33 American (Traditional)
#
#  Busted Nut Bar & Grill 57325 Brule County, South Dakota 3.0 17 American (Traditional)
#
#  Charlys Restaurant & Lounge 57325 Brule County, South Dakota 3.5 23 American (New)
#
#  Pizza Hut 73737 Major County, Oklahoma 3.0 5 Italian
#
#  El Maya 73737 Major County, Oklahoma 4.5 8 Mexican
#
#  Delgado Mexican Restaurant 73737 Major County, Oklahoma 3.5 6 Mexican
#
#  Dos Hermanas 81120 Conejos County, Colorado 4.0 29 Mexican
#
#  El Vallecito 81140 Conejos County, Colorado 4.0 7 Mexican
#
#  Mel's  Restaurant 81140 Conejos County, Colorado 3.5 2 Mexican
#
#  Dos Hermanas 81120 Conejos County, Colorado 4.0 29 American (Traditional)
#
#  Val's Place 81141 Conejos County, Colorado 3.5 3 American (Traditional)
#
#  Wagon Wheel Saloon 81140 Conejos County, Colorado 4.5 7 American (New)
#
#  Pronto Slice N Pasta 31024 Putnam County, Georgia 4.0 8 Italian
#
#  Pizza Hut 31024 Putnam County, Georgia 2.0 2 Italian
#
#  El Agave 31024 Putnam County, Georgia 4.5 27 Mexican
#
#  El Sitio Mexican Grill 31024 Putnam County, Georgia 3.5 11 Mexican
#
#  Cucos Mexican Restaurant 31024 Putnam County, Georgia 4.0 3 Mexican
#
#  El Llano Mexican Grill III 31024 Putnam County, Georgia 2.0 2 Mexican
#
#  Taco Bell 31024 Putnam County, Georgia 1.5 2 Mexican
#
#  China Yuan 31024 Putnam County, Georgia 2.0 1 Chinese
#
#  The Silver Moon 31024 Putnam County, Georgia 4.5 75 American (Traditional)
#
#  Bone Island Grillhouse 31024 Putnam County, Georgia 4.0 39 American (Traditional)
#
#  Iron Fork Café 31024 Putnam County, Georgia 4.0 10 American (Traditional)
#
#  The Frisk Pub 31024 Putnam County, Georgia 4.0 1 American (Traditional)
#
#  Smiths Coastal Grill 31024 Putnam County, Georgia 4.5 39 American (New)
#
#  Waterside Restaurant 31024 Putnam County, Georgia 3.5 7 American (New)
#
#  6'N'Tubbs 38655 Lafayette County, Mississippi 4.5 18 Italian
#
#  Proud Larrys' 38655 Lafayette County, Mississippi 3.5 40 Italian
#
#  Pizza Den 38655 Lafayette County, Mississippi 4.0 23 Italian
#
#  Pizza Hut 38655 Lafayette County, Mississippi 1.5 5 Italian
#
#  Square Pizza 38655 Lafayette County, Mississippi 2.5 19 Italian
# End of list. Found 5 Italian restaurants in Lafayette County, Mississippi
#
#  El Agave Mexican Grill 38655 Lafayette County, Mississippi 3.5 25 Mexican
#
#  Taco Shop 38655 Lafayette County, Mississippi 4.0 23 Mexican
#
#  South Depot Taco Shop 38655 Lafayette County, Mississippi 4.0 44 Mexican
#
#  Casa Mexicana Bar & Grill 38655 Lafayette County, Mississippi 3.0 21 Mexican
#
#  La Tienda Carreton 38655 Lafayette County, Mississippi 3.5 3 Mexican
#
#  Ming's Kitchen 38655 Lafayette County, Mississippi 4.0 20 Chinese
#
#  China Royal 38655 Lafayette County, Mississippi 4.5 4 Chinese
#
#  The Blind Pig Pub 38655 Lafayette County, Mississippi 4.0 18 American (Traditional)
#
#  Mama Jos Country Cookin 38655 Lafayette County, Mississippi 4.0 12 American (Traditional)
#
#  The Sizzler 38655 Lafayette County, Mississippi 3.5 5 American (Traditional)
#
#  Chancellor's Grill 38655 Lafayette County, Mississippi 4.5 7 American (Traditional)
#
#  England Dan's Char-Steaks & Grill 38655 Lafayette County, Mississippi 4.0 1 American (Traditional)
#
#  Boure Restaurant 38655 Lafayette County, Mississippi 4.0 142 American (New)
#
#  Grit 38655 Lafayette County, Mississippi 4.0 18 American (New)
#
#  Maharaja Indian Cuisine 38655 Lafayette County, Mississippi 3.5 27 Indian
#
#  Villa Sena 18848 Bradford County, Pennsylvania 3.5 11 Italian
#
#  Mangialardo's Restaurant 18840 Bradford County, Pennsylvania 4.0 26 Italian
#
#  Yanuzzi's Restaurant 18840 Bradford County, Pennsylvania 3.5 17 Italian
#
#  Robbie's Pizzeria 18853 Bradford County, Pennsylvania 5.0 1 Italian
#  Kam Bo Chinese Restaurant 18848 Bradford County, Pennsylvania 3.5 10 Chinese
#
#  Great Wall Chinese Buffet 18848 Bradford County, Pennsylvania 2.5 3 Chinese
#
#  Woody's Ale House & Grille 18848 Bradford County, Pennsylvania 4.5 10 American (Traditional)
#
#  Suky's Diner 18848 Bradford County, Pennsylvania 3.5 5 American (Traditional)
#
#  Flatiron Bar & Grill 18840 Bradford County, Pennsylvania 5.0 2 American (New)
#  Union and Finch 18102 Lehigh County, Pennsylvania 4.5 143 American (New)
#
#  Grain 18101 Lehigh County, Pennsylvania 4.0 315 American (New)
#
#  Savory Grille 18062 Lehigh County, Pennsylvania 4.5 49 American (New)
#
#  Randall's on the Orchard 18069 Lehigh County, Pennsylvania 4.0 21 American (New)
#
#  Curious Goods 18053 Lehigh County, Pennsylvania 4.5 42 American (New)
#
#  The Trapp Door Gastropub 18049 Lehigh County, Pennsylvania 4.5 131 American (New)
#
#  Grille 3501 18104 Lehigh County, Pennsylvania 4.0 165 American (New)
#
#  The Shelby 18106 Lehigh County, Pennsylvania 3.5 81 American (New)
#
#  Bay Leaf Restaurant 18101 Lehigh County, Pennsylvania 4.5 61 American (New)
#
#  Bolete Restaurant 18105 Lehigh County, Pennsylvania 4.5 283 American (New)
#
#  Cafe Santosha 18087 Lehigh County, Pennsylvania 4.5 21 American (New)
#
#  Ringer's Roost 18104 Lehigh County, Pennsylvania 4.0 26 American (New)
#
#  Hops Bar And Grill 18051 Lehigh County, Pennsylvania 2.5 3 American (New)
#
#  Clove, Fine Indian Dining 18109 Lehigh County, Pennsylvania 4.5 96 Indian
#
#  Biryani City - Allentown 18109 Lehigh County, Pennsylvania 4.0 106 Indian
#
#  Mayuri Indian Cuisine 18052 Lehigh County, Pennsylvania 4.0 72 Indian
#
#  Zanzibar Kababs and Grill 18104 Lehigh County, Pennsylvania 3.5 23 Indian
#
#  Spice India 18052 Lehigh County, Pennsylvania 3.5 103 Indian
# End of list. Found 5 Indian restaurants in Lehigh County, Pennsylvania
# End of list. Found 0 Indian restaurants in Lehigh County, Pennsylvania

# %%
res_df.to_csv("output1804071028.csv")
try:
    res_df.price.replace(["$","$$","$$$","$$$$"],[1,2,3,4],inplace=True)
except:
    print("Already done")
try:
    res_df.category.replace(["American (New)","American (Traditional)"],["American","American"],inplace=True)
except:
    print("Already done")
res_df
# Out:
#                                     name zipcode                county_string  \
# 0                           Cafe Tuscano   83201        Bannock County, Idaho
# 1             Buddy's Italian Restaurant   83201        Bannock County, Idaho
# 2                      Villano's Italian   83204        Bannock County, Idaho
# 3                      PV's Pasta & Vino   83201        Bannock County, Idaho
# 4                              Pizza Hut   83201        Bannock County, Idaho
# 5                             El Caporal   83201        Bannock County, Idaho
# 6                           El Herradero   83201        Bannock County, Idaho
# 7         Señor Garcia's Puerto Vallarta   83201        Bannock County, Idaho
# 8                              Mama Inez   83201        Bannock County, Idaho
# 9              Chapala Mexican Resturant   83202        Bannock County, Idaho
# 10                        Chang's Garden   83201        Bannock County, Idaho
# 11                        Mandarin House   83201        Bannock County, Idaho
# 12                  The Little Rock Cafe   83250        Bannock County, Idaho
# 13               Sandbaggers Bar & Grill   83201        Bannock County, Idaho
# 14                Chuck Wagon Restaurant   83246        Bannock County, Idaho
# 15                           Blue Heeler   83204        Bannock County, Idaho
# 16                 Blue Moon Bar & Grill   83246        Bannock County, Idaho
# 17                 78 Main Street Dining   83246        Bannock County, Idaho
# 18             Red Robin Gourmet Burgers   83202        Bannock County, Idaho
# 9       3.5           14   Mexican      2  region
# 10      4.0           33   Chinese      2  region
# 11      3.5           30   Chinese      1  region
# 12      4.5           37  American      1  region
# 13      4.5            8  American      1  region
# 14      3.5           78  American      2  region
# 15      4.0            4  American      1  region
# 16      4.0           22  American      1  region
# 17      3.0           71  American      2  region
# 18      3.5           20  American      2  region
# 19      4.0          123  American      2  region
# 20      3.5           32  American      2  region
# 21      3.5           92  American      1  region
# 22      3.5           37  American      1  region
# 23      3.5           31  American      2  region
# 24      3.5           14  American      2  region
# 25      4.0           78  American      2  region
# 26      4.0           32  American      2  region
# 27      4.0           46  American      1  region
# 28      3.0           28  American      2  region
# 29      3.0           55  American      2  region
# ..      ...          ...       ...    ...     ...
# 110     4.0           17   Mexican      2  region
# 111     4.5           49   Mexican      1  region
# 112     4.5           42   Chinese      2  region
# 113     4.0          116   Chinese      2  region
# 114     4.0           27   Chinese      2  region
# 115     4.5            9  American      2  region
# 116     3.0           55  American      2  region
# 117     3.5           28  American      1  region
# 118     3.5           10  American      2  region
# 119     4.0          103  American      1  region
# 120     4.0            8  American      3  region
# 121     4.0           96  American      1  region
# 122     4.0           67  American      2  region
# 123     4.5          143  American      2  region
# 124     4.0          315  American      2  region
# 125     4.5           49  American      3  region
# 126     4.0           21  American      3  region
# 127     4.5           42  American      2  region
# 128     4.5          131  American      2  region
# 129     4.0          165  American      3  region
# 130     3.5           81  American      2  region
# 131     4.5           61  American      2  region
# 132     4.5          283  American      3  region
# 133     4.5           21  American      1  region
# 134     4.0           26  American      2  region
# 135     4.5           96    Indian      2  region
# 136     4.0          106    Indian      2  region
# 137     4.0           72    Indian      2  region
# 138     3.5           23    Indian      2  region
# 139     3.5          103    Indian      2  region
#
# [140 rows x 8 columns]

# %%
res_df= pd.merge(res_df,counties,how="left",on="county_string")
res_df.head()
# Out:
#                          name zipcode          county_string  rating  \
# 0                Cafe Tuscano   83201  Bannock County, Idaho     4.0
# 1  Buddy's Italian Restaurant   83201  Bannock County, Idaho     3.5
# 2           Villano's Italian   83204  Bannock County, Idaho     3.5
# 3           PV's Pasta & Vino   83201  Bannock County, Idaho     4.0
# 4                   Pizza Hut   83201  Bannock County, Idaho     1.5
#
#   review_count category  price  region  CensusId  State   ...   OtherTransp  \
# 0           78  Italian      2  region     16005  Idaho   ...           2.2
# 1           78  Italian      2  region     16005  Idaho   ...           2.2
# 2           25  Italian      2  region     16005  Idaho   ...           2.2
# 3           12  Italian      2  region     16005  Idaho   ...           2.2
# 4            6  Italian      2  region     16005  Idaho   ...           2.2
#
#    WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0         3.8         17.9     37206         73.0        20.8           6.0
# 1         3.8         17.9     37206         73.0        20.8           6.0
# 2         3.8         17.9     37206         73.0        20.8           6.0
# 3         3.8         17.9     37206         73.0        20.8           6.0
# 4         3.8         17.9     37206         73.0        20.8           6.0
#
#    FamilyWork  Unemployment  Region
# 0         0.2           7.2      WC
# 1         0.2           7.2      WC
# 2         0.2           7.2      WC
# 3         0.2           7.2      WC
# 4         0.2           7.2      WC
#
# [5 rows x 46 columns]

# %%
itadf = res_df.groupby(res_df["category"]).get_group("Italian")
mexdf = res_df.groupby(res_df["category"]).get_group("Mexican")
chndf = res_df.groupby(res_df["category"]).get_group("Chinese")
usadf = res_df.groupby(res_df["category"]).get_group("American")
inddf = res_df.groupby(res_df["category"]).get_group("Indian")
res_df
# CHA = res_df.groupby(res_df["county_string"]).get_group("Mecklenburg County, North Carolina")
# CHAbreakdown = pd.DataFrame(CHA["category"].value_counts()).T.reset_index()
# CHAbreakdown["county_string"]="Mecklenburg County, North Carolina"
# CHA_price_avg = CHA.groupby(res_df["price"]).mean()
# CHA_price_count = CHA["price"].value_counts()

# RAL = res_df.groupby(res_df["county_string"]).get_group("Wake County, North Carolina")
# RALbreakdown = pd.DataFrame(RAL["category"].value_counts()).T.reset_index()
# RALbreakdown["county_string"]="Wake County, North Carolina"
# RAL_price_avg = RAL.groupby(res_df["price"]).mean()
# RAL_price_count = RAL["price"].value_counts()

# ATL = res_df.groupby(res_df["county_string"]).get_group("Fulton County, Georgia")
# ATLbreakdown = pd.DataFrame(ATL["category"].value_counts()).T.reset_index()
# ATLbreakdown["county_string"]="Fulton County, Georgia"
# ATL_price_avg = ATL.groupby(res_df["price"]).mean()
# ATL_price_count = ATL["price"].value_counts()

# MEM = res_df.groupby(res_df["county_string"]).get_group("Shelby County, Tennessee")
# MEMbreakdown = pd.DataFrame(MEM["category"].value_counts()).T.reset_index()
# MEMbreakdown["county_string"]="Shelby County, Tennessee"
# MEM_price_avg = MEM.groupby(res_df["price"]).mean()
# MEM_price_count = MEM["price"].value_counts()


# ORL = res_df.groupby(res_df["county_string"]).get_group("Orange County, Florida")
# ORLbreakdown = pd.DataFrame(ORL["category"].value_counts()).T.reset_index()
# ORLbreakdown["county_string"]="Orange County, Florida"
# ORL_price_avg = ORL.groupby(res_df["price"]).mean()
# ORL_price_count = ORL["price"].value_counts()

# MIL = res_df.groupby(res_df["county_string"]).get_group("Milwaukee County, Wisconsin")
# MILbreakdown = pd.DataFrame(MIL["category"].value_counts()).T.reset_index()
# MILbreakdown["county_string"]="Milwaukee County, Wisconsin"
# MIL_price_avg = MIL.groupby(res_df["price"]).mean()
# MIL_price_count = MIL["price"].value_counts()

# SFC = res_df.groupby(res_df["county_string"]).get_group("San Francisco County, California")
# SFCbreakdown = pd.DataFrame(SFC["category"].value_counts()).T.reset_index()
# SFCbreakdown["county_string"]="San Francisco County, California"
# SFC_price_avg = SFC.groupby(res_df["price"]).mean()
# SFC_price_count = SFC["price"].value_counts()

# AUS = res_df.groupby(res_df["county_string"]).get_group("Travis County, Texas")
# AUSbreakdown = pd.DataFrame(AUS["category"].value_counts()).T.reset_index()
# AUSbreakdown["county_string"]="Travis County, Texas"
# AUS_price_avg = AUS.groupby(res_df["price"]).mean()
# AUS_price_count = AUS["price"].value_counts()

# PIT = res_df.groupby(res_df["county_string"]).get_group("Allegheny County, Pennsylvania")
# PITbreakdown = pd.DataFrame(PIT["category"].value_counts()).T.reset_index()
# 118     3.5           10  American      2  region     42077  Pennsylvania
# 119     4.0          103  American      1  region     42077  Pennsylvania
# 120     4.0            8  American      3  region     42077  Pennsylvania
# 121     4.0           96  American      1  region     42077  Pennsylvania
# 122     4.0           67  American      2  region     42077  Pennsylvania
# 123     4.5          143  American      2  region     42077  Pennsylvania
# 124     4.0          315  American      2  region     42077  Pennsylvania
# 125     4.5           49  American      3  region     42077  Pennsylvania
# 126     4.0           21  American      3  region     42077  Pennsylvania
# 127     4.5           42  American      2  region     42077  Pennsylvania
# 128     4.5          131  American      2  region     42077  Pennsylvania
# 129     4.0          165  American      3  region     42077  Pennsylvania
# 130     3.5           81  American      2  region     42077  Pennsylvania
# 131     4.5           61  American      2  region     42077  Pennsylvania
# 132     4.5          283  American      3  region     42077  Pennsylvania
# 133     4.5           21  American      1  region     42077  Pennsylvania
# 134     4.0           26  American      2  region     42077  Pennsylvania
# 135     4.5           96    Indian      2  region     42077  Pennsylvania
# 136     4.0          106    Indian      2  region     42077  Pennsylvania
# 137     4.0           72    Indian      2  region     42077  Pennsylvania
# 138     3.5           23    Indian      2  region     42077  Pennsylvania
# 139     3.5          103    Indian      2  region     42077  Pennsylvania
#
#       ...   OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0     ...           2.2         3.8         17.9     37206         73.0
# 1     ...           2.2         3.8         17.9     37206         73.0
# 2     ...           2.2         3.8         17.9     37206         73.0
# 3     ...           2.2         3.8         17.9     37206         73.0
# 4     ...           2.2         3.8         17.9     37206         73.0
# 5     ...           2.2         3.8         17.9     37206         73.0
# 6     ...           2.2         3.8         17.9     37206         73.0
# 7     ...           2.2         3.8         17.9     37206         73.0
# 8     ...           2.2         3.8         17.9     37206         73.0
# 9     ...           2.2         3.8         17.9     37206         73.0
# 10    ...           2.2         3.8         17.9     37206         73.0
# 11    ...           2.2         3.8         17.9     37206         73.0
# 12    ...           2.2         3.8         17.9     37206         73.0
# 13    ...           2.2         3.8         17.9     37206         73.0
# 14    ...           2.2         3.8         17.9     37206         73.0
# 15    ...           2.2         3.8         17.9     37206         73.0
# 16    ...           2.2         3.8         17.9     37206         73.0
# 17    ...           2.2         3.8         17.9     37206         73.0
# 18    ...           2.2         3.8         17.9     37206         73.0
# 19    ...           2.2         3.8         17.9     37206         73.0
# 20    ...           2.2         3.8         17.9     37206         73.0
# 21    ...           2.2         3.8         17.9     37206         73.0
# 22    ...           2.2         3.8         17.9     37206         73.0
# 23    ...           2.2         3.8         17.9     37206         73.0
# 24    ...           2.2         3.8         17.9     37206         73.0
# 25    ...           2.2         3.8         17.9     37206         73.0
# 26    ...           2.2         3.8         17.9     37206         73.0
# 27    ...           2.2         3.8         17.9     37206         73.0
# 28    ...           2.2         3.8         17.9     37206         73.0
# 29    ...           2.2         3.8         17.9     37206         73.0
# ..    ...           ...         ...          ...       ...          ...
# 110   ...           0.9         4.1         24.9    170448         87.0
# 111   ...           0.9         4.1         24.9    170448         87.0
# 112   ...           0.9         4.1         24.9    170448         87.0
# 113   ...           0.9         4.1         24.9    170448         87.0
# 114   ...           0.9         4.1         24.9    170448         87.0
# 115   ...           0.9         4.1         24.9    170448         87.0
# 116   ...           0.9         4.1         24.9    170448         87.0
# 117   ...           0.9         4.1         24.9    170448         87.0
# 118   ...           0.9         4.1         24.9    170448         87.0
# 119   ...           0.9         4.1         24.9    170448         87.0
# 120   ...           0.9         4.1         24.9    170448         87.0
# 121   ...           0.9         4.1         24.9    170448         87.0
# 122   ...           0.9         4.1         24.9    170448         87.0
# 123   ...           0.9         4.1         24.9    170448         87.0
# 124   ...           0.9         4.1         24.9    170448         87.0
# 125   ...           0.9         4.1         24.9    170448         87.0
# 126   ...           0.9         4.1         24.9    170448         87.0
# 127   ...           0.9         4.1         24.9    170448         87.0
# 128   ...           0.9         4.1         24.9    170448         87.0
# 129   ...           0.9         4.1         24.9    170448         87.0
# 130   ...           0.9         4.1         24.9    170448         87.0
# 131   ...           0.9         4.1         24.9    170448         87.0
# 132   ...           0.9         4.1         24.9    170448         87.0
# 133   ...           0.9         4.1         24.9    170448         87.0
# 134   ...           0.9         4.1         24.9    170448         87.0
# 135   ...           0.9         4.1         24.9    170448         87.0
# 136   ...           0.9         4.1         24.9    170448         87.0
# 137   ...           0.9         4.1         24.9    170448         87.0
# 138   ...           0.9         4.1         24.9    170448         87.0
# 139   ...           0.9         4.1         24.9    170448         87.0
#
#      PublicWork  SelfEmployed  FamilyWork  Unemployment  Region
# 0          20.8           6.0         0.2           7.2      WC
# 1          20.8           6.0         0.2           7.2      WC
# 2          20.8           6.0         0.2           7.2      WC
# 3          20.8           6.0         0.2           7.2      WC
# 4          20.8           6.0         0.2           7.2      WC
# 5          20.8           6.0         0.2           7.2      WC
# 6          20.8           6.0         0.2           7.2      WC
# 7          20.8           6.0         0.2           7.2      WC
# 8          20.8           6.0         0.2           7.2      WC
# 9          20.8           6.0         0.2           7.2      WC
# 10         20.8           6.0         0.2           7.2      WC
# 11         20.8           6.0         0.2           7.2      WC
# 12         20.8           6.0         0.2           7.2      WC
# 13         20.8           6.0         0.2           7.2      WC
# 14         20.8           6.0         0.2           7.2      WC
# 15         20.8           6.0         0.2           7.2      WC
# 16         20.8           6.0         0.2           7.2      WC
# 17         20.8           6.0         0.2           7.2      WC
# 18         20.8           6.0         0.2           7.2      WC
# 19         20.8           6.0         0.2           7.2      WC
# 20         20.8           6.0         0.2           7.2      WC
# 21         20.8           6.0         0.2           7.2      WC
# 22         20.8           6.0         0.2           7.2      WC
# 23         20.8           6.0         0.2           7.2      WC
# 24         20.8           6.0         0.2           7.2      WC
# 25         20.8           6.0         0.2           7.2      WC
# 26         20.8           6.0         0.2           7.2      WC
# 27         20.8           6.0         0.2           7.2      WC
# 28         20.8           6.0         0.2           7.2      WC
# 29         20.8           6.0         0.2           7.2      WC
# ..          ...           ...         ...           ...     ...
# 110         8.5           4.4         0.1           8.5      NE
# 111         8.5           4.4         0.1           8.5      NE
# 112         8.5           4.4         0.1           8.5      NE
# 113         8.5           4.4         0.1           8.5      NE
# 114         8.5           4.4         0.1           8.5      NE
# 115         8.5           4.4         0.1           8.5      NE
# 116         8.5           4.4         0.1           8.5      NE
# 117         8.5           4.4         0.1           8.5      NE
# 118         8.5           4.4         0.1           8.5      NE
# 119         8.5           4.4         0.1           8.5      NE
# 120         8.5           4.4         0.1           8.5      NE
# 121         8.5           4.4         0.1           8.5      NE
# 122         8.5           4.4         0.1           8.5      NE
# 123         8.5           4.4         0.1           8.5      NE
# 124         8.5           4.4         0.1           8.5      NE
# 125         8.5           4.4         0.1           8.5      NE
# 126         8.5           4.4         0.1           8.5      NE
# 127         8.5           4.4         0.1           8.5      NE
# 128         8.5           4.4         0.1           8.5      NE
# 129         8.5           4.4         0.1           8.5      NE
# 130         8.5           4.4         0.1           8.5      NE
# 131         8.5           4.4         0.1           8.5      NE
# 132         8.5           4.4         0.1           8.5      NE
# 133         8.5           4.4         0.1           8.5      NE
# 134         8.5           4.4         0.1           8.5      NE
# 135         8.5           4.4         0.1           8.5      NE
# 136         8.5           4.4         0.1           8.5      NE
# 137         8.5           4.4         0.1           8.5      NE
# 138         8.5           4.4         0.1           8.5      NE
# 139         8.5           4.4         0.1           8.5      NE
#
# [140 rows x 46 columns]

# %%
TOTAL_price_avg = res_df.groupby(["price"]).mean()
rescount = res_df.groupby(["county_string"]).count()["name"].reset_index()
rescount.columns=['county_string', 'restaurant_count']
TOTAL_county_reviews = res_df.groupby(["county_string"]).review_count.sum().reset_index()
TOTAL_county_reviews.columns=["county_string","review_count"]
TOTAL_county_avg = res_df.groupby(res_df["county_string"]).mean().reset_index()

county_stats = TOTAL_county_avg.merge(TOTAL_county_reviews, on="county_string")
csdf = county_stats.merge(counties, on="county_string")
c_df = rescount.merge(csdf, on="county_string")
c_df
# Out:
#                    county_string  restaurant_count    rating     price  \
# 0          Bannock County, Idaho                44  3.568182  1.681818
# 1            Benton County, Iowa                 1  4.000000  1.000000
# 2  Bradford County, Pennsylvania                 5  3.800000  2.200000
# 3     Brule County, South Dakota                 8  3.625000  1.625000
# 4       Conejos County, Colorado                 5  4.000000  1.600000
# 5  Lafayette County, Mississippi                16  3.625000  1.562500
# 6    Lehigh County, Pennsylvania                46  4.043478  1.978261
# 7         Major County, Oklahoma                 2  3.750000  1.500000
# 8         Putnam County, Georgia                11  3.681818  1.636364
# 9          Storey County, Nevada                 2  4.000000  1.500000
#
#    CensusId_x  TotalPop_x     Men_x   Women_x  Hispanic_x  White_x   ...    \
# 0     16005.0     83604.0   41666.0   41938.0         7.7     85.3   ...
# 1     19011.0     25803.0   12888.0   12915.0         1.3     96.8   ...
# 2     42015.0     62228.0   30666.0   31562.0         1.4     96.2   ...
# 3     46015.0      5330.0    2621.0    2709.0         0.4     85.8   ...
# 4      8021.0      8249.0    4111.0    4138.0        54.4     43.3   ...
# 5     28071.0     51169.0   24919.0   26250.0         2.3     70.4   ...
# 6     42077.0    356756.0  173680.0  183076.0        21.1     68.5   ...
# 7     40093.0      7700.0    3854.0    3846.0         8.9     85.9   ...
# 8     13237.0     21247.0   10565.0   10682.0         6.6     65.3   ...
# 9     32029.0      3929.0    1882.0    2047.0         3.7     90.7   ...
#
#    OtherTransp_y  WorkAtHome_y  MeanCommute_y  Employed_y  PrivateWork_y  \
# 0            2.2           3.8           17.9       37206           73.0
# 1            1.9           5.1           23.9       13080           79.5
# 2            1.1           3.5           22.9       26689           82.7
# 3            2.2           8.3           13.9        2583           66.4
# 4            1.0           5.7           22.6        3021           65.8
# 5            2.0           2.9           17.7       22584           67.2
# 6            0.9           4.1           24.9      170448           87.0
# 7            2.9           3.3           21.9        3518           72.6
# 8            2.3           3.6           25.9        9448           77.2
# 9            0.0           6.6           27.9        1777           72.9
#
#    PublicWork_y  SelfEmployed_y  FamilyWork_y  Unemployment_y  Region
# 0          20.8             6.0           0.2             7.2      WC
# 1          13.0             7.4           0.1             4.7      MW
# 2           9.9             7.1           0.2             5.6      NE
# 3          16.3            15.4           1.9             2.6      MW
# 4          21.3            12.8           0.0             9.7      SW
# 5          27.4             5.4           0.0             8.4      SE
# 6           8.5             4.4           0.1             8.5      NE
# 7          15.1            11.5           0.9             5.4      SW
# 8          15.8             7.0           0.0             6.3      SE
# 9          16.4            10.7           0.0            10.3      WC
#
# [10 rows x 78 columns]

# %%
current_county="Lehigh County, Pennsylvania"
WCO = res_df.groupby(res_df["county_string"]).get_group(current_county)
WCObreakdown = pd.DataFrame(WCO["category"].value_counts()).T.reset_index()
WCOrate = pd.DataFrame(WCO["rating"].value_counts()).T.reset_index()
WCObreakdown["county_string"]=current_county
WCO_price_avg = WCO.groupby(res_df["price"]).mean()
WCO_price_count = WCO["price"].value_counts()
WCObreakdown
# Out:
#       index  American  Italian  Indian  Chinese  Mexican  \
# 0  category        20       15       5        3        3
#
#                  county_string
# 0  Lehigh County, Pennsylvania

# %%
comp_df = pd.DataFrame(columns=["Italian","Mexican","Chinese","American", "Indian","county_string"])
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.reset_index()
del comp_df["index"]
del comp_df["level_0"]
#comp_df["Totals"]=comp_df["Italian"]+comp_df["Mexican"]+comp_df["Chinese"]+comp_df["Indian"]+comp_df["American"]
comp_df
# Out:
#   American Chinese Indian Italian Mexican                county_string
# 0       20       3      5      15       3  Lehigh County, Pennsylvania
# 1       20       3      5      15       3  Lehigh County, Pennsylvania
# 2       20       3      5      15       3  Lehigh County, Pennsylvania
# 3       20       3      5      15       3  Lehigh County, Pennsylvania
# 4       20       3      5      15       3  Lehigh County, Pennsylvania
# 5       20       3      5      15       3  Lehigh County, Pennsylvania
# 6       20       3      5      15       3  Lehigh County, Pennsylvania
# 7       20       3      5      15       3  Lehigh County, Pennsylvania
# 8       20       3      5      15       3  Lehigh County, Pennsylvania

# %%
fig, axes = plt.subplots(3,3,figsize= (16,9))
for i, (idx, row) in enumerate(comp_df.set_index("county_string").iterrows()):
    ax = axes[i // 3, i % 3]
    row = row[row.gt(row.sum()*.01)]
    ax.pie(row, labels=row.index)
    ax.set_title(idx)
fig.subplots_adjust(wspace=1)

# %%
plt.show()

# %%
labels = ["Italian","Mexican","Chinese","American", "Indian"]
# Values of each group
bars =[[],[],[],[]]
for label in labels:
    df= res_df.loc[res_df["category"]==label, :]
    counts = df["price"].value_counts()
    for price in range(1,5):
        try:
            bars[price-1].append(counts[price])
        except: 
            bars[price-1].append(0)
print(bars[1])
# Out:
# [28, 8, 5, 42, 7]

# %%
from matplotlib import rc
sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})


# y-axis in bold
# rc('font', weight='bold')

figsize= (100, 100, 50)
 
# Values of each group
bars1 = bars[0]
bars2 = bars[1]
bars3 = bars[2]
bars4 = bars[3]
x = np.arange(len(bars1))


four_dolla=plt.bar(x, bars4, color="plum")
three_dolla=plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dolla=plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dolla=plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

plt.xticks(x, ["Italian","Mexican","Chinese","American", "Indian"])

plt.grid(axis='y')
plt.xlabel("Category")
plt.ylabel('Count')
plt.title('Number of $ per Category')
    
plt.legend((four_dolla[0], three_dolla[0],two_dolla[0], one_dolla[0]), ('4$', '3$','2$', '1$'), loc="best")


# Show graphic
plt.show()
plt.savefig("stacked.png")

# %%
region = ["NE","MW","WC","SW","SE"]
# Values of each group
r_bars =[[],[],[],[]]
for r in region:
    reg_bars= res_df.loc[res_df["Region"]==r, :]
    reg_counts = reg_bars["price"].value_counts()
    for price in range(1,5):
        try:
            r_bars[price-1].append(reg_counts[price])
        except: 
            r_bars[price-1].append(0)
print(r_bars)
# Out:
# [[6, 4, 16, 3, 13], [39, 5, 29, 4, 13], [6, 0, 1, 0, 0], [0, 0, 0, 0, 1]]

# %%
#### sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})

figsize= (100, 100, 50)
 
# Values of each group
bars1 = r_bars[0]
bars2 = r_bars[1]
bars3 = r_bars[2]
bars4 = r_bars[3]
x = np.arange(len(bars1))


four_dol = plt.bar(x, bars4, color="plum")
three_dol =plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dol =plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dol =plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

plt.xticks(x, ["NE","MW","WC","SW","SE","NE","WC","SE"])

plt.grid(axis='y')
plt.xlabel("Region")
plt.ylabel('Price Count')
plt.title('Number of $ per Region')

plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")

# Show graphic
plt.show()
plt.savefig("stacked2.png")
