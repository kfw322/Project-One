# %% [markdown]
# <h1>From the top!</h1>
#
# We decided to use the Yelp api, demographic census information, and education data to explore potential correlations. Below is an outline of our projec:
#
# <ul>
# <li>Import dependencies</li>
# <li>Read in CSV data files</li>
# <li>Define US regions based on states</li>
# <li>Create main DataFrame (res_df)</li>
# <li>Coded a for loop to make our API calls and append to res_df</li>
# <li>Exported res_df to a CSV file</li>
# <li>Cleaned up res_df (ex: combine American (new) and American (Traditional) </li>
# <li>Merged our res_df and our counties CSV file</li>
# <li>Examine category distribution across the US</li>
# <li>KYRUS? </li>
# <li>KYRUS?</li>
# <li>Display pie charts for each county thay show restaurant category distribution</li>
# <li>Examined price breakdown based on region and restaurant category</li>
# <li>Produced graphs to illustrate our findings</li>
# <li>MONICA - Compared Pricing and Income?</li>
# <li>MONICA - </li>
# <li>Catherine - EDUCATION</li>
# <li>Conclusions</li>
# <li>Limitations </li>
# <li>If we only had more time...</li>
# </ul>

# %% [markdown]
# <h3>Part 1: Initial Setup</h3>
#
# Below, we imported all of our dependencies including the yelpapi needed for the project. Next, we brought in all of our outside data files, These files include county data, census data, and education data. These were all source from government websites and were CSV files.
#
# Once the CSV files were read in, we modified them as needed to fit in out dataframe. To check the formatting, we used a print statement.

# %%
# !pip install yelpapi
# !pip install numpy
import yelpapi
import json
import requests
from  pprint import  pprint
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

#reading in county data
counties=pd.read_csv("acs2015_county_data.csv")
counties["county_string"] = counties["County"] + " County, " + counties["State"]
listofcounties = counties["county_string"].tolist()
#reading in zipcodes
zipcodes=pd.read_csv("zip_codes_states.csv")
zipcodes["county_string"] = zipcodes["county"] + " County, " + zipcodes["state"]
listofzipcodes=zipcodes["county_string"].unique().tolist()
counties.to_csv("counties.csv")
zipcodes.to_csv("zcs.csv")
fullcountylist = list(set(listofcounties) & set(listofzipcodes))
counties.head(1)
# Out:
# Requirement already satisfied: yelpapi in /Users/randi/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: requests in /Users/randi/anaconda3/lib/python3.6/site-packages (from yelpapi)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/randi/anaconda3/lib/python3.6/site-packages (from requests->yelpapi)
# Requirement already satisfied: numpy in /Users/randi/anaconda3/lib/python3.6/site-packages
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
#
#    Native           ...             OtherTransp  WorkAtHome  MeanCommute  \
# 0     0.4           ...                     1.3         1.8         26.5
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0     23986         73.6        20.9           5.5         0.0           7.6
#
#              county_string
# 0  Autauga County, Alabama
#
# [1 rows x 38 columns]

# %% [markdown]
# <h3>Part 1: County Setup</h3>
#
# In the framework portion, we established regions of the US that we will use later, created a new dataframe that holds out counties, and created a list to hold all the randomly generated countries. This will be more important later.

# %%
#creating regions
WC = ["Washington","Oregon","California","Nevada","Idaho"]
MW = ["Montana","Wyoming","North Dakota","South Dakota","Nebraska","Kansas","Minnesota","Iowa","Missouri",
      "Wisconsin","Illinois","Michigan","Indiana","Ohio","Kentucky"]
SW = ["Arizona","Utah","Colorado","New Mexico","Oklahoma","Texas"]
SE = ["Arkansas","Louisiana","Mississippi","Alabama","Tennessee","Virginia","West Virginia","North Carolina","South Carolina","Georgia","Florida"]
NE = ["District of Columbia","Pennsylvania","Maryland","Delaware","New Jersey","New York","Maine","New Hampshire","Vermont","Massachusetts","Rhode Island","Connecticut"]
counties["Region"]= np.where(counties["State"].isin(WC),'WC',
                    np.where(counties["State"].isin(MW),'MW',
                    np.where(counties["State"].isin(SW),'SW',
                    np.where(counties["State"].isin(SE),'SE',
                    np.where(counties["State"].isin(NE),'NE', 
                             'other')))))

# %%
#counties.groupby(["Region"]).sum()["TotalPop"]
cdf = pd.DataFrame(counties,columns=["county_string","Region"])
WClist = (cdf.groupby("Region").get_group("WC")["county_string"]).tolist()
MWlist = (cdf.groupby("Region").get_group("MW")["county_string"]).tolist()
SWlist = (cdf.groupby("Region").get_group("SW")["county_string"]).tolist()
SElist = (cdf.groupby("Region").get_group("SE")["county_string"]).tolist()
NElist = (cdf.groupby("Region").get_group("NE")["county_string"]).tolist()

sample_list = []
sample_list.extend(random.sample(list(set(WClist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(MWlist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(SWlist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(SElist) & set(fullcountylist)),2))
sample_list.extend(random.sample(list(set(NElist) & set(fullcountylist)),2))
sample_list
# Out:
# ['Kern County, California',
#  'Kitsap County, Washington',
#  'Estill County, Kentucky',
#  'Douglas County, Missouri',
#  'Logan County, Colorado',
#  'Brazoria County, Texas',
#  'Sumter County, South Carolina',
#  'Benton County, Tennessee',
#  'Frederick County, Maryland',
#  'Essex County, Massachusetts']

# %% [markdown]
# <h3>Part 1: Establishing the Main DataFrame</h3>
#
# After reading in the county data and creating regions, we established our primary dataframe. We named the dataframe res_df. This dataframe will be used throughout the project.

# %%
res_df = pd.DataFrame(columns=["name","zipcode","county_string","rating","review_count","category","price","region"])
res_df
# Out:
# Empty DataFrame
# Columns: [name, zipcode, county_string, rating, review_count, category, price, region]
# Index: []

# %% [markdown]
# <h3>Part 1: The Framework - Kyrus For Loop</h3>
#
# Kyrus was able to build the primary framework for our project. With multiple nested for loops, Kyrus was able to make the Yelp API call, loop through the first 50 pages for each restuarunt type, then red in that data and append it to the res_df dataframe.
#
# Kyrus also included a try/ecxcept option as a way to check or verify the code was working and pulling in the data correctly.

# %%
r = 0
for c in sample_list:
    county_string = str(c)
    for term in ["Italian","Mexican","Chinese","American (Traditional)","American (New)","Indian"]:
        #we are allowed 5000 queries per 24 hours. if we run out, we can create another. till then, use this
        yelpkey="IXRN_1GI8f8J9Kj5O5GciqeyFSWR5RMh41_rADGy1KrtQ5ZABGGZEkWwot5mOka0NlzlNxXPmzYXLWk88oOV0N_YxD1MSW4kQRfJnFrwfHLtKrr2HcsjLo6uWBzAWnYx"
        try:
            offset=0
            for loopcount in range(5):
                
                response = requests.get(url="https://api.yelp.com/v3/businesses/search", 
                       params= {"location": county_string,"term": term, "limit":"50", "offset": offset}, 
                       headers={'Authorization': 'bearer %s' % yelpkey})
                responsejson = response.json()
                offset += 50
                try:
                    count=0
            
                    for x in range(0,49):
                        for y in range(0,len(responsejson["businesses"][x]["categories"])):
                            if ((str(responsejson["businesses"][x]["categories"][y]["title"])==str(term)) and 
                                (responsejson["businesses"][x]["review_count"] > 0)):
                                zc = int(responsejson["businesses"][x]["location"]["zip_code"])
                                if (zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0]== county_string):
                                    
                                    print("\n",responsejson["businesses"][x]["name"],
                                        responsejson["businesses"][x]["location"]["zip_code"],
                                        zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0],
                                        responsejson["businesses"][x]["rating"],
                                        responsejson["businesses"][x]["review_count"],
                                        responsejson["businesses"][x]["categories"][y]["title"])
                                    res_df.loc[r]=[responsejson["businesses"][x]["name"],
                                        str(zc),
                                        county_string,
                                        responsejson["businesses"][x]["rating"],
                                        responsejson["businesses"][x]["review_count"],
                                        term,
                                        responsejson["businesses"][x]["price"],
                                        "region"
                                                  ]
                                    count += 1
                                    r += 1
                except:
                    
                    break
    
                print("End of list. Found", count, term, "restaurants in", county_string)
        except:
            print("Error: this shouldn't happen")
            break
# Out:
#  Uricchio's Trattoria 93301 Kern County, California 4.0 288 Italian
#
#  Luigis 93305 Kern County, California 4.0 246 Italian
#
#  Frugatti's Italian Eatery 93309 Kern County, California 4.0 430 Italian
#
#  Perfetto Italian Restaurant 93561 Kern County, California 4.5 65 Italian
#
#  Sorella Ristorante Italiano 93313 Kern County, California 3.5 194 Italian
#
#  Joseph's Italian Restaurant 93301 Kern County, California 3.5 143 Italian
#
#  Little Italy 93311 Kern County, California 3.5 101 Italian
#
#  Rosa's Italian Restaurant 93306 Kern County, California 3.5 143 Italian
#
#  That's Italian 93238 Kern County, California 4.0 92 Italian
#
#  Sandrini's Public House 93301 Kern County, California 3.5 123 Italian
#
#  Olive Garden Italian Restaurant 93309 Kern County, California 3.5 254 Italian
#
#  Mama Tosca's Ristorante Italiano 93311 Kern County, California 3.0 91 Italian
#
#  Giovanni's Italian Eatery 93263 Kern County, California 4.0 35 Italian
#
#  Slice of Italy 93301 Kern County, California 3.5 149 Italian
#
#  TK's Pizza & Pasta 93561 Kern County, California 4.0 192 Italian
#
#  Narducci's Cafe 93305 Kern County, California 3.5 88 Italian
#
#  Romano's Macaroni Grill 93312 Kern County, California 3.5 156 Italian
#
#  Slice of Italy 93312 Kern County, California 3.5 246 Italian
#
#  Farrah's Pizza 93307 Kern County, California 4.0 9 Italian
#
#  Caesar's Italian Delicatessen 93312 Kern County, California 4.0 84 Italian
#
#  Caesars II Delicatessen 93309 Kern County, California 4.0 26 Italian
#
#  PizzaRev 93311 Kern County, California 4.0 135 Italian
#
#  Magoo's Pizza 93309 Kern County, California 5.0 2 Italian
#
#  Nuestro Mexico Restaurant 93301 Kern County, California 4.5 681 Mexican
#
#  El Jacalito Restaurant 93241 Kern County, California 4.0 39 Mexican
#
#  El Pueblo 93241 Kern County, California 4.0 26 Mexican
#
#  La Costa Mariscos 93301 Kern County, California 4.0 432 Mexican
#
#
#  La Poblanita Mexican Restaurant 98312 Kitsap County, Washington 4.5 63 Mexican
#
#  El Sabor Casero 98370 Kitsap County, Washington 4.5 29 Mexican
#
#  El Balcon 98337 Kitsap County, Washington 4.5 410 Mexican
#
#  Puerto Vallarta 98346 Kitsap County, Washington 3.5 89 Mexican
#
#  Casa Luna 98370 Kitsap County, Washington 3.5 114 Mexican
#
#  Isla Bonita 98110 Kitsap County, Washington 3.5 119 Mexican
#
#  La Línda Cocina 98370 Kitsap County, Washington 3.0 6 Mexican
#
#  Mandarin Chinese Restaurant 98383 Kitsap County, Washington 3.0 120 Chinese
#
#  Golden Star Chinese & American Restaurant 98310 Kitsap County, Washington 4.0 88 Chinese
#
#  China Wok 98312 Kitsap County, Washington 4.0 60 Chinese
#
#  Emperor's Palace 98312 Kitsap County, Washington 3.0 77 Chinese
#
#  Golden Grill On the Bay 98366 Kitsap County, Washington 3.0 85 Chinese
#
#  Golden Grill Mongolian Barbeque 98383 Kitsap County, Washington 3.5 62 Chinese
#
#  Phoenix Orchard 98370 Kitsap County, Washington 4.0 8 Chinese
#
#  Shady Jack's Bar and Grill 98383 Kitsap County, Washington 4.0 52 American (Traditional)
#
#  Cash Brewing Company 98383 Kitsap County, Washington 4.0 208 American (Traditional)
#
#  The Junction Diner 98370 Kitsap County, Washington 4.5 59 American (Traditional)
#
#  Ozzie's Place 98383 Kitsap County, Washington 4.0 5 American (Traditional)
#
#  The Dugout Sports Bar And Grill 98312 Kitsap County, Washington 3.5 21 American (Traditional)
#
#  The Garage Bar & Grill 98312 Kitsap County, Washington 4.0 142 American (Traditional)
#
#  Mrs Muir's House 98370 Kitsap County, Washington 4.5 10 American (Traditional)
#
#  Brick House Bar & Grill 98366 Kitsap County, Washington 3.5 28 American (Traditional)
#
#  Sully's Bistro & Bar 98392 Kitsap County, Washington 4.5 40 American (Traditional)
#
#  The Harbour Public House 98110 Kitsap County, Washington 3.5 634 American (Traditional)
#
#  The Brass Kraken 98370 Kitsap County, Washington 3.0 68 American (Traditional)
#
#  Green Light Diner 98370 Kitsap County, Washington 4.0 202 American (Traditional)
#
#  Elmer's Restaurant 98370 Kitsap County, Washington 3.5 115 American (Traditional)
#
#  Doc's Marina Grill 98110 Kitsap County, Washington 3.5 396 American (Traditional)
#
#  Hop Jack's 98383 Kitsap County, Washington 4.0 263 American (Traditional)
#
#  Streamliner Diner 98110 Kitsap County, Washington 4.0 297 American (Traditional)
#
#  Larson's Restaurant & Lounge 98310 Kitsap County, Washington 4.0 18 American (Traditional)
#
#  World of Beer 98383 Kitsap County, Washington 3.0 40 American (Traditional)
#
#  Meadowmeer Grill 98110 Kitsap County, Washington 4.0 5 American (Traditional)
#
#  Envy Bar and Grill 98370 Kitsap County, Washington 3.5 41 American (Traditional)
#
#  McCloud's Grill House 98310 Kitsap County, Washington 3.0 75 American (Traditional)
#
#  Manette Yacht Club Bar 98337 Kitsap County, Washington 4.5 8 American (Traditional)
#
#  Bremerton Bar & Grill 98337 Kitsap County, Washington 3.0 344 American (Traditional)
#
#  Dickey's Barbecue Pit 98370 Kitsap County, Washington 2.5 44 American (Traditional)
#
#  Everybody's American Cookhouse & Sports Theater 98366 Kitsap County, Washington 3.5 70 American (Traditional)
#
#  Uncle Dave's Cafe 98366 Kitsap County, Washington 4.0 128 American (Traditional)
#
#  Our Place Pub & Eatery 98383 Kitsap County, Washington 3.5 25 American (Traditional)
#
#  Bethel Square Restaraunt & Lounge 98366 Kitsap County, Washington 3.5 17 American (Traditional)
#
#  The Filling Station 98346 Kitsap County, Washington 3.5 59 American (Traditional)
#
#  Jimmy D's Hwy 3 Roadhouse 98312 Kitsap County, Washington 3.5 30 American (Traditional)
#
#  Putters At Rolling Hills Golf Course 98311 Kitsap County, Washington 4.0 7 American (Traditional)
#
#  Stoddy's Bar & Grill 98312 Kitsap County, Washington 4.0 1 American (Traditional)
#
#  Oak Table Cafe 98383 Kitsap County, Washington 4.5 375 American (New)
#
#  Agate Pass Cafe 98392 Kitsap County, Washington 4.5 101 American (New)
#
#  The Loft at Latitude Forty Seven Seven 98370 Kitsap County, Washington 3.0 272 American (New)
#
#  Honor Bar 98310 Kitsap County, Washington 4.5 79 American (New)
#
#  Silver City Restaurant & Brewery 98383 Kitsap County, Washington 4.0 604 American (New)
#
#  Blazing Onion Burger Company 98383 Kitsap County, Washington 3.0 175 American (New)
#
#  Chipmunk Grill 98383 Kitsap County, Washington 4.0 29 American (New)
#
#  The Dock Bar & Eatery 98366 Kitsap County, Washington 4.0 63 American (New)
#
#  Bay Street Bistro 98366 Kitsap County, Washington 4.5 125 American (New)
#
#  BIMA Bistro at Bainbridge Island Museum 98110 Kitsap County, Washington 4.5 10 American (New)
#
#  Toro Lounge 98337 Kitsap County, Washington 4.0 196 American (New)
#
#  ChocMo 98370 Kitsap County, Washington 4.0 92 American (New)
#
#  The Beach House Bar 98110 Kitsap County, Washington 3.0 23 American (New)
#
#  Mossback 98346 Kitsap County, Washington 4.5 78 American (New)
#
#  Sugar Studios Crepe Cafe 98383 Kitsap County, Washington 4.0 37 American (New)
#
#  19th Hole Bar & Grill 98312 Kitsap County, Washington 4.0 32 American (New)
#
#  Jake's Pickup 98110 Kitsap County, Washington 4.5 119 American (New)
#
#  Molly Ward Gardens 98370 Kitsap County, Washington 4.0 45 American (New)
#
#  The Manor House Restaurant 98110 Kitsap County, Washington 4.0 40 American (New)
#
#  Little Boston Bistro 98346 Kitsap County, Washington 4.5 21 American (New)
#
#  Larson's Restaurant & Lounge 98310 Kitsap County, Washington 4.0 18 American (New)
#
#  The Plate & Pint 98110 Kitsap County, Washington 3.5 108 American (New)
#
#  The Daily Dish 98337 Kitsap County, Washington 4.0 1 American (New)
#
#  Punjab Indian Cuisine 98370 Kitsap County, Washington 4.5 105 Indian
#
#  The Curry Indian Cuisine & Lounge 98337 Kitsap County, Washington 4.5 133 Indian
#
#  Spice Route Cuisine of India 98110 Kitsap County, Washington 3.5 94 Indian
#  Steam Engine Pizza Pub 40336 Estill County, Kentucky 4.5 7 Italian
#
#  Pizza Hut 40336 Estill County, Kentucky 4.5 3 Italian
#
#
#  Chipotle Mexican Grill 21704 Frederick County, Maryland 3.5 50 Mexican
#
#  Chipotle Mexican Grill 21701 Frederick County, Maryland 2.5 46 Mexican
# End of list. Found 4 Mexican restaurants in Frederick County, Maryland
#
#  Chipotle Mexican Grill 21702 Frederick County, Maryland 3.5 3 Mexican
#
#  Peking Gourmet 21704 Frederick County, Maryland 4.0 63 Chinese
#
#  A Asia Restaurant 21701 Frederick County, Maryland 4.5 30 Chinese
#
#  Great Wall Chinese Restaurant 21701 Frederick County, Maryland 4.0 22 Chinese
#
#  Hunan Gourmet Restaurant 21701 Frederick County, Maryland 3.5 37 Chinese
#
#  China Garden 21701 Frederick County, Maryland 3.5 86 Chinese
#
#  China Wok 21793 Frederick County, Maryland 4.0 16 Chinese
#
#  Asian Cafe 21701 Frederick County, Maryland 3.5 24 Chinese
#
#  Great Wall Chinese Restaurant 21702 Frederick County, Maryland 3.5 21 Chinese
#
#  Asian Bistro 21774 Frederick County, Maryland 4.0 72 Chinese
#
#  Asian Number 1 21793 Frederick County, Maryland 3.5 20 Chinese
#
#  Eastern 89 21703 Frederick County, Maryland 4.0 19 Chinese
#
#  Big Chef Chinese Kitchen 21702 Frederick County, Maryland 4.0 12 Chinese
#
#  Simply Asia 21788 Frederick County, Maryland 4.0 47 Chinese
#
#  MC Asian Bistro 21703 Frederick County, Maryland 3.5 46 Chinese
#
#  Beijing Restaurant 21701 Frederick County, Maryland 3.5 15 Chinese
#
#  Charlies Restaurant 21701 Frederick County, Maryland 2.5 31 Chinese
#
#  Asian Cafe 21769 Frederick County, Maryland 3.5 39 Chinese
#
#  Great Wall Chinese Restaurant 21701 Frederick County, Maryland 3.5 11 Chinese
#
#  Chef Lin Buffet 21701 Frederick County, Maryland 3.5 69 Chinese
#
#  China Sea 21703 Frederick County, Maryland 3.5 16 Chinese
#
#  New Win Hing 21788 Frederick County, Maryland 3.0 8 Chinese
#
#  Peking Palace 21788 Frederick County, Maryland 3.5 8 Chinese
#
#  Nannie's Diner 21701 Frederick County, Maryland 4.5 22 American (Traditional)
#
#  The Furnace Bar & Grill 21788 Frederick County, Maryland 3.5 14 American (Traditional)
#
#  Dempseys Grille 21769 Frederick County, Maryland 4.5 36 American (Traditional)
#
#  Vintage 21774 Frederick County, Maryland 4.0 174 American (Traditional)
#
#  The Real Thurmont Kountry Kitchen 21788 Frederick County, Maryland 4.0 74 American (Traditional)
#
#  Callahan's Seafood Bar & Grill 21702 Frederick County, Maryland 4.0 92 American (Traditional)
#
#  Dj's Catering & Services 21717 Frederick County, Maryland 5.0 23 American (Traditional)
#
#  Trout's Towne Restaurant 21798 Frederick County, Maryland 4.5 26 American (Traditional)
#
#  Waffle House 21701 Frederick County, Maryland 5.0 4 American (Traditional)
#
#  Shamrock Restaurant 21788 Frederick County, Maryland 3.5 119 American (Traditional)
#
#  Morgan's American Grill 21774 Frederick County, Maryland 3.5 70 American (Traditional)
#
#  Cafe Bueno 21701 Frederick County, Maryland 4.5 340 American (Traditional)
#
#  Magoo's Pub & Eatery 21701 Frederick County, Maryland 3.0 63 American (Traditional)
#
#  Beef N Buns N Paradise 21701 Frederick County, Maryland 4.5 170 American (Traditional)
#
#  Bollinger's Restaurant 21788 Frederick County, Maryland 3.5 27 American (Traditional)
#
#  Brewer's Alley 21701 Frederick County, Maryland 3.5 417 American (Traditional)
#
#  Bennigans 21701 Frederick County, Maryland 3.0 51 American (Traditional)
#
#  The Palms 21727 Frederick County, Maryland 4.0 22 American (Traditional)
#
#  JoJo's Restaurant & Tap House 21701 Frederick County, Maryland 4.0 167 American (Traditional)
#
#  The Main Cup 21769 Frederick County, Maryland 4.0 106 American (Traditional)
#
#  Airways Inn of Frederick 21701 Frederick County, Maryland 3.5 33 American (Traditional)
#
#  Mountain Gate Family Restaurant 21788 Frederick County, Maryland 3.0 88 American (Traditional)
#
#  Doc Geiser's 21702 Frederick County, Maryland 3.5 15 American (Traditional)
#
#  Chicken Basket 21702 Frederick County, Maryland 3.0 23 American (Traditional)
#
#  Old Town Diner 21773 Frederick County, Maryland 2.5 36 American (Traditional)
#
#  Cryin' Johnnies 21771 Frederick County, Maryland 4.0 39 American (Traditional)
#
#  Olde Town Restaurant 21771 Frederick County, Maryland 4.0 43 American (Traditional)
#
#  Glory Days Grill 21702 Frederick County, Maryland 3.5 89 American (Traditional)
#
#  Beef 'O' Brady's 21703 Frederick County, Maryland 3.0 35 American (Traditional)
#
#  IHOP 21701 Frederick County, Maryland 3.0 34 American (Traditional)
#
#  Applebee's Grill + Bar 21703 Frederick County, Maryland 2.5 28 American (Traditional)
#
#  Potomac Street Grill 21716 Frederick County, Maryland 4.5 109 American (Traditional)
#
#  Charlies Restaurant 21701 Frederick County, Maryland 2.5 31 American (Traditional)
#
#  Monkey La La 21704 Frederick County, Maryland 4.0 14 American (Traditional)
#
#  Atlantic Grille 21704 Frederick County, Maryland 3.5 63 American (Traditional)
# End of list. Found 35 American (Traditional) restaurants in Frederick County, Maryland
#
#  Golden Corral 21703 Frederick County, Maryland 3.5 52 American (Traditional)
#
#  Bob Evans 21702 Frederick County, Maryland 2.5 21 American (Traditional)
#
#  TGI Fridays 21704 Frederick County, Maryland 3.0 86 American (Traditional)
#
#  Red Lobster 21703 Frederick County, Maryland 3.0 39 American (Traditional)
#
#  Pennys Diner 21716 Frederick County, Maryland 3.0 29 American (Traditional)
#
#  Tilted Kilt Pub & Eatery 21703 Frederick County, Maryland 2.5 78 American (Traditional)
#
#  The Beacon 21704 Frederick County, Maryland 3.5 12 American (Traditional)
#
#  Cracker Barrel Old Country Store 21704 Frederick County, Maryland 3.5 112 American (Traditional)
#
#  IHOP 21704 Frederick County, Maryland 3.0 30 American (Traditional)
#
#  Boston Market 21703 Frederick County, Maryland 3.0 15 American (Traditional)
#
#  LongHorn Steakhouse 21704 Frederick County, Maryland 3.5 64 American (Traditional)
#
#  Ott House 21727 Frederick County, Maryland 4.0 67 American (Traditional)
#
#  Olde Towne Tavern 21701 Frederick County, Maryland 3.5 22 American (Traditional)
#
#  Ruby Tuesday 21704 Frederick County, Maryland 2.5 30 American (Traditional)
#
#  Waffle House 21704 Frederick County, Maryland 3.5 53 American (Traditional)
#
#  Chili's 21704 Frederick County, Maryland 3.0 20 American (Traditional)
#
#  Buffalo Wild Wings 21701 Frederick County, Maryland 3.0 77 American (Traditional)
#
#  Valley Grill Sports Bar 21769 Frederick County, Maryland 3.0 17 American (Traditional)
#
#  Carriage House Inn 21727 Frederick County, Maryland 4.0 49 American (Traditional)
#
#  Denny's 21701 Frederick County, Maryland 3.0 31 American (Traditional)
#
#  Watson's Carry Out & Catering 21755 Frederick County, Maryland 3.0 9 American (Traditional)
#
#  Uno Pizzeria & Grill 21704 Frederick County, Maryland 3.5 51 American (Traditional)
#
#  Jacksons 21701 Frederick County, Maryland 2.0 1 American (Traditional)
#  Hootch and Banter 21701 Frederick County, Maryland 4.5 227 American (New)
#
#  Oscar's Ale House 21701 Frederick County, Maryland 4.5 38 American (New)
#
#  The Braddock Inn 21714 Frederick County, Maryland 4.0 22 American (New)
#
#  Ragin' Reef 21701 Frederick County, Maryland 4.5 85 American (New)
#
#  Firestone's Culinary Tavern 21701 Frederick County, Maryland 4.0 238 American (New)
#
#  The Blue Side Tavern 21701 Frederick County, Maryland 3.5 87 American (New)
#
#  Volt 21701 Frederick County, Maryland 4.0 785 American (New)
#
#  Bolder 21771 Frederick County, Maryland 4.0 72 American (New)
#
#  The Orchard 21701 Frederick County, Maryland 4.0 239 American (New)
#
#  The Tasting Room 21701 Frederick County, Maryland 4.0 287 American (New)
#
#  Walkersville Diner 21793 Frederick County, Maryland 2.5 24 American (New)
#
#  Padmini's Curry Grill 21701 Frederick County, Maryland 4.5 97 Indian
#
#  Agra Palace 21702 Frederick County, Maryland 4.5 29 Indian
#
#  Tulip Grill 21703 Frederick County, Maryland 4.5 109 Indian
#
#  Clay Oven 21703 Frederick County, Maryland 4.0 125 Indian
#
#  Delhi 6 Indian cuisine 21704 Frederick County, Maryland 4.0 120 Indian
#
#  Padmini's Curry Grill 21704 Frederick County, Maryland 4.5 26 Indian
#
#  Grace of India 21704 Frederick County, Maryland 4.5 10 Indian
#
#  Firenze Trattoria 01970 Essex County, Massachusetts 4.5 189 Italian
#
#  Evviva Cucina 01915 Essex County, Massachusetts 4.0 54 Italian
#
#  Toscana Bar Italiano 01915 Essex County, Massachusetts 4.0 69 Italian
#
#  Giuseppe's Fresh Pasta & Fine Food 01950 Essex County, Massachusetts 4.5 112 Italian
#
#  Bella Verona 01970 Essex County, Massachusetts 4.0 222 Italian
#
#  Petrillo's Italian Kitchen 01960 Essex County, Massachusetts 4.0 135 Italian
#
#  Daniella's Cafe and Market 01923 Essex County, Massachusetts 4.0 145 Italian
#
#  Bambolina Restaurant 01970 Essex County, Massachusetts 4.5 212 Italian
#
#  Casa Mia Cucina Italiana 01945 Essex County, Massachusetts 4.5 40 Italian
#
#  Rossetti Restaurant 01901 Essex County, Massachusetts 4.5 140 Italian
#
#  Italiano Restaurant and Bar 01930 Essex County, Massachusetts 3.0 23 Italian
#
#  Marco's Restaurant 01960 Essex County, Massachusetts 4.0 154 Italian
#
#  Alto Forno 01960 Essex County, Massachusetts 4.5 41 Italian
#
#  The Causeway Restaurant 01930 Essex County, Massachusetts 4.0 465 Italian
#
#  I Pazzi 01923 Essex County, Massachusetts 4.0 92 Italian
#
#  Ponte Vecchio Restaurant 01923 Essex County, Massachusetts 3.5 70 Italian
#
#  Lo Grasso's Cafe & Bistro 01966 Essex County, Massachusetts 4.0 33 Italian
#
#  Antique Table 01902 Essex County, Massachusetts 4.0 154 Italian
#
#  Osteria Peppino Pizzeria 01983 Essex County, Massachusetts 4.0 29 Italian
#
#  Dicor  Italian & Argentinian Restaurant 01845 Essex County, Massachusetts 4.5 35 Italian
#
#  Toscana's Ristorante 01960 Essex County, Massachusetts 3.5 134 Italian
#
#  Victor's Italian Restaurant 01906 Essex County, Massachusetts 4.5 85 Italian
#
#  Ristorante Molise 01913 Essex County, Massachusetts 4.0 58 Italian
#
#  Tonno 01930 Essex County, Massachusetts 4.0 68 Italian
#
#  Blue Marlin Grille 01929 Essex County, Massachusetts 4.0 74 Italian
#
#  Andiamo Restaurant & Bar 01950 Essex County, Massachusetts 3.5 114 Italian
#
#  Cafe Salerno 01915 Essex County, Massachusetts 4.0 29 Italian
#
#  Adriatic Restaurant & Bar 01970 Essex County, Massachusetts 4.0 176 Italian
#
#  Chianti Cafe 01915 Essex County, Massachusetts 3.5 111 Italian
#
#  Caffé Italia 01945 Essex County, Massachusetts 3.5 56 Italian
#
#  Olivia's 01832 Essex County, Massachusetts 4.0 65 Italian
# End of list. Found 31 Italian restaurants in Essex County, Massachusetts
#
#  Joseph's Trattoria Bakery Cafe 01835 Essex County, Massachusetts 4.0 116 Italian
#
#  Teresa's Italian Eatery & Deli 01949 Essex County, Massachusetts 3.0 161 Italian
#
#  LaRosa's 01810 Essex County, Massachusetts 4.0 125 Italian
#
#  Carmaleno's Pushcart Restaurant 01906 Essex County, Massachusetts 4.0 44 Italian
#
#  Calitri's Italian Cuisine 01923 Essex County, Massachusetts 3.0 47 Italian
#
#  Spaziano's Pizzeria Catering 01832 Essex County, Massachusetts 4.5 51 Italian
#
#  Old Tyme Italian Cuisine 01905 Essex County, Massachusetts 4.0 47 Italian
#
#  Paradiso Ristorante 01907 Essex County, Massachusetts 4.0 39 Italian
#
#  Andolini's 01810 Essex County, Massachusetts 3.5 79 Italian
#
#  Phat Cats Bistro 01913 Essex County, Massachusetts 4.5 123 Italian
#
#  Off the Vine Tuscan Grille 01969 Essex County, Massachusetts 3.5 52 Italian
#
#  La Vita Mia 01906 Essex County, Massachusetts 3.5 81 Italian
#
#  Bertini's Restaurant 01970 Essex County, Massachusetts 3.5 31 Italian
# End of list. Found 13 Italian restaurants in Essex County, Massachusetts
#
#  Salem Green Tomato 01970 Essex County, Massachusetts 4.5 7 Italian
#
#  Buono Bistro 01845 Essex County, Massachusetts 3.5 118 Italian
#
#  Supino's Restaurant 01923 Essex County, Massachusetts 2.5 72 Italian
#
#  Carrabba's Italian Grill 01960 Essex County, Massachusetts 3.0 108 Italian
#
#  Butch's Uptown 01830 Essex County, Massachusetts 4.0 204 Italian
#
#  Caffe Paolina 01907 Essex County, Massachusetts 3.5 31 Italian
#
#  Pizzeria Romano's 01945 Essex County, Massachusetts 4.0 36 Italian
#
#  Polcari's Restaurant 01906 Essex County, Massachusetts 3.5 195 Italian
#
#  Rosaria 01906 Essex County, Massachusetts 3.5 82 Italian
#
#  Orzo Trattoria 01845 Essex County, Massachusetts 3.0 93 Italian
#
#  Sam & Joe's Restaurant 01923 Essex County, Massachusetts 3.0 57 Italian
#
#  Cafe Avellino 01907 Essex County, Massachusetts 4.0 14 Italian
#
#  Capri Seaside Italian Grille and Bar 01952 Essex County, Massachusetts 3.0 58 Italian
#
#  Victor's Italian Cuisine 01906 Essex County, Massachusetts 3.0 148 Italian
#
#  Bertucci's 01915 Essex County, Massachusetts 2.5 48 Italian
#
#  Enzo's Pizzeria 01901 Essex County, Massachusetts 4.0 54 Italian
# End of list. Found 16 Italian restaurants in Essex County, Massachusetts
#
#  Gallo Nero 01960 Essex County, Massachusetts 3.5 59 Italian
#
#  Chama Grill 01845 Essex County, Massachusetts 4.0 118 Italian
#
#  Tony's Pizza 01945 Essex County, Massachusetts 4.0 25 Italian
#
#  Borrelli's Italian Delicatessen 01844 Essex County, Massachusetts 4.0 46 Italian
#
#  Salvatore's Restaurant 01810 Essex County, Massachusetts 3.0 88 Italian
#
#  Volo Craft Pizza 01907 Essex County, Massachusetts 5.0 32 Italian
# End of list. Found 6 Italian restaurants in Essex County, Massachusetts
#
#  Davios Northern Italian Steakhouse 01940 Essex County, Massachusetts 3.5 219 Italian
#
#  Salvatore's Restaurant 01843 Essex County, Massachusetts 3.0 160 Italian
#
#  Krueger Flatbread 01832 Essex County, Massachusetts 4.0 178 Italian
#
#  Santarpio's Pizza 01960 Essex County, Massachusetts 3.0 268 Italian
#
#  Comello's 01945 Essex County, Massachusetts 2.5 3 Italian
#
#  La Victoria Taqueria 01915 Essex County, Massachusetts 4.5 228 Mexican
#
#  El Tapatio 01969 Essex County, Massachusetts 4.0 89 Mexican
#
#  Casa Vallarta 01906 Essex County, Massachusetts 4.5 235 Mexican
#
#  En Fuego Cocina Mexicana 01938 Essex County, Massachusetts 3.0 183 Mexican
#
#  En Fuego Cocina Mexicana 01915 Essex County, Massachusetts 3.5 36 Mexican
#
#  The NexMex Thing 01960 Essex County, Massachusetts 4.5 62 Mexican
#
#  Howling Wolf Taqueria 01970 Essex County, Massachusetts 4.0 682 Mexican
#
#  Tacos Lupita 01930 Essex County, Massachusetts 4.0 78 Mexican
#
#  BuenoMalo 01810 Essex County, Massachusetts 4.0 38 Mexican
#
#  Jalapeno's Authentic Mexican Food 01930 Essex County, Massachusetts 3.5 96 Mexican
#
#  Metzy's Cantina 01950 Essex County, Massachusetts 4.0 122 Mexican
#
#  Casa Corona 01945 Essex County, Massachusetts 3.5 100 Mexican
#
#  Lola's Mex Cocina 01833 Essex County, Massachusetts 3.0 10 Mexican
#
#  Fuloon 01915 Essex County, Massachusetts 4.5 73 Chinese
#
#  Gourmet Garden 01915 Essex County, Massachusetts 3.5 59 Chinese
#
#  Su-Chang's Restaurant 01960 Essex County, Massachusetts 4.0 172 Chinese
#
#  Happy Garden Danvers 01923 Essex County, Massachusetts 4.0 67 Chinese
#
#  May Flower 01938 Essex County, Massachusetts 4.0 40 Chinese
#
#  Yang Ming II 01913 Essex County, Massachusetts 4.0 18 Chinese
#
#  Family's Chinese Restaurant & Bar 01952 Essex County, Massachusetts 4.0 67 Chinese
#
#  Salem Lowe 01970 Essex County, Massachusetts 4.0 32 Chinese
#
#  Green Tea 01960 Essex County, Massachusetts 3.5 80 Chinese
#
#  Horizon Chinese Restaurant 01930 Essex County, Massachusetts 3.5 22 Chinese
#
#  Sugar Cane 01960 Essex County, Massachusetts 4.0 172 Chinese
#
#  Shoyu Chinese & Japanese cuisine 01906 Essex County, Massachusetts 4.5 112 Chinese
#
#  Yan's China Bistro 01907 Essex County, Massachusetts 4.0 62 Chinese
#
#  Lee Chen Chinese Cuisine 01843 Essex County, Massachusetts 4.0 108 Chinese
#
#  Majestic Dragon 01938 Essex County, Massachusetts 3.0 27 Chinese
#
#  Iron Chef 01923 Essex County, Massachusetts 3.5 46 Chinese
#
#  China Jade Restaurant 01915 Essex County, Massachusetts 3.0 55 Chinese
#
#  I Yit Ho Restaurant 01960 Essex County, Massachusetts 4.0 23 Chinese
#
#  Beverly Jade 01915 Essex County, Massachusetts 3.5 45 Chinese
#
#  Midori 01930 Essex County, Massachusetts 3.5 34 Chinese
#
#  China River Restaurant 01915 Essex County, Massachusetts 4.0 27 Chinese
#
#  Shunju 01845 Essex County, Massachusetts 3.5 63 Chinese
#
#  Mikado 01915 Essex County, Massachusetts 3.5 114 Chinese
#
#  Gourmet Garden 01907 Essex County, Massachusetts 3.5 129 Chinese
#
#  Hong Kong Cafe 01923 Essex County, Massachusetts 3.0 35 Chinese
#
#  Good Taste 01938 Essex County, Massachusetts 3.0 11 Chinese
#
#  Tea Garden Restaurant 01834 Essex County, Massachusetts 3.0 35 Chinese
#
#  Fen Yang House 01945 Essex County, Massachusetts 3.5 30 Chinese
#
#  Honga Restaurant 01970 Essex County, Massachusetts 3.5 40 Chinese
#
#  Asia Taste 01960 Essex County, Massachusetts 4.0 21 Chinese
#
#  Mandarin Danvers 01923 Essex County, Massachusetts 3.5 70 Chinese
#
#  China Wok 01915 Essex County, Massachusetts 2.5 14 Chinese
#
#  Li's Fine Asian Cuisine & Sushi Bar 01830 Essex County, Massachusetts 4.0 116 Chinese
# End of list. Found 33 Chinese restaurants in Essex County, Massachusetts
#  China Villa of Middleton 01949 Essex County, Massachusetts 2.5 29 Chinese
#
#  Hans Garden 01832 Essex County, Massachusetts 3.5 51 Chinese
#
#  Lucky Dragon Restaurant 01904 Essex County, Massachusetts 3.5 22 Chinese
#
#  Kowloon 01906 Essex County, Massachusetts 3.0 779 Chinese
#
#  Hong Kong King 01970 Essex County, Massachusetts 3.0 55 Chinese
#
#  Hoya 01906 Essex County, Massachusetts 4.5 28 Chinese
#
#  Imperial Mandarin 01945 Essex County, Massachusetts 3.0 24 Chinese
#
#  Jade's Restaurant 01960 Essex County, Massachusetts 3.0 50 Chinese
#
#  Jade Pacifica 01904 Essex County, Massachusetts 3.0 24 Chinese
#
#  Buddha's Tavern 01960 Essex County, Massachusetts 4.0 32 Chinese
#
#  Lucky House 01960 Essex County, Massachusetts 3.0 24 Chinese
#
#  Ming's Chinese Restaurant 01940 Essex County, Massachusetts 3.0 44 Chinese
#
#  Ocean Garden 01930 Essex County, Massachusetts 2.5 11 Chinese
#
#  Wang's Table 01830 Essex County, Massachusetts 3.5 117 Chinese
#
#  Jin's Garden 01902 Essex County, Massachusetts 3.5 10 Chinese
#
#  Jade 3 01913 Essex County, Massachusetts 3.5 33 Chinese
#
#  Bali Hai 01940 Essex County, Massachusetts 3.0 64 Chinese
#
#  Dragon Island II Restaurant 01906 Essex County, Massachusetts 2.5 23 Chinese
#
#  Beijing 01902 Essex County, Massachusetts 3.5 21 Chinese
#
#  Hokkaido Restaurant 01845 Essex County, Massachusetts 3.5 97 Chinese
#
#  Kiki's Chinese Food 01970 Essex County, Massachusetts 3.0 35 Chinese
#
#  Hung's Kitchen 01960 Essex County, Massachusetts 3.5 9 Chinese
# End of list. Found 22 Chinese restaurants in Essex County, Massachusetts
#
#  China Blossom 01845 Essex County, Massachusetts 3.0 137 Chinese
#
#  Hong Kong Kitchen 01966 Essex County, Massachusetts 3.0 12 Chinese
#
#  Eighty Eight Restaurant 01923 Essex County, Massachusetts 2.0 20 Chinese
#
#  Peking Garden of Andover 01810 Essex County, Massachusetts 3.0 29 Chinese
#
#  Asian Garden 01901 Essex County, Massachusetts 3.0 4 Chinese
#
#  Green Tea Restaurant 01905 Essex County, Massachusetts 3.0 93 Chinese
#
#  Fusion House Restaurant 01844 Essex County, Massachusetts 3.5 168 Chinese
#
#  Wah Sang Restaurant 01844 Essex County, Massachusetts 3.5 24 Chinese
#
#  Good Fortune Restaurant 01952 Essex County, Massachusetts 4.0 12 Chinese
# End of list. Found 9 Chinese restaurants in Essex County, Massachusetts
#
#  East Sakura Buffet 01970 Essex County, Massachusetts 3.0 70 Chinese
#
#  Master Wok 01960 Essex County, Massachusetts 3.5 4 Chinese
#
#  China Wok 01950 Essex County, Massachusetts 4.0 1 Chinese
#
#  The 1640 Hart House 01938 Essex County, Massachusetts 4.0 129 American (Traditional)
#
#  Black Arrow 01944 Essex County, Massachusetts 4.5 19 American (Traditional)
#
#  Choate Bridge Pub & Restaurant 01938 Essex County, Massachusetts 4.0 109 American (Traditional)
#
#  The Brown Dog 01938 Essex County, Massachusetts 4.0 5 American (Traditional)
#
#  Riversbend 01929 Essex County, Massachusetts 3.0 69 American (New)
#
#  Loretta 01950 Essex County, Massachusetts 4.0 79 American (New)
#
#  9 Elm American Bistro 01923 Essex County, Massachusetts 4.5 176 American (New)
#
#  Sea Glass Restaurant 01930 Essex County, Massachusetts 4.0 8 American (New)
#
#  C K Pearl 01929 Essex County, Massachusetts 4.0 126 American (New)
#
#  Cala's 01944 Essex County, Massachusetts 4.0 82 American (New)
#
#  Soma 01915 Essex County, Massachusetts 4.0 283 American (New)
#
#  Passports 01930 Essex County, Massachusetts 4.0 201 American (New)
#
#  Alto Forno 01960 Essex County, Massachusetts 4.5 41 American (New)
#
#  1606 Restaurant & Bar 01930 Essex County, Massachusetts 4.0 30 American (New)
#
#  The Blue Ox 01901 Essex County, Massachusetts 4.5 442 American (New)
#
#  Duckworth's Bistrot 01930 Essex County, Massachusetts 4.5 136 American (New)
#
#  CRAVE: Kitchen - Wine - Tap 01913 Essex County, Massachusetts 4.5 121 American (New)
#
#  Market Restaurant 01930 Essex County, Massachusetts 4.0 89 American (New)
#
#  Salt Kitchen and Rum Bar 01938 Essex County, Massachusetts 3.5 169 American (New)
#
#  Turtle Cove Bar & Grille 01945 Essex County, Massachusetts 4.0 87 American (New)
#
#  Olde Main Street Pub 01970 Essex County, Massachusetts 4.0 84 American (New)
#
#  The Indo 01915 Essex County, Massachusetts 4.0 64 American (New)
#
#  Opus 01970 Essex County, Massachusetts 4.0 378 American (New)
#
#  Maggies Farm 01949 Essex County, Massachusetts 3.5 236 American (New)
#
#  Back Alley Bacon 01970 Essex County, Massachusetts 5.0 7 American (New)
#
#  Mission Oak Grill 01950 Essex County, Massachusetts 3.5 169 American (New)
#
#  The Berry Tavern 01923 Essex County, Massachusetts 3.0 90 American (New)
#
#  Wild Garlic 01913 Essex County, Massachusetts 5.0 31 American (New)
#
#  The Spot 01833 Essex County, Massachusetts 3.0 122 American (New)
#
#  Counter 01970 Essex County, Massachusetts 4.0 6 American (New)
#
#  Anmol 01915 Essex County, Massachusetts 4.5 224 Indian
#
#  Passage To India 01970 Essex County, Massachusetts 4.0 288 Indian
#
#  The Jewel in the Crown 01950 Essex County, Massachusetts 4.0 127 Indian
#
#  Raagini Indian Bistro 01810 Essex County, Massachusetts 4.0 142 Indian
#
#  Mr India Restaurant 01950 Essex County, Massachusetts 3.5 95 Indian
#
#  Bollywood Grill 01845 Essex County, Massachusetts 3.5 140 Indian
# End of list. Found 6 Indian restaurants in Essex County, Massachusetts
# End of list. Found 0 Indian restaurants in Essex County, Massachusetts
# End of list. Found 0 Indian restaurants in Essex County, Massachusetts
# End of list. Found 0 Indian restaurants in Essex County, Massachusetts

# %% [markdown]
# <h3>Part 1: Cleaning the Data</h3>
#
# After waiting forever for the Kyrus for loop to finish, we needed to clean up the data. Early on, we noticed that res_df displayed \$, \$\$, and \$\$\$ in the price column, but would not show \$\$\$\$. After several attempts, we decided to replace the dollar signs with equivalent numerical value. Thus, we ended up with the following:
#
# <ul>
# <li>\$ = 1 </li>
# <li>\$\$= 2 </li>
# <li>\$\$\$ = 3 </li>
# <li>\$\$\$\$ = 4 </li>
# </ul>
#
# Additionally, we realized the Yelp does not have an American category. Instead, Yelp uses American (New) and American (Traditional). After some research, we realized that we were not entirely sure what the exact difference between the two American sub-categories were, so we opted to merge the two category types into one - American.
#
# After these corrections, we saved the changes to the res_df dataframe.

# %%
res_df.to_csv("output1804071028.csv")
try:
    res_df.price.replace(["$","$$","$$$","$$$$"],[1,2,3,4],inplace=True)
except:
    print("Already done")
try:
    res_df.category.replace(["American (New)","American (Traditional)"],["American","American"],inplace=True)
except:
    print("Already done")
res_df
# Out:
#                                  name zipcode                county_string  \
# 0                Uricchio's Trattoria   93301      Kern County, California
# 1                              Luigis   93305      Kern County, California
# 623               Mr India Restaurant    1950  Essex County, Massachusetts
# 624                   Bollywood Grill    1845  Essex County, Massachusetts
#
#      rating review_count  category  price  region
# 0       4.0          288   Italian      2  region
# 1       4.0          246   Italian      2  region
# 2       4.0          430   Italian      2  region
# 3       4.5           65   Italian      2  region
# 4       3.5          194   Italian      2  region
# 5       3.5          143   Italian      2  region
# 6       3.5          101   Italian      2  region
# 7       3.5          143   Italian      2  region
# 8       4.0           92   Italian      2  region
# 9       3.5          123   Italian      2  region
# 10      3.5          254   Italian      2  region
# 11      3.0           91   Italian      3  region
# 12      4.0           35   Italian      2  region
# 13      3.5          149   Italian      2  region
# 14      4.0          192   Italian      2  region
# 15      3.5           88   Italian      2  region
# 16      3.5          156   Italian      2  region
# 17      3.5          246   Italian      2  region
# 18      4.0            9   Italian      1  region
# 19      4.0           84   Italian      1  region
# 20      4.0           26   Italian      1  region
# 21      4.0          135   Italian      1  region
# 22      4.5          681   Mexican      2  region
# 23      4.0           39   Mexican      2  region
# 24      4.0           26   Mexican      2  region
# 25      4.0          432   Mexican      2  region
# 26      4.0          602   Mexican      2  region
# 27      4.5          169   Mexican      2  region
# 28      4.5           12   Mexican      1  region
# 29      4.5           66   Mexican      1  region
# ..      ...          ...       ...    ...     ...
# 595     4.0           79  American      2  region
# 596     4.5          176  American      3  region
# 597     4.0            8  American      3  region
# 598     4.0          126  American      2  region
# 599     4.0           82  American      2  region
# 600     4.0          283  American      2  region
# 601     4.0          201  American      2  region
# 602     4.5           41  American      3  region
# 603     4.0           30  American      3  region
# 604     4.5          442  American      2  region
# 605     4.5          136  American      3  region
# 606     4.5          121  American      2  region
# 607     4.0           89  American      3  region
# 608     3.5          169  American      2  region
# 609     4.0           87  American      3  region
# 610     4.0           84  American      2  region
# 611     4.0           64  American      2  region
# 612     4.0          378  American      2  region
# 613     3.5          236  American      2  region
# 614     5.0            7  American      2  region
# 615     3.5          169  American      3  region
# 616     3.0           90  American      2  region
# 617     5.0           31  American      1  region
# 618     3.0          122  American      2  region
# 619     4.5          224    Indian      2  region
# 620     4.0          288    Indian      2  region
# 621     4.0          127    Indian      2  region
# 622     4.0          142    Indian      2  region
# 623     3.5           95    Indian      2  region
# 624     3.5          140    Indian      2  region
#
# [625 rows x 8 columns]

# %% [markdown]
# <h3>Part 1: Merging Data</h3>
#
# Since a large part of our project revolved around correlationg geograpic location and Yelp restaurant data, we needed to merge all the necessary information into one larger dataframe. Thus, we merged res_df with our counties data on the county_string column. This allowed us to pull in and use all the data from both sources.
#
# Up until this point, if you noticed above, we had not inserted our regions, only created a placeholder column. In merging the two datasets, we were also able to populate our region column accordingly.
#
# We then printed res_df as a check to verify contents.

# %%
res_df= pd.merge(res_df,counties,how="left",on="county_string")
res_df.head()
# Out:
#                           name zipcode            county_string  rating  \
# 0         Uricchio's Trattoria   93301  Kern County, California     4.0
# 1                       Luigis   93305  Kern County, California     4.0
# 2    Frugatti's Italian Eatery   93309  Kern County, California     4.0
# 3  Perfetto Italian Restaurant   93561  Kern County, California     4.5
# 4  Sorella Ristorante Italiano   93313  Kern County, California     3.5
#
#   review_count category  price  region  CensusId       State   ...    \
# 0          288  Italian      2  region      6029  California   ...
# 1          246  Italian      2  region      6029  California   ...
# 2          430  Italian      2  region      6029  California   ...
# 3           65  Italian      2  region      6029  California   ...
# 4          194  Italian      2  region      6029  California   ...
#
#   OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  \
# 0         2.9         2.9         23.6    327294         76.3        17.2
# 1         2.9         2.9         23.6    327294         76.3        17.2
# 2         2.9         2.9         23.6    327294         76.3        17.2
# 3         2.9         2.9         23.6    327294         76.3        17.2
# 4         2.9         2.9         23.6    327294         76.3        17.2
#
#    SelfEmployed  FamilyWork  Unemployment  Region
# 0           6.2         0.2          12.7      WC
# 1           6.2         0.2          12.7      WC
# 2           6.2         0.2          12.7      WC
# 3           6.2         0.2          12.7      WC
# 4           6.2         0.2          12.7      WC
#
# [5 rows x 46 columns]

# %% [markdown]
# <h3>IDK - KYRUS can fill this part in. </h3>
# <h3>Part 2: Examining category distribution across the US </h3>

# %%
itadf = res_df.groupby(res_df["category"]).get_group("Italian")
mexdf = res_df.groupby(res_df["category"]).get_group("Mexican")
chndf = res_df.groupby(res_df["category"]).get_group("Chinese")
usadf = res_df.groupby(res_df["category"]).get_group("American")
inddf = res_df.groupby(res_df["category"]).get_group("Indian")
res_df
# CHA = res_df.groupby(res_df["county_string"]).get_group("Mecklenburg County, North Carolina")
# CHAbreakdown = pd.DataFrame(CHA["category"].value_counts()).T.reset_index()
# CHAbreakdown["county_string"]="Mecklenburg County, North Carolina"
# CHA_price_avg = CHA.groupby(res_df["price"]).mean()
# CHA_price_count = CHA["price"].value_counts()

# RAL = res_df.groupby(res_df["county_string"]).get_group("Wake County, North Carolina")
# RALbreakdown = pd.DataFrame(RAL["category"].value_counts()).T.reset_index()
# RALbreakdown["county_string"]="Wake County, North Carolina"
# RAL_price_avg = RAL.groupby(res_df["price"]).mean()
# RAL_price_count = RAL["price"].value_counts()

# ATL = res_df.groupby(res_df["county_string"]).get_group("Fulton County, Georgia")
# ATLbreakdown = pd.DataFrame(ATL["category"].value_counts()).T.reset_index()
# ATLbreakdown["county_string"]="Fulton County, Georgia"
# ATL_price_avg = ATL.groupby(res_df["price"]).mean()
# ATL_price_count = ATL["price"].value_counts()

# MEM = res_df.groupby(res_df["county_string"]).get_group("Shelby County, Tennessee")
# MEMbreakdown = pd.DataFrame(MEM["category"].value_counts()).T.reset_index()
# MEMbreakdown["county_string"]="Shelby County, Tennessee"
# MEM_price_avg = MEM.groupby(res_df["price"]).mean()
# MEM_price_count = MEM["price"].value_counts()


# ORL = res_df.groupby(res_df["county_string"]).get_group("Orange County, Florida")
# ORLbreakdown = pd.DataFrame(ORL["category"].value_counts()).T.reset_index()
# ORLbreakdown["county_string"]="Orange County, Florida"
# ORL_price_avg = ORL.groupby(res_df["price"]).mean()
# ORL_price_count = ORL["price"].value_counts()

# MIL = res_df.groupby(res_df["county_string"]).get_group("Milwaukee County, Wisconsin")
# MILbreakdown = pd.DataFrame(MIL["category"].value_counts()).T.reset_index()
# MILbreakdown["county_string"]="Milwaukee County, Wisconsin"
# MIL_price_avg = MIL.groupby(res_df["price"]).mean()
# MIL_price_count = MIL["price"].value_counts()

# SFC = res_df.groupby(res_df["county_string"]).get_group("San Francisco County, California")
# SFCbreakdown = pd.DataFrame(SFC["category"].value_counts()).T.reset_index()
# SFCbreakdown["county_string"]="San Francisco County, California"
# SFC_price_avg = SFC.groupby(res_df["price"]).mean()
# SFC_price_count = SFC["price"].value_counts()

# AUS = res_df.groupby(res_df["county_string"]).get_group("Travis County, Texas")
# AUSbreakdown = pd.DataFrame(AUS["category"].value_counts()).T.reset_index()
# AUSbreakdown["county_string"]="Travis County, Texas"
# AUS_price_avg = AUS.groupby(res_df["price"]).mean()
# AUS_price_count = AUS["price"].value_counts()

# PIT = res_df.groupby(res_df["county_string"]).get_group("Allegheny County, Pennsylvania")
# PITbreakdown = pd.DataFrame(PIT["category"].value_counts()).T.reset_index()
# PITbreakdown["county_string"]="Allegheny County, Pennsylvania"
# PIT_price_avg = PIT.groupby(res_df["price"]).mean()
# PIT_price_count = PIT["price"].value_counts()
# Out:
#                                  name zipcode                county_string  \
# 0                Uricchio's Trattoria   93301      Kern County, California
# 1                              Luigis   93305      Kern County, California
# 2           Frugatti's Italian Eatery   93309      Kern County, California
# 3         Perfetto Italian Restaurant   93561      Kern County, California
# 4         Sorella Ristorante Italiano   93313      Kern County, California
# 5         Joseph's Italian Restaurant   93301      Kern County, California
# 6                        Little Italy   93311      Kern County, California
# 7           Rosa's Italian Restaurant   93306      Kern County, California
# 8                      That's Italian   93238      Kern County, California
# 9             Sandrini's Public House   93301      Kern County, California
# 10    Olive Garden Italian Restaurant   93309      Kern County, California
# 11   Mama Tosca's Ristorante Italiano   93311      Kern County, California
# 12          Giovanni's Italian Eatery   93263      Kern County, California
# 13                     Slice of Italy   93301      Kern County, California
# 14                 TK's Pizza & Pasta   93561      Kern County, California
# 15                    Narducci's Cafe   93305      Kern County, California
# 16            Romano's Macaroni Grill   93312      Kern County, California
# 17                     Slice of Italy   93312      Kern County, California
# 18                     Farrah's Pizza   93307      Kern County, California
# 19      Caesar's Italian Delicatessen   93312      Kern County, California
# 20            Caesars II Delicatessen   93309      Kern County, California
# 21                           PizzaRev   93311      Kern County, California
# 22          Nuestro Mexico Restaurant   93301      Kern County, California
# 23             El Jacalito Restaurant   93241      Kern County, California
# 24                          El Pueblo   93241      Kern County, California
# 25                  La Costa Mariscos   93301      Kern County, California
# 26      Camino Real Kitchen & Tequila   93313      Kern County, California
# 27             Lino's Mexican Cuisine   93313      Kern County, California
# 28                 Restaurant Chilate   93241      Kern County, California
# 29             Ben Paca Mexican Grill   93307      Kern County, California
# ..                                ...     ...                          ...
# 595                           Loretta    1950  Essex County, Massachusetts
# 596             9 Elm American Bistro    1923  Essex County, Massachusetts
# 597              Sea Glass Restaurant    1930  Essex County, Massachusetts
# 598                         C K Pearl    1929  Essex County, Massachusetts
# 599                            Cala's    1944  Essex County, Massachusetts
# 600                              Soma    1915  Essex County, Massachusetts
# 601                         Passports    1930  Essex County, Massachusetts
# 602                        Alto Forno    1960  Essex County, Massachusetts
# 603             1606 Restaurant & Bar    1930  Essex County, Massachusetts
# 604                       The Blue Ox    1901  Essex County, Massachusetts
# 605               Duckworth's Bistrot    1930  Essex County, Massachusetts
# 606       CRAVE: Kitchen - Wine - Tap    1913  Essex County, Massachusetts
# 607                 Market Restaurant    1930  Essex County, Massachusetts
# 608          Salt Kitchen and Rum Bar    1938  Essex County, Massachusetts
# 609          Turtle Cove Bar & Grille    1945  Essex County, Massachusetts
# 610              Olde Main Street Pub    1970  Essex County, Massachusetts
# 611                          The Indo    1915  Essex County, Massachusetts
# 612                              Opus    1970  Essex County, Massachusetts
# 613                      Maggies Farm    1949  Essex County, Massachusetts
# 614                  Back Alley Bacon    1970  Essex County, Massachusetts
# 615                 Mission Oak Grill    1950  Essex County, Massachusetts
# 616                  The Berry Tavern    1923  Essex County, Massachusetts
# 617                       Wild Garlic    1913  Essex County, Massachusetts
# 618                          The Spot    1833  Essex County, Massachusetts
# 619                             Anmol    1915  Essex County, Massachusetts
# 620                  Passage To India    1970  Essex County, Massachusetts
# 621            The Jewel in the Crown    1950  Essex County, Massachusetts
# 622             Raagini Indian Bistro    1810  Essex County, Massachusetts
# 623               Mr India Restaurant    1950  Essex County, Massachusetts
# 624                   Bollywood Grill    1845  Essex County, Massachusetts
#
#      rating review_count  category  price  region  CensusId          State  \
# 0       4.0          288   Italian      2  region      6029     California
# 1       4.0          246   Italian      2  region      6029     California
# 2       4.0          430   Italian      2  region      6029     California
# 3       4.5           65   Italian      2  region      6029     California
# 4       3.5          194   Italian      2  region      6029     California
# 5       3.5          143   Italian      2  region      6029     California
# 6       3.5          101   Italian      2  region      6029     California
# 7       3.5          143   Italian      2  region      6029     California
# 8       4.0           92   Italian      2  region      6029     California
# 9       3.5          123   Italian      2  region      6029     California
# 10      3.5          254   Italian      2  region      6029     California
# 11      3.0           91   Italian      3  region      6029     California
# 12      4.0           35   Italian      2  region      6029     California
# 13      3.5          149   Italian      2  region      6029     California
# 14      4.0          192   Italian      2  region      6029     California
# 15      3.5           88   Italian      2  region      6029     California
# 16      3.5          156   Italian      2  region      6029     California
# 17      3.5          246   Italian      2  region      6029     California
# 18      4.0            9   Italian      1  region      6029     California
# 19      4.0           84   Italian      1  region      6029     California
# 20      4.0           26   Italian      1  region      6029     California
# 21      4.0          135   Italian      1  region      6029     California
# 22      4.5          681   Mexican      2  region      6029     California
# 23      4.0           39   Mexican      2  region      6029     California
# 24      4.0           26   Mexican      2  region      6029     California
# 25      4.0          432   Mexican      2  region      6029     California
# 26      4.0          602   Mexican      2  region      6029     California
# 27      4.5          169   Mexican      2  region      6029     California
# 28      4.5           12   Mexican      1  region      6029     California
# 29      4.5           66   Mexican      1  region      6029     California
# ..      ...          ...       ...    ...     ...       ...            ...
# 595     4.0           79  American      2  region     25009  Massachusetts
# 596     4.5          176  American      3  region     25009  Massachusetts
# 597     4.0            8  American      3  region     25009  Massachusetts
# 598     4.0          126  American      2  region     25009  Massachusetts
# 599     4.0           82  American      2  region     25009  Massachusetts
# 600     4.0          283  American      2  region     25009  Massachusetts
# 601     4.0          201  American      2  region     25009  Massachusetts
# 602     4.5           41  American      3  region     25009  Massachusetts
# 603     4.0           30  American      3  region     25009  Massachusetts
# 604     4.5          442  American      2  region     25009  Massachusetts
# 605     4.5          136  American      3  region     25009  Massachusetts
# 606     4.5          121  American      2  region     25009  Massachusetts
# 607     4.0           89  American      3  region     25009  Massachusetts
# 608     3.5          169  American      2  region     25009  Massachusetts
# 609     4.0           87  American      3  region     25009  Massachusetts
# 610     4.0           84  American      2  region     25009  Massachusetts
# 611     4.0           64  American      2  region     25009  Massachusetts
# 612     4.0          378  American      2  region     25009  Massachusetts
# 613     3.5          236  American      2  region     25009  Massachusetts
# 614     5.0            7  American      2  region     25009  Massachusetts
# 615     3.5          169  American      3  region     25009  Massachusetts
# 616     3.0           90  American      2  region     25009  Massachusetts
# 617     5.0           31  American      1  region     25009  Massachusetts
# 618     3.0          122  American      2  region     25009  Massachusetts
# 619     4.5          224    Indian      2  region     25009  Massachusetts
# 620     4.0          288    Indian      2  region     25009  Massachusetts
# 621     4.0          127    Indian      2  region     25009  Massachusetts
# 622     4.0          142    Indian      2  region     25009  Massachusetts
# 623     3.5           95    Indian      2  region     25009  Massachusetts
# 624     3.5          140    Indian      2  region     25009  Massachusetts
#
#       ...   OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0     ...           2.9         2.9         23.6    327294         76.3
# 1     ...           2.9         2.9         23.6    327294         76.3
# 2     ...           2.9         2.9         23.6    327294         76.3
# 3     ...           2.9         2.9         23.6    327294         76.3
# 4     ...           2.9         2.9         23.6    327294         76.3
# 5     ...           2.9         2.9         23.6    327294         76.3
# 6     ...           2.9         2.9         23.6    327294         76.3
# 7     ...           2.9         2.9         23.6    327294         76.3
# 8     ...           2.9         2.9         23.6    327294         76.3
# 9     ...           2.9         2.9         23.6    327294         76.3
# 10    ...           2.9         2.9         23.6    327294         76.3
# 11    ...           2.9         2.9         23.6    327294         76.3
# 12    ...           2.9         2.9         23.6    327294         76.3
# 13    ...           2.9         2.9         23.6    327294         76.3
# 14    ...           2.9         2.9         23.6    327294         76.3
# 15    ...           2.9         2.9         23.6    327294         76.3
# 16    ...           2.9         2.9         23.6    327294         76.3
# 17    ...           2.9         2.9         23.6    327294         76.3
# 18    ...           2.9         2.9         23.6    327294         76.3
# 19    ...           2.9         2.9         23.6    327294         76.3
# 20    ...           2.9         2.9         23.6    327294         76.3
# 21    ...           2.9         2.9         23.6    327294         76.3
# 22    ...           2.9         2.9         23.6    327294         76.3
# 23    ...           2.9         2.9         23.6    327294         76.3
# 24    ...           2.9         2.9         23.6    327294         76.3
# 25    ...           2.9         2.9         23.6    327294         76.3
# 26    ...           2.9         2.9         23.6    327294         76.3
# 27    ...           2.9         2.9         23.6    327294         76.3
# 28    ...           2.9         2.9         23.6    327294         76.3
# 29    ...           2.9         2.9         23.6    327294         76.3
# ..    ...           ...         ...          ...       ...          ...
# 595   ...           2.3         5.5         29.0    383882         81.7
# 596   ...           2.3         5.5         29.0    383882         81.7
# 597   ...           2.3         5.5         29.0    383882         81.7
# 598   ...           2.3         5.5         29.0    383882         81.7
# 599   ...           2.3         5.5         29.0    383882         81.7
# 600   ...           2.3         5.5         29.0    383882         81.7
# 601   ...           2.3         5.5         29.0    383882         81.7
# 602   ...           2.3         5.5         29.0    383882         81.7
# 603   ...           2.3         5.5         29.0    383882         81.7
# 604   ...           2.3         5.5         29.0    383882         81.7
# 605   ...           2.3         5.5         29.0    383882         81.7
# 606   ...           2.3         5.5         29.0    383882         81.7
# 607   ...           2.3         5.5         29.0    383882         81.7
# 608   ...           2.3         5.5         29.0    383882         81.7
# 609   ...           2.3         5.5         29.0    383882         81.7
# 610   ...           2.3         5.5         29.0    383882         81.7
# 611   ...           2.3         5.5         29.0    383882         81.7
# 612   ...           2.3         5.5         29.0    383882         81.7
# 613   ...           2.3         5.5         29.0    383882         81.7
# 614   ...           2.3         5.5         29.0    383882         81.7
# 615   ...           2.3         5.5         29.0    383882         81.7
# 616   ...           2.3         5.5         29.0    383882         81.7
# 617   ...           2.3         5.5         29.0    383882         81.7
# 618   ...           2.3         5.5         29.0    383882         81.7
# 619   ...           2.3         5.5         29.0    383882         81.7
# 620   ...           2.3         5.5         29.0    383882         81.7
# 621   ...           2.3         5.5         29.0    383882         81.7
# 622   ...           2.3         5.5         29.0    383882         81.7
# 623   ...           2.3         5.5         29.0    383882         81.7
# 624   ...           2.3         5.5         29.0    383882         81.7
#
#      PublicWork  SelfEmployed  FamilyWork  Unemployment  Region
# 0          17.2           6.2         0.2          12.7      WC
# 1          17.2           6.2         0.2          12.7      WC
# 2          17.2           6.2         0.2          12.7      WC
# 3          17.2           6.2         0.2          12.7      WC
# 4          17.2           6.2         0.2          12.7      WC
# 5          17.2           6.2         0.2          12.7      WC
# 6          17.2           6.2         0.2          12.7      WC
# 7          17.2           6.2         0.2          12.7      WC
# 8          17.2           6.2         0.2          12.7      WC
# 9          17.2           6.2         0.2          12.7      WC
# 10         17.2           6.2         0.2          12.7      WC
# 11         17.2           6.2         0.2          12.7      WC
# 12         17.2           6.2         0.2          12.7      WC
# 13         17.2           6.2         0.2          12.7      WC
# 14         17.2           6.2         0.2          12.7      WC
# 15         17.2           6.2         0.2          12.7      WC
# 16         17.2           6.2         0.2          12.7      WC
# 17         17.2           6.2         0.2          12.7      WC
# 18         17.2           6.2         0.2          12.7      WC
# 19         17.2           6.2         0.2          12.7      WC
# 20         17.2           6.2         0.2          12.7      WC
# 21         17.2           6.2         0.2          12.7      WC
# 22         17.2           6.2         0.2          12.7      WC
# 23         17.2           6.2         0.2          12.7      WC
# 24         17.2           6.2         0.2          12.7      WC
# 25         17.2           6.2         0.2          12.7      WC
# 26         17.2           6.2         0.2          12.7      WC
# 27         17.2           6.2         0.2          12.7      WC
# 28         17.2           6.2         0.2          12.7      WC
# 29         17.2           6.2         0.2          12.7      WC
# ..          ...           ...         ...           ...     ...
# 595        12.0           6.1         0.2           7.7      NE
# 596        12.0           6.1         0.2           7.7      NE
# 597        12.0           6.1         0.2           7.7      NE
# 598        12.0           6.1         0.2           7.7      NE
# 599        12.0           6.1         0.2           7.7      NE
# 600        12.0           6.1         0.2           7.7      NE
# 601        12.0           6.1         0.2           7.7      NE
# 602        12.0           6.1         0.2           7.7      NE
# 603        12.0           6.1         0.2           7.7      NE
# 604        12.0           6.1         0.2           7.7      NE
# 605        12.0           6.1         0.2           7.7      NE
# 606        12.0           6.1         0.2           7.7      NE
# 607        12.0           6.1         0.2           7.7      NE
# 608        12.0           6.1         0.2           7.7      NE
# 609        12.0           6.1         0.2           7.7      NE
# 610        12.0           6.1         0.2           7.7      NE
# 611        12.0           6.1         0.2           7.7      NE
# 612        12.0           6.1         0.2           7.7      NE
# 613        12.0           6.1         0.2           7.7      NE
# 614        12.0           6.1         0.2           7.7      NE
# 615        12.0           6.1         0.2           7.7      NE
# 616        12.0           6.1         0.2           7.7      NE
# 617        12.0           6.1         0.2           7.7      NE
# 618        12.0           6.1         0.2           7.7      NE
# 619        12.0           6.1         0.2           7.7      NE
# 620        12.0           6.1         0.2           7.7      NE
# 621        12.0           6.1         0.2           7.7      NE
# 622        12.0           6.1         0.2           7.7      NE
# 623        12.0           6.1         0.2           7.7      NE
# 624        12.0           6.1         0.2           7.7      NE
#
# [625 rows x 46 columns]

# %% [markdown]
# <h3>IDK - KYRUS can fill this part in. </h3>
# <h3>Part 2: Examining category distribution across the US </h3>

# %%
TOTAL_price_avg = res_df.groupby(["price"]).mean()
rescount = res_df.groupby(["county_string"]).count()["name"].reset_index()
rescount.columns=['county_string', 'restaurant_count']
TOTAL_county_reviews = res_df.groupby(["county_string"]).review_count.sum().reset_index()
TOTAL_county_reviews.columns=["county_string","review_count"]
TOTAL_county_avg = res_df.groupby(res_df["county_string"]).mean().reset_index()

county_stats = TOTAL_county_avg.merge(TOTAL_county_reviews, on="county_string")
csdf = county_stats.merge(counties, on="county_string")
c_df = rescount.merge(csdf, on="county_string")
c_df
# Out:
#                    county_string  restaurant_count    rating     price  \
# 0       Benton County, Tennessee                 6  3.083333  1.333333
# 1         Brazoria County, Texas                46  3.652174  1.565217
# 2       Douglas County, Missouri                 3  3.166667  1.666667
# 3    Essex County, Massachusetts               182  3.703297  1.939560
# 4        Estill County, Kentucky                 3  4.333333  1.666667
# 5     Frederick County, Maryland               144  3.611111  1.687500
# 6        Kern County, California               120  3.937500  1.733333
# 7      Kitsap County, Washington                91  3.868132  1.879121
# 8         Logan County, Colorado                12  3.750000  1.833333
# 9  Sumter County, South Carolina                18  3.583333  1.444444
#
#    CensusId_x  TotalPop_x     Men_x   Women_x  Hispanic_x  White_x   ...    \
# 0     47005.0     16261.0    8010.0    8251.0         2.1     93.3   ...
# 1     48039.0    331741.0  168196.0  163545.0        28.9     50.6   ...
# 2     29067.0     13516.0    6743.0    6773.0         1.1     97.8   ...
# 3     25009.0    763849.0  367791.0  396058.0        18.2     73.6   ...
# 4     21065.0     14476.0    7118.0    7358.0         0.1     97.9   ...
# 5     24021.0    241373.0  119038.0  122335.0         8.1     76.0   ...
# 6      6029.0    865736.0  444547.0  421189.0        51.0     36.6   ...
# 7     53035.0    255441.0  130126.0  125315.0         7.1     77.7   ...
# 8      8075.0     21928.0   11889.0   10039.0        15.4     78.5   ...
# 9     45085.0    107777.0   51732.0   56045.0         3.7     46.5   ...
#
#    OtherTransp_y  WorkAtHome_y  MeanCommute_y  Employed_y  PrivateWork_y  \
# 0            1.5           2.3           24.5        5844           73.6
# 1            1.2           2.6           29.1      154290           80.5
# 2            0.4           3.3           32.1        4897           80.2
# 3            2.3           5.5           29.0      383882           81.7
# 4            1.4           3.1           33.9        4855           76.5
# 5            1.1           6.3           34.9      127105           73.9
# 6            2.9           2.9           23.6      327294           76.3
# 7            2.3           6.9           29.9      107745           65.3
# 8            0.7           4.7           16.9       10407           72.9
# 9            1.5           1.7           22.2       41972           74.0
#
#    PublicWork_y  SelfEmployed_y  FamilyWork_y  Unemployment_y  Region
# 0          18.4             7.8           0.2            14.3      SE
# 1          14.4             5.0           0.1             5.4      SW
# 2          11.7             7.8           0.3             9.0      MW
# 3          12.0             6.1           0.2             7.7      NE
# 4          16.9             6.2           0.4            11.8      MW
# 5          20.7             5.2           0.2             5.8      NE
# 6          17.2             6.2           0.2            12.7      WC
# 7          27.6             7.0           0.1             8.0      WC
# 8          18.9             8.0           0.1             9.0      SW
# 9          20.1             5.8           0.1            12.4      SE
#
# [10 rows x 78 columns]

# %%
current_county="Lehigh County, Pennsylvania"
WCO = res_df.groupby(res_df["county_string"]).get_group(current_county)
WCObreakdown = pd.DataFrame(WCO["category"].value_counts()).T.reset_index()
WCOrate = pd.DataFrame(WCO["rating"].value_counts()).T.reset_index()
WCObreakdown["county_string"]=current_county
WCO_price_avg = WCO.groupby(res_df["price"]).mean()
WCO_price_count = WCO["price"].value_counts()
WCObreakdown
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d4d390e3dbdb> in <module>()
#       1 current_county="Lehigh County, Pennsylvania"
# ----> 2 WCO = res_df.groupby(res_df["county_string"]).get_group(current_county)
#       3 WCObreakdown = pd.DataFrame(WCO["category"].value_counts()).T.reset_index()
#       4 WCOrate = pd.DataFrame(WCO["rating"].value_counts()).T.reset_index()
#       5 WCObreakdown["county_string"]=current_county
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in get_group(self, name, obj)
#     638         inds = self._get_index(name)
#     639         if not len(inds):
# --> 640             raise KeyError(name)
#     641
#     642         return obj.take(inds, axis=self.axis, convert=False)
#
# KeyError: 'Lehigh County, Pennsylvania'

# %%
comp_df = pd.DataFrame(columns=["Italian","Mexican","Chinese","American", "Indian","county_string"])
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.append(WCObreakdown)
comp_df = comp_df.reset_index()
del comp_df["index"]
del comp_df["level_0"]
#comp_df["Totals"]=comp_df["Italian"]+comp_df["Mexican"]+comp_df["Chinese"]+comp_df["Indian"]+comp_df["American"]
comp_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fc867dc8d47a> in <module>()
#       1 comp_df = pd.DataFrame(columns=["Italian","Mexican","Chinese","American", "Indian","county_string"])
# ----> 2 comp_df = comp_df.append(WCObreakdown)
#       3 comp_df = comp_df.append(WCObreakdown)
#       4 comp_df = comp_df.append(WCObreakdown)
#       5 comp_df = comp_df.append(WCObreakdown)
#
# NameError: name 'WCObreakdown' is not defined

# %% [markdown]
# <h3>Part 2: Examining category distribution across the US </h3>
#
# Next, Kyrus generated a for loop to create multiple pie charts representing the categorical breakdown by count

# %%
fig, axes = plt.subplots(3,3,figsize= (16,9))
for i, (idx, row) in enumerate(comp_df.set_index("county_string").iterrows()):
    ax = axes[i // 3, i % 3]
    row = row[row.gt(row.sum()*.01)]
    ax.pie(row, labels=row.index)
    ax.set_title(idx)
fig.subplots_adjust(wspace=1)

# %%
plt.show()

# %% [markdown]
# <h3>Part 3: Examining price breakdown based on region and restaurant category</h3>
#
# Next, after examining the categorical breakdown based on county, we moved on to determine the price breakdown by both region and restaurant category.
#
# This was Randi's portion of the project. We ran into some tricky stuff with the stacked bar charts. The primary issue was that the each bar's list needed to be the same length, that was fine, except when there was a resturaunt for every price braket. Also, in all of her research Randi could not find how to make the stacked bars dynamic. In all the examples she found, the bar values were created manually. This is fine if you have a small dataset that you do not intend to run over and over again; however, this was not ideal for this project.
#
# <b>With some help from Mirko, Ryan, and Caleb, we figured it out! </b>
#
# First, we needed to define this list we would be looping through. For the first chart, Number of \$ per Category, we created a list named labels that contained all the different resturaunt categories. Then, we created a second list with four empty lists. These four empty lists would represet 1\$, 2\$, 3\$, and 4\$. We then looped through our category list and found the count for each of the dollar ratings in said category. Once the loop determined how many 1\$, 2\$, 3\$, and 4\$ there were in each category it appended it to the corresponding empty list. If we did not find a 1\$, 2\$, 3\$, and 4\$ for a particular restuaunt category, then the except argument kicked-in and instead appended a zero. Again, the goal was to make each of the four lists the same length.
#
# In the end, we ended up with a list corresponding to 1\$, 2\$, 3\$, and 4\$, with ratings per restuarunt category.
#
# Once we created this loop and stored the counts in lists, we could call these lists in our chart creation; thereby, making the charts dynamic, changing with the number of pulls.

# %%
labels = ["Italian","Mexican","Chinese","American", "Indian"]
# Values of each group
bars =[[],[],[],[]]
for label in labels:
    df= res_df.loc[res_df["category"]==label, :]
    counts = df["price"].value_counts()
    for price in range(1,5):
        try:
            bars[price-1].append(counts[price])
        except: 
            bars[price-1].append(0)
print(bars[1])
# Out:
# [122, 48, 77, 159, 24]

# %% [markdown]
# <h3>Part 3: Stacked Bar Chart One - Number of $ per Category</h3>

# %%
from matplotlib import rc
sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})



figsize= (100, 100, 50)
 
# Values of each group
bars1 = bars[0]
bars2 = bars[1]
bars3 = bars[2]
bars4 = bars[3]
x = np.arange(len(bars1))


four_dolla=plt.bar(x, bars4, color="plum")
three_dolla=plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dolla=plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dolla=plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

plt.xticks(x, ["Italian","Mexican","Chinese","American", "Indian"])

plt.grid(axis='y')
plt.xlabel("Category")
plt.ylabel('Price Count')
plt.title('Number of $ per Category')
    
plt.legend((four_dolla[0], three_dolla[0],two_dolla[0], one_dolla[0]), ('4$', '3$','2$', '1$'), loc="best")


# Show graphic
plt.show()
plt.savefig("stacked.png")

# %% [markdown]
# <h3>Part 3: Stacked Bar Chart Two - $ Breakdown by Region</h3>

# %%
region = ["NE","MW","WC","SW","SE"]
# Values of each group
r_bars =[[],[],[],[]]
for r in region:
    reg_bars= res_df.loc[res_df["Region"]==r, :]
    reg_counts = reg_bars["price"].value_counts()
    for price in range(1,5):
        try:
            r_bars[price-1].append(reg_counts[price])
        except: 
            r_bars[price-1].append(0)
print(r_bars)
# Out:
# [[77, 2, 50, 22, 16], [230, 4, 154, 36, 6], [17, 0, 7, 0, 2], [2, 0, 0, 0, 0]]

# %%
#### sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})

figsize= (300, 300, 25)
 
# Values of each group
bars1 = r_bars[0]
bars2 = r_bars[1]
bars3 = r_bars[2]
bars4 = r_bars[3]
x = np.arange(len(bars1))


four_dol = plt.bar(x, bars4, color="plum")
three_dol =plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dol =plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dol =plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

plt.xticks(x, ["NE","MW","WC","SW","SE","NE","WC","SE"])

plt.grid(axis='y')
plt.xlabel("Regions")
plt.ylabel('Price Count')
plt.title('$ Breakdown by Region')

plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")

# Show graphic
plt.show()
plt.savefig("stacked2.png")

# %% [markdown]
# <h3>Part 3: Pie Chart</h3>
#
# With the dynamic stacked bar charts created, we thought it was relevant to also see the count of each dollar amount when comparing the counts by region or category. Thus, we created a pie chart (also dynamic) that shows the total of each resturaunt category by dollar.

# %%
##check for pie chart
print(sum(bars1))
print(sum(bars2))
print(sum(bars3))
print(sum(bars4))
# Out:
# 167
# 430
# 26
# 2

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
sns.set()
orgPalette = sns.color_palette("Set2")
sns.set_palette(orgPalette)
# sns.set_style("", {'legend.frameon':False})

plt.figure(figsize=(20,20))

#labels = '4$', '3$','2$', '1$'
sizes = [sum(bars1),sum(bars2),sum(bars3),sum(bars4)]
explode = (0.03, 0.03, 0.03, 0.5)  # only "explode" the 2nd slice 

def make_autopct(sizes):
    def my_autopct(pct):
        total = sum(sizes)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, colors=orgPalette, autopct=make_autopct(sizes),
        shadow=True, startangle=90) 
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Sum of each $ Amount')
plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")


plt.show()
plt.savefig("pie_chart.jpg")

# %% [markdown]
# <h3>Part 4: MONICA</h3>

# %% [markdown]
# <h3>Part 5: CATHERINE</h3>

# %% [markdown]
# <h3>Part 6: Conclusions</h3>

# %% [markdown]
# <h3>Part 7: Limitations</h3>

# %% [markdown]
# <h3>Part 8: If only we had more time...</h3>
