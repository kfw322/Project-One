# %%
import json
import requests
import pandas as pd
from pprint import pprint
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import matplotlib.pyplot as plt
import seaborn as sns

# %%
g_key = "AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8"

# %%
#find place ids near Charlotte

target_city = {"lat": 35.227724, "lng": -80.839699} 
target_coords = f"{target_city['lat']},{target_city['lng']}"
print(target_coords)
location = target_coords
radius = 8000
place = "restaurant"

url=f"https://maps.googleapis.com/maps/api/place/nearbysearch/output?location={location}?radius={radius}?type={place}"
print(url)
# Out:
# 35.227724,-80.839699
# https://maps.googleapis.com/maps/api/place/nearbysearch/output?location=35.227724,-80.839699?radius=8000?type=restaurant

# %%
gkey = "AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8"
# Google developer API key



target_city = {"lat": 43.6187102, "lng": -116.2146068}
target_coords = f"{target_city['lat']},{target_city['lng']}"

params = {
    "location": target_coords,
    "radius": 400,
    "keyword": "restaurant",
    "type": "food",
    "key": gkey
}

# Build the endpoint URL (Checks all ice cream shops)
base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

# Run a request to endpoint and convert result to json
ice_cream_data = requests.get(base_url, params=params)

# Print the assembled URL
print(ice_cream_data.url)

# Convert to JSON
ice_cream_data = ice_cream_data.json()

# Print the number of ice cream shops
# print(len(ice_cream_data["results"]))
for i in ice_cream_data['results']:
#     print (i['id'])
    id2 = i['place_id']
    url2 = "https://maps.googleapis.com/maps/api/place/details/json?placeid={}&key={}".format(id2,gkey)
    print(url2)
    place_data = requests.get(url2)
    place_data_json = place_data.json()
    pprint(place_data_json)
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=43.6187102%2C-116.2146068&radius=400&keyword=restaurant&type=food&key=AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8
# https://maps.googleapis.com/maps/api/place/details/json?placeid=ChIJa_gZf-j4rlQREzIv176umXs&key=AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '164-198',
#                                     'short_name': '164-198',
#                                     'types': ['street_number']},
#                                    {'long_name': 'South 15th Street',
#                                     'short_name': 'S 15th St',
#                                     'types': ['route']},
#                                    {'long_name': 'Downtown',
#                                     'short_name': 'Downtown',
#                                     'types': ['neighborhood', 'political']},
#                                    {'long_name': 'Boise',
#                                     'short_name': 'Boise',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Ada County',
#                                     'short_name': 'Ada County',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Idaho',
#                                     'short_name': 'ID',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'United States',
#                                     'short_name': 'US',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '83702',
#                                     'short_name': '83702',
#                                     'types': ['postal_code']}],
#             'adr_address': '<span class="street-address">164-198 S 15th '
#                            'St</span>, <span class="locality">Boise</span>, '
#                            '<span class="region">ID</span> <span '
#                            'class="postal-code">83702</span>, <span '
#                            'class="country-name">USA</span>',
#             'formatted_address': '164-198 S 15th St, Boise, ID 83702, USA',
#             'geometry': {'location': {'lat': 43.6190677, 'lng': -116.2124133},
#                          'viewport': {'northeast': {'lat': 43.6204012802915,
#                                                     'lng': -116.2110330197085},
#                                       'southwest': {'lat': 43.6177033197085,
#                                                     'lng': -116.2137309802915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#             'id': '73b1f9fa11b0f1237a8c862332bc97e03e47451c',
#             'name': 'Burger Hut',
#             'place_id': 'ChIJa_gZf-j4rlQREzIv176umXs',
#             'reference': 'CmRRAAAAEwfHRID_KvTAuQT4WxeA4OYcuzD3HrhveLkx-mJYErqJyBGLCbnNI4SjfqJuae-9fZqD510BboHgYigFH92E_SP4r36wmKCRf4GFxQbswu0CcKj8gbeYjXjW1CooXidNEhBFgre8B2dhHTN4NF9GrDkYGhTV1ukn3dwVIqmi-vMXDRiBTpGO_Q',
#             'scope': 'GOOGLE',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'url': 'https://maps.google.com/?cid=8906341872779080211',
#             'utc_offset': -360,
#             'vicinity': '164-198 South 15th Street, Boise'},
#  'status': 'OK'}
# https://maps.googleapis.com/maps/api/place/details/json?placeid=ChIJ_fZEO-b4rlQRESiN6JvXLD8&key=AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '1314',
#                                     'short_name': '1314',
#                                     'types': ['street_number']},
#                                    {'long_name': 'West Grove Street',
#                                     'short_name': 'W Grove St',
#                                     'types': ['route']},
#                                    {'long_name': 'Downtown',
#                                     'short_name': 'Downtown',
#                                     'types': ['neighborhood', 'political']},
#                                    {'long_name': 'Boise',
#                                     'short_name': 'Boise',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Ada County',
#                                     'short_name': 'Ada County',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Idaho',
#                                     'short_name': 'ID',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'United States',
#                                     'short_name': 'US',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '83702',
#                                     'short_name': '83702',
#                                     'types': ['postal_code']},
#                                    {'long_name': '6942',
#                                     'short_name': '6942',
#                                     'types': ['postal_code_suffix']}],
#             'adr_address': '<span class="street-address">1314 W Grove '
#                            'St</span>, <span class="locality">Boise</span>, '
#                            '<span class="region">ID</span> <span '
#                            'class="postal-code">83702-6942</span>, <span '
#                            'class="country-name">USA</span>',
#             'formatted_address': '1314 W Grove St, Boise, ID 83702, USA',
#             'formatted_phone_number': '(208) 424-8244',
#             'geometry': {'location': {'lat': 43.618414, 'lng': -116.210601},
#                          'viewport': {'northeast': {'lat': 43.6197211302915,
#                                                     'lng': -116.2095126197085},
#                                       'southwest': {'lat': 43.6170231697085,
#                                                     'lng': -116.2122105802915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#             'id': 'b76b556c1981e60826e9b1591d3997c34bf92289',
#             'international_phone_number': '+1 208-424-8244',
#             'name': 'The Modern Hotel and Bar',
#             'opening_hours': {'open_now': True,
#                               'periods': [{'close': {'day': 0, 'time': '2300'},
#                                            'open': {'day': 0, 'time': '1600'}},
#                                           {'close': {'day': 1, 'time': '2300'},
#                                            'open': {'day': 1, 'time': '1600'}},
#                                           {'close': {'day': 3, 'time': '0000'},
#                                            'open': {'day': 2, 'time': '1600'}},
#                                           {'close': {'day': 4, 'time': '0000'},
#                                            'open': {'day': 3, 'time': '1600'}},
#                                           {'close': {'day': 5, 'time': '0000'},
#                                            'open': {'day': 4, 'time': '1600'}},
#                                           {'close': {'day': 6, 'time': '0000'},
#                                            'open': {'day': 5, 'time': '1600'}},
s128-c0x00000000-cc-rp-mo-ba2/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '3 weeks ago',
#                          'text': 'The outdoor seating around the cozy fires is '
#                                  "perfect for chilly spring evenings. There's "
#                                  'a lot to choose from on the drink menu but '
#                                  "it's impossible to go wrong - they're all "
#                                  'sublime. Weekday hours were better than '
#                                  'other places nearby and parking options '
#                                  'include the small lot on site as well as '
#                                  'street parking with decent availability, '
#                                  'being a few blocks removed from the center '
#                                  'of town.',
#                          'time': 1521093835},
#                         {'author_name': 'Christopher Watts',
#                          'author_url': 'https://www.google.com/maps/contrib/104377058523596912253/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh6.googleusercontent.com/-v4ee19YtpRs/AAAAAAAAAAI/AAAAAAAAAAo/lgsljVRjO9o/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': 'a month ago',
#                          'text': "My wife and I's stay at the Modern Hotel was "
#                                  'nothing shy of extraordinary. The front desk '
#                                  'staff was friendly and very welcoming from '
#                                  'the moment we first arrived to the moment we '
#                                  'checked out. They were also kind enough to '
#                                  'take the time and see if any of their suites '
#                                  'had become available. Much to our delight, '
#                                  'one had and we were seamlessly upgraded '
#                                  'without even having to ask. The room was '
#                                  'wonderful, the food was delicious and the '
#                                  'cocktails were one of a kind. 10/10. Would '
#                                  'recommend.',
#                          'time': 1518537288},
#                         {'author_name': 'Chris Evans',
#                          'author_url': 'https://www.google.com/maps/contrib/101835685319349588617/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh4.googleusercontent.com/-p8u7aPTwQaw/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDIkZdORtr9FNzoaqMIBDNR2a8EUg/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#                          'rating': 4,
#                          'relative_time_description': 'a month ago',
#                          'text': 'King bed and full size pillows were very '
#                                  'nice.  Probably one of the most comfortable '
#                                  "beds in all the places I've stayed.  Room "
#                                  'was clean and the walk in shower was great.  '
#                                  'My only complaints are there was only one '
#                                  'lock on each door.  Being a street level '
#                                  'room I would want another one.  Last thing '
#                                  'is the room was noisy.  I could hear '
#                                  'everything in the hall.',
#                          'time': 1519862369},
#                         {'author_name': 'Thaddeas Acree',
#                          'author_url': 'https://www.google.com/maps/contrib/107207517433585356503/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/-hkzaPHLCS28/AAAAAAAAAAI/AAAAAAAAAAo/T_TztdQ8Mts/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '2 weeks ago',
#                          'text': 'Felt incredible!\n'
#                                  '\n'
#                                  'Stayed in the upper level King Suite for a '
#                                  'recent business trip.  LOVED the room, from '
#                                  'the well stocked kitchenette to the '
#                                  'generously oversized bathroom with separate '
#                                  'shower and tub.\n'
#                                  '\n'
#                                  'Living space made for a great work area and '
#                                  'the bedroom was quite comfortable.  Double '
#                                  'access to the balcony patio was a super nice '
#                                  "detail that I'm glad they didn't overlook.\n"
#                                  '\n'
#                                  'Whether traveling to Boise to check out your '
#                                  'relocation options, or for traditional '
#                                  'business or pleasure, request room 221 for '
#                                  'an unforgettable experience during your time '
#                                  'in the city of trees!\n'
#                                  '\n'
#                                  'Again, the staff here is sooo professional, '
#                                  "can't say enough about how well we're "
#                                  'treated each time we stay here.  \n'
#                                  '\n'
#                                  'Special thank you to Tony and Polly for '
#                                  'making it consistently great.\n'
#                                  '\n'
#                                  'Cheers,\n'
#                                  '\n'
#                                  'Thaddeas',
#                          'time': 1521234604},
#                         {'author_name': 'Michael John Slavin',
#                          'author_url': 'https://www.google.com/maps/contrib/104207309561602129167/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh6.googleusercontent.com/-8apWC7at7VA/AAAAAAAAAAI/AAAAAAAAAC8/WH9LVxZq_IE/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '3 months ago',
#                          'text': 'The best hotel in Boise by far.  Very good '
#                                  'design (the owners took an ordinary hotel, '
#                                  'and invested real capital to make it '
#                                  'extraordinary).  \n'
#                                  '\n'
#                                  'Great staff.  Clean rooms.  Comfy beds.  '
#                                  'Fantastic bathrooms (tiled walk-in '
#                                  'showers).  Quick walk to downtown and 8th '
#                                  'street.  And if you stay over the weekend, '
#                                  'their brunch is second to none in Boise.  \n'
#                                  '\n'
#                                  'All of this at a reasonable price.  You have '
#                                  'to try it.',
#                          'time': 1513607470}],
#             'scope': 'GOOGLE',
#             'types': ['bar',
#                       'lodging',
#                       'restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'url': 'https://maps.google.com/?cid=4552250387986196497',
#             'utc_offset': -360,
#             'vicinity': '1314 West Grove Street, Boise',
#             'website': 'http://www.themodernhotel.com/'},
#  'status': 'OK'}
# https://maps.googleapis.com/maps/api/place/details/json?placeid=ChIJOwU3e-j4rlQRkF2KrM14JZo&key=AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '1515',
#                                     'short_name': '1515',
#                                     'types': ['street_number']},
#                                    {'long_name': 'West Grove Street',
#                                     'short_name': 'W Grove St',
#                                     'types': ['route']},
#                                    {'long_name': 'Downtown',
#                                     'short_name': 'Downtown',
#                                     'types': ['neighborhood', 'political']},
#                                    {'long_name': 'Boise',
#                                     'short_name': 'Boise',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Ada County',
#                                     'short_name': 'Ada County',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Idaho',
#                                     'short_name': 'ID',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'United States',
#                                     'short_name': 'US',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '83702',
#                                     'short_name': '83702',
#                                     'types': ['postal_code']},
#                                    {'long_name': '5244',
#                                     'short_name': '5244',
#                                     'types': ['postal_code_suffix']}],
#             'adr_address': '<span class="street-address">1515 W Grove '
#                            'St</span>, <span class="locality">Boise</span>, '
#                            '<span class="region">ID</span> <span '
#                            'class="postal-code">83702-5244</span>, <span '
#                            'class="country-name">USA</span>',
#             'formatted_address': '1515 W Grove St, Boise, ID 83702, USA',
#             'formatted_phone_number': '(208) 336-3641',
#             'geometry': {'location': {'lat': 43.619152, 'lng': -116.2132897},
#                          'viewport': {'northeast': {'lat': 43.6205954302915,
#                                                     'lng': -116.2118500197085},
#                                       'southwest': {'lat': 43.6178974697085,
#                                                     'lng': -116.2145479802915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#             'id': '95a6b1416bfeeb71f0c91c29bc35c2f94625b57f',
#             'international_phone_number': '+1 208-336-3641',
#             'name': "A'Tavola",
#             'opening_hours': {'open_now': False,
#                               'periods': [{'close': {'day': 1, 'time': '1500'},
#                                            'open': {'day': 1, 'time': '0700'}},
#                                           {'close': {'day': 2, 'time': '1500'},
#                                            'open': {'day': 2, 'time': '0700'}},
#                                           {'close': {'day': 3, 'time': '1500'},
#                                            'open': {'day': 3, 'time': '0700'}},
#                                           {'close': {'day': 4, 'time': '1500'},
#                                            'open': {'day': 4, 'time': '0700'}},
#                                           {'close': {'day': 5, 'time': '1500'},
#                                            'open': {'day': 5, 'time': '0700'}},
#                                           {'close': {'day': 6, 'time': '1500'},
#                                            'open': {'day': 6, 'time': '0700'}}],
#                               'weekday_text': ['Monday: 7:00 AM – 3:00 PM',
#                                                'Tuesday: 7:00 AM – 3:00 PM',
#                                                'Wednesday: 7:00 AM – 3:00 PM',
#                                                'Thursday: 7:00 AM – 3:00 PM',
#                                                'Friday: 7:00 AM – 3:00 PM',
#                                                'Saturday: 7:00 AM – 3:00 PM',
#                                                'Sunday: Closed']},
#             'photos': [{'height': 2988,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/116403600914294680135/photos">M '
#                                               'Phillips</a>'],
#                         'photo_reference': 'CmRaAAAArywK5YENwPKs_XNN6vvMa5ziwqx4JxCzdJ_FwAPbEzyJk-LMyDndAu1VqVz5djEpWkwWNp8NMpzh2Sa5-scF0HDjWBqDBgYGzqQDqXi1oFsbPhKGcKPOAoMxn1MpioNzEhA12Sw_u8OxsAEUVbDPs0bCGhRc98XXmZ_leTvMI0dMhW1li5Ws0w',
#                         'width': 5312},
#                        {'height': 4008,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/111084550293068882005/photos">Morgan '
#                                               'La Frey</a>'],
#                         'photo_reference': 'CmRaAAAACebzr7YyZEC2L_RrmDqiOEqx5Yema25KrWRaEtEjJ2cl7mXGfEo6aR3ucH02dYp9aZaca3YqGoe9Bb5STDSXdfY5UIV-r0nZv2VhZ76L6jUudmX-Sp0u8heLFKFEUoImEhAgbqB0lf8L60PG2BIyibLPGhTt6nnNVKWtN2wFQ-b44WnxQcNyVw',
#                         'width': 5344},
#                        {'height': 2992,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/112134603562794061051/photos">Christy '
#                                               'Leach</a>'],
#                         'photo_reference': 'CmRaAAAAhknQriXFHfALmJm7jwtDssgpivBPngOTysQozFgQEZSp7exXd_nswJN_4_tiAVIDiIrCr0Jpu4LIy96c-FPTJA-CgY0VhLt98xbRHf9HjrcAkrVi8NY8m2rXcpeNltsTEhDYhvEGAB1ToGkSgBMLqwmWGhQzwuT3KNFarg1DlkY0Q7Skfz9_5Q',
#                         'width': 4000},
#                        {'height': 2988,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/113560854740524912239/photos">Marie '
#                                               'Koecke</a>'],
#                         'photo_reference': 'CmRaAAAAAcCl2CAqUx2oh2P0nRowk-ViClxyQTqiHZtwpGlW-ALLsa9KmnKEv5e3feYXSxtQzIATB951WC1kdD_5sltw7Cler2F0wj0giDmO_6aCu8H8zEKzGUxUwPDBqbVzDhMfEhCQT3rTCRO1AdJefFXNRb5LGhS3Z8XIqt-sZyEKDleEGgoxAepweQ',
#                         'width': 5312},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib
reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/-fNtN-QYyKPM/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWC71-Oh2q2Je08ii5_fX_iyFpFKKQ/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 2,
#                          'relative_time_description': 'in the last week',
#                          'text': "I've had a few good lunches here - good "
#                                  'quality food and prices reasonable. Beware '
#                                  'of their mark-ups on some products including '
#                                  'water. Nothing like $2.00 for a can of '
#                                  'LaCroix. Poor response from the manager when '
#                                  'I inquired politely about her 500% margin on '
#                                  "that product. I'll think twice about going "
#                                  'back.',
#                          'time': 1522865412},
#                         {'author_name': "A'Channa Kichiwa Valle",
#                          'author_url': 'https://www.google.com/maps/contrib/104250489402385006672/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh6.googleusercontent.com/-JrhhNlTv_Lg/AAAAAAAAAAI/AAAAAAAAACs/mmiz6gzRg30/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#                          'rating': 3,
#                          'relative_time_description': '3 weeks ago',
#                          'text': 'Tried breakfast here a few days ago. Bright '
#                                  'spotlights aimed at shiny metal tables make '
#                                  'it hard on the eyes.  A decent number of '
#                                  'breakfast selections but everything has '
#                                  'cheese in it. A lot of cheese. Not sure when '
#                                  "this became a trend but it's discouraging "
#                                  'when you are trying to limit dairy and still '
#                                  'enjoy egg dishes.',
#                          'time': 1520990088},
#                         {'author_name': 'Jeff',
#                          'author_url': 'https://www.google.com/maps/contrib/104929781061243699308/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh4.googleusercontent.com/-z2LhJK9LXLo/AAAAAAAAAAI/AAAAAAAAAEk/dCZ8VJfzzRw/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#                          'rating': 3,
#                          'relative_time_description': 'a week ago',
#                          'text': 'The food is good, nice clean interior. We '
#                                  'got a sandwich, quiche and two coffees. '
#                                  'About $24- not sure the price is worth what '
#                                  'we got. Popular with the locals, has a '
#                                  'feeling of catering to upper class house '
#                                  'wives. Interesting for the Boise area.',
#                          'time': 1522348131},
#                         {'author_name': 'Cindy Cooperrider',
#                          'author_url': 'https://www.google.com/maps/contrib/109989570183326332818/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/-dJH0Eds65EY/AAAAAAAAAAI/AAAAAAAAAFY/Wz93eVBECxY/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Yummy with an unpretentious gourmet vibe.  '
#                                  'Located in a former auto repair shop in the '
#                                  'Linen District. Order at the counter or grab '
#                                  'something for later out of the frig. Wines '
#                                  'and beers offered. A coffee bar and a food '
#                                  'and gift area are icing on the cake. '
#                                  'Speaking of cake and the like...a real '
#                                  'treat.',
#                          'time': 1518666410},
#                         {'author_name': 'Peasley Creek',
#                          'author_url': 'https://www.google.com/maps/contrib/102705529513343936037/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/-C4luFZ6lQdw/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWBifQP4H_6Z87mgIllr2l6pZVYkEw/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 4,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Love this place.  High ceiling, good food, '
#                                  'reasonable prices, fast service.  Fresh. '
#                                  'Lots of little food items to buy also, but '
#                                  'these are. expensive.',
#                          'time': 1518295127}],
#             'scope': 'GOOGLE',
#             'types': ['restaurant',
#                       'food',
#                       'point_of_interest',
#                       'establishment'],
#             'url': 'https://maps.google.com/?cid=11107416880737574288',
#             'utc_offset': -360,
#             'vicinity': '1515 West Grove Street, Boise',
#             'website': 'https://atavolaboise.com/'},
#  'status': 'OK'}
# https://maps.googleapis.com/maps/api/place/details/json?placeid=ChIJCavi88L4rlQR8mDWej59VVc&key=AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '2275',
#                                     'short_name': '2275',
#                                     'types': ['street_number']},
#                                    {'long_name': 'West Main Street',
#                                     'short_name': 'W Main St',
#                                     'types': ['route']},
#                                    {'long_name': 'Boise',
#                                     'short_name': 'Boise',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Ada County',
#                                     'short_name': 'Ada County',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Idaho',
#                                     'short_name': 'ID',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'United States',
#                                     'short_name': 'US',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '83702',
#                                     'short_name': '83702',
#                                     'types': ['postal_code']},
#                                    {'long_name': '4963',
#                                     'short_name': '4963',
#                                     'types': ['postal_code_suffix']}],
#             'adr_address': '<span class="street-address">2275 W Main '
#                            'St</span>, <span class="locality">Boise</span>, '
#                            '<span class="region">ID</span> <span '
#                            'class="postal-code">83702-4963</span>, <span '
#                            'class="country-name">USA</span>',
#             'formatted_address': '2275 W Main St, Boise, ID 83702, USA',
#             'formatted_phone_number': '(208) 433-8888',
#             'geometry': {'location': {'lat': 43.62154539999999,
#                                       'lng': -116.2180356},
#                          'viewport': {'northeast': {'lat': 43.6230174302915,
#                                                     'lng': -116.2166859697085},
#                                       'southwest': {'lat': 43.6203194697085,
#                                                     'lng': -116.2193839302915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#             'id': 'af8363c6aa7b756c9c0ebc6251030024a8067dd5',
#             'international_phone_number': '+1 208-433-8888',
#             'name': 'Sushi Joy Asian Cuisine',
#             'opening_hours': {'open_now': True,
#                               'periods': [{'close': {'day': 0, 'time': '2130'},
#                                            'open': {'day': 0, 'time': '1200'}},
#                                           {'close': {'day': 1, 'time': '2130'},
#                                            'open': {'day': 1, 'time': '1100'}},
#                                           {'close': {'day': 2, 'time': '2130'},
#                                            'open': {'day': 2, 'time': '1100'}},
#                                           {'close': {'day': 3, 'time': '2130'},
#                                            'open': {'day': 3, 'time': '1100'}},
#                                           {'close': {'day': 4, 'time': '2130'},
#                                            'open': {'day': 4, 'time': '1100'}},
#                                           {'close': {'day': 5, 'time': '2230'},
#                                            'open': {'day': 5, 'time': '1100'}},
#                                           {'close': {'day': 6, 'time': '2230'},
#                                            'open': {'day': 6, 'time': '1100'}}],
#                               'weekday_text': ['Monday: 11:00 AM – 9:30 PM',
#                                                'Tuesday: 11:00 AM – 9:30 PM',
#                                                'Wednesday: 11:00 AM – 9:30 PM',
#                                                'Thursday: 11:00 AM – 9:30 PM',
#                                                'Friday: 11:00 AM – 10:30 PM',
#                                                'Saturday: 11:00 AM – 10:30 PM',
#                                                'Sunday: 12:00 – 9:30 PM']},
#             'photos': [{'height': 3984,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib

#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/102539125365184033797/photos">Jared '
#                                               'Bergquist</a>'],
#                         'photo_reference': 'CmRaAAAA0lTtU1kpQTDEwGs6IEpIUNNToE20mwFdnyu_AN6LUOQpb8APmIF-tbgrA9G4sXaO4g9kBgsqU-OZAPJEKcIfE7cmkPvi3sCahV2i0Q8lajbaoRY9e5XnJxkqx-dHg1VtEhCQiovnoJnaPfFlUVocwBOlGhQ652mmpwuPSicybAz6JkAgsCcHnA',
#                         'width': 2048},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/102671727481495750001/photos">Terry '
#                                               'Lilly-Halbrook</a>'],
# ...
#                       'establishment'],
#             'url': 'https://maps.google.com/?cid=11860116547780800815',
#             'utc_offset': -360,
#             'vicinity': '1099 West Front Street, Boise',
#             'website': 'http://www.simplot.com/'},
#  'status': 'OK'}
# https://maps.googleapis.com/maps/api/place/details/json?placeid=ChIJyZ8O8eX4rlQRVhIt0-6Kuwk&key=AIzaSyB4qv-Xl3m0Z93vAemyXvjeztXSyITa6p8
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '1114',
#                                     'short_name': '1114',
#                                     'types': ['street_number']},
#                                    {'long_name': 'West Front Street',
#                                     'short_name': 'W Front St',
#                                     'types': ['route']},
#                                    {'long_name': 'Downtown',
#                                     'short_name': 'Downtown',
#                                     'types': ['neighborhood', 'political']},
#                                    {'long_name': 'Boise',
#                                     'short_name': 'Boise',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Ada County',
#                                     'short_name': 'Ada County',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Idaho',
#                                     'short_name': 'ID',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'United States',
#                                     'short_name': 'US',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '83702',
#                                     'short_name': '83702',
#                                     'types': ['postal_code']}],
#             'adr_address': '<span class="street-address">1114 W Front '
#                            'St</span>, <span class="locality">Boise</span>, '
#                            '<span class="region">ID</span> <span '
#                            'class="postal-code">83702</span>, <span '
#                            'class="country-name">USA</span>',
#             'formatted_address': '1114 W Front St, Boise, ID 83702, USA',
#             'formatted_phone_number': '(208) 426-0510',
#             'geometry': {'location': {'lat': 43.6165157, 'lng': -116.2090752},
#                          'viewport': {'northeast': {'lat': 43.6176980802915,
#                                                     'lng': -116.2076853697085},
#                                       'southwest': {'lat': 43.6150001197085,
#                                                     'lng': -116.2103833302915}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#             'id': 'd524769620629bef822383fb11b944f9a7318a30',
#             'international_phone_number': '+1 208-426-0510',
#             'name': 'Woodland Empire Brewery',
#             'opening_hours': {'open_now': True,
#                               'periods': [{'close': {'day': 0, 'time': '2200'},
#                                            'open': {'day': 0, 'time': '1300'}},
#                                           {'close': {'day': 1, 'time': '2200'},
#                                            'open': {'day': 1, 'time': '1400'}},
#                                           {'close': {'day': 2, 'time': '2200'},
#                                            'open': {'day': 2, 'time': '1400'}},
#                                           {'close': {'day': 3, 'time': '2200'},
#                                            'open': {'day': 3, 'time': '1400'}},
#                                           {'close': {'day': 4, 'time': '2200'},
#                                            'open': {'day': 4, 'time': '1100'}},
#                                           {'close': {'day': 5, 'time': '2300'},
#                                            'open': {'day': 5, 'time': '1100'}},
#                                           {'close': {'day': 6, 'time': '2300'},
#                                            'open': {'day': 6, 'time': '1300'}}],
#                               'weekday_text': ['Monday: 2:00 – 10:00 PM',
#                                                'Tuesday: 2:00 – 10:00 PM',
#                                                'Wednesday: 2:00 – 10:00 PM',
#                                                'Thursday: 11:00 AM – 10:00 PM',
#                                                'Friday: 11:00 AM – 11:00 PM',
#                                                'Saturday: 1:00 – 11:00 PM',
#                                                'Sunday: 1:00 – 10:00 PM']},
#             'photos': [{'height': 2448,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/107024854762392465476/photos">Colby '
#                                               'Utah</a>'],
#                         'photo_reference': 'CmRaAAAAJFsIHRWYoJm8oJSmDDPHzxaYpeFUCAFFHseIV8d-p4D4bQZPv34vCpP7xZ_uVg-nZHXxXufkSGgwNf-Hlf_jsHSCXHmr2JgEx1y2QaELJqwK-83m1bFTNhVtwa3m__s7EhBLq0ooRyjebaZywV_Lxwd8GhSslKozoH0_UunOW_rRWedSkiBeOw',
#                         'width': 3264},
#                        {'height': 2988,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/110428530385489737925/photos">Tyson '
#                                               'Burlile</a>'],
#                         'photo_reference': 'CmRaAAAAvkHAa4wlyjOMaaS6iyTL-tv3gOyn8bRR61FOpjEskL2dQ1u9CIIjd2ah1VB64XBgH4wK8j3lzKF6-U3Of7vrYZEIY-_UWm_3n5UY-uyPCIzXgI6vBjsKzUBLZF-XEdgDEhBBs1OQje_64HKpQSQ_KaR1GhTytzTGhsUxB7wI-Wp52iZM3Df_CQ',
#                         'width': 5312},
#                        {'height': 2448,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/105540086321513830198/photos">John '
#                                               'Michael Schert</a>'],
#                         'photo_reference': 'CmRaAAAAXdx7ySkuWnb3PVJUomBH0sQ3cFyrEg90AVZ3LojXx6RSDQGLOtlOQkLyR1sNhUuQtUR3_adXeGswya-ojRGnsIhzHzZznvkFLu9AQwkkIHpE_j4hPEfRUeuV3tS5OfDLEhA90fMECAB1buXQ95nppx09GhQv5k-Kl7j2uuV5iGSAnUCVg-G_Fg',
#                         'width': 2448},
#                        {'height': 4032,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/116584351101580025505/photos">Barton '
#                                               'Kline</a>'],
#                         'photo_reference': 'CmRaAAAA1VmezFT0F35S5zGMWOHfUUTKkpxkYWppMSg2jKog3zG3fzCaiM2xPR6RHNiiy3CIL9g6n_khDhvvIodZeapk0ICpiRZrh3Ft3guNHyqWUCehI3mznkU8KEUb8T3XYmTuEhCKRscgYIKnCpgu-xKk6S7NGhRMYcjajqWi4LcqmnjGg6fBMKNA0A',
#                         'width': 3024},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/106248842066006903236/photos">Shane '
#                                               'S</a>'],
#                         'photo_reference': 'CmRaAAAAMjNdeJ-9Md6Pp1bZ6LP0FNfzxINAf-O9cusn8HdNWlW0WGtn9jAFBs9qPODTmF1Iv7wOk2eM3zU3Mn0h7RB9X8A0KRjQ8q3TVJDHuvzd34h_LP-_xk9p9A0SOPBqT5zXEhB7v-VP9J-P0hVhbCF9PWkTGhQUgC0Vti_v6ZGnlidUm9jOvVciHA',
#                         'width': 4032},
#                        {'height': 2448,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib
reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh4.googleusercontent.com/-PVshwmzsKFI/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWAeH6eILkRl1NvtleHVBecZoN3YPA/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 1,
#                          'relative_time_description': 'in the last week',
#                          'text': 'If I could give it zero I would. Our first '
#                                  'time there. We walked in and sat down at the '
#                                  'bar. After about 10 minutes we got tired of '
#                                  'waiting for the bar tender to even '
#                                  'acknowledge we were there. He was too '
#                                  'occupied with giving his three buddies at '
#                                  'the end of the bar free drinks. We got up '
#                                  'and left. Never again. Never again.',
#                          'time': 1522554024},
#                         {'author_name': 'Kaylan Vogele',
#                          'author_url': 'https://www.google.com/maps/contrib/115621246095604838664/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh6.googleusercontent.com/-FWXJratCJXE/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDgxFYU3PW6hdUh7OU2TxQl5Kd7HA/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '3 months ago',
#                          'text': "There's always something new, and more "
#                                  'genuine variety than your typical craft '
#                                  'joint. The restaurant next door pairs '
#                                  'magnificently with the beers here, and they '
#                                  'do a lot of different events from a house '
#                                  'made quiz night to annual puppet shows and '
#                                  'more. Worth visiting often just to keep up '
#                                  'with their experiments and offerings.',
#                          'time': 1515078790},
#                         {'author_name': 'Tim Guill',
#                          'author_url': 'https://www.google.com/maps/contrib/105696606266435986465/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh5.googleusercontent.com/-SC8-MhGOqyA/AAAAAAAAAAI/AAAAAAAAAGQ/orfc0EuOQ-E/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '2 months ago',
#                          'text': 'Great environment, tastey brews, and a '
#                                  'really open and friendly staff. Quick tip: '
#                                  'the food next door can be ordered and then '
#                                  'you can have it delivered in the tasting '
#                                  'room. The food is unbelievably good!\n'
#                                  '\n'
#                                  'Also, the have a Game is Thrones pinball '
#                                  'machine.... seriously!!!',
#                          'time': 1516647578},
#                         {'author_name': 'Emily Loewe',
#                          'author_url': 'https://www.google.com/maps/contrib/115868252838985615049/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh5.googleusercontent.com/-Xn0BjdahuC0/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWBVywPSfweJOPAPoWarkqpgyD-oZA/s128-c0x00000000-cc-rp-mo/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '2 months ago',
#                          'text': "I've liked every beer I've tried here. Great "
#                                  'chill atmosphere. Great prices.',
#                          'time': 1517536619},
#                         {'author_name': 'Francisco Alvarez',
#                          'author_url': 'https://www.google.com/maps/contrib/100857125619153704920/reviews',
#                          'language': 'en',
#                          'profile_photo_url': 'https://lh5.googleusercontent.com/-rnjJZNXFG2E/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDrdPrHWK5a7j6nE8FSbHeFAgyDfA/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#                          'rating': 5,
#                          'relative_time_description': '2 weeks ago',
#                          'text': 'Always a great selection of beer and food is '
#                                  'available around the corner',
#                          'time': 1521651007}],
#             'scope': 'GOOGLE',
#             'types': ['food', 'point_of_interest', 'establishment'],
#             'url': 'https://maps.google.com/?cid=701306925336040022',
#             'utc_offset': -360,
#             'vicinity': '1114 West Front Street, Boise',
#             'website': 'http://woodlandempire.com/'},
#  'status': 'OK'}

# %%
for x in range(0, len(place_data_json['result']['reviews'])):
    reviews = (f"{place_data_json['result']['reviews'][x]['text']}")
    print(reviews)
# Out:
# If I could give it zero I would. Our first time there. We walked in and sat down at the bar. After about 10 minutes we got tired of waiting for the bar tender to even acknowledge we were there. He was too occupied with giving his three buddies at the end of the bar free drinks. We got up and left. Never again. Never again.
# There's always something new, and more genuine variety than your typical craft joint. The restaurant next door pairs magnificently with the beers here, and they do a lot of different events from a house made quiz night to annual puppet shows and more. Worth visiting often just to keep up with their experiments and offerings.
# Great environment, tastey brews, and a really open and friendly staff. Quick tip: the food next door can be ordered and then you can have it delivered in the tasting room. The food is unbelievably good!
#
# Also, the have a Game is Thrones pinball machine.... seriously!!!
# I've liked every beer I've tried here. Great chill atmosphere. Great prices.
# Always a great selection of beer and food is available around the corner

# %%
reviews1 = []
for x in range(0, len(place_data_json['result']['reviews'])):
    reviews = (f"{place_data_json['result']['reviews'][x]['text']}")
    reviews1.append(reviews)
print(reviews1)
# Out:
# ['If I could give it zero I would. Our first time there. We walked in and sat down at the bar. After about 10 minutes we got tired of waiting for the bar tender to even acknowledge we were there. He was too occupied with giving his three buddies at the end of the bar free drinks. We got up and left. Never again. Never again.', "There's always something new, and more genuine variety than your typical craft joint. The restaurant next door pairs magnificently with the beers here, and they do a lot of different events from a house made quiz night to annual puppet shows and more. Worth visiting often just to keep up with their experiments and offerings.", 'Great environment, tastey brews, and a really open and friendly staff. Quick tip: the food next door can be ordered and then you can have it delivered in the tasting room. The food is unbelievably good!\n\nAlso, the have a Game is Thrones pinball machine.... seriously!!!', "I've liked every beer I've tried here. Great chill atmosphere. Great prices.", 'Always a great selection of beer and food is available around the corner']

# %%
counter = 1

   # for i in reviews1:

sentiments = []

for i in reviews1:

    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

#Run Vader Analysis
    compound = analyzer.polarity_scores(i)["compound"]
    pos = analyzer.polarity_scores(i)["pos"]
    neu = analyzer.polarity_scores(i)["neu"]
    neg = analyzer.polarity_scores(i)["neg"]

# Add each value to the appropriate array
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)

    sentiments.append({"Compound":compound_list,
                       "Positive":positive_list,
                       "Negative":negative_list,
                       "Neutral":neutral_list,
                        "Number Review": counter})

    counter = counter + 1

sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()
#print(reviews1)
#Pull in types of food/income/ and group by for x axis.
# Out:
#    Compound Negative  Neutral  Number Review Positive
# 0  [0.4215]  [0.042]  [0.876]              1  [0.082]
# 1  [0.7645]    [0.0]  [0.886]              2  [0.114]
# 2  [0.9047]  [0.032]  [0.746]              3  [0.222]
# 3  [0.9001]    [0.0]   [0.45]              4   [0.55]
# 4  [0.6249]    [0.0]  [0.728]              5  [0.272]

# %%
#Create graphs. (swarm w/ violin plot)
