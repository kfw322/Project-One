# %% [markdown]
# <h1>YumPy</h1>
#
# <b>Group Members:</b>
# <ul>
# <li>Randi Howell</li>
# <li>Kyrus Wankadiya</li>
# <li>Catherine Safrit</li>
# <li>Monica Sehgal</li>
# </ul>

# %% [markdown]
# <h3>Data Used</h3>
# <ul>
# <li>Income: https://www.kaggle.com/muonneutrino/us-census-demographic-data/data   </li>
# <li>Education: https://www.ers.usda.gov/data-products/county-level-data-sets/</li>
# <li>Yelp Fusion API: https://www.yelp.com/fusion</li>
# </ul>

# %% [markdown]
# <h1>From the top!</h1>
#
# We decided to use the Yelp api, demographic census information, and education data to explore potential correlations. Below is an outline of our projec:
#
# <ul>
# <li>Import dependencies</li>
# <li>Read in CSV data files</li>
# <li>Define US regions based on states</li>
# <li>Create main DataFrame (res_df)</li>
# <li>Coded a for loop to make our API calls and append to res_df</li>
# <li>Exported res_df to a CSV file</li>
# <li>Cleaned up res_df (ex: combine American (new) and American (Traditional) </li>
# <li>Merged our res_df and our counties CSV file</li>
# <li>Examine category distribution across the US</li>
# <li>KYRUS? </li>
# <li>KYRUS?</li>
# <li>Display pie charts for each county thay show restaurant category distribution</li>
# <li>Examined price breakdown based on region and restaurant category</li>
# <li>Produced graphs to illustrate our findings</li>
# <li>MONICA - Compared Pricing and Income?</li>
# <li>MONICA - </li>
# <li>Catherine - EDUCATION</li>
# <li>Conclusions</li>
# <li>Limitations </li>
# <li>If we only had more time...</li>
# </ul>

# %% [markdown]
# <h3>Part 1: Initial Setup</h3>
#
# Below, we imported all of our dependencies including the yelpapi needed for the project. Next, we brought in all of our outside data files, These files include county data, census data, and education data. These were all source from government websites and were CSV files.
#
# Once the CSV files were read in, we modified them as needed to fit in out dataframe. To check the formatting, we used a print statement.

# %%
import yelpapi
import json
import requests
from  pprint import  pprint
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

#reading in county data
counties=pd.read_csv("acs2015_county_data.csv")
counties = counties.loc[counties["TotalPop"]>40000]
counties["county_string"] = counties["County"] + " County, " + counties["State"]
listofcounties = counties["county_string"].tolist()
#reading in zipcodes
zipcodes=pd.read_csv("zip_codes_states.csv")
zipcodes["county_string"] = zipcodes["county"] + " County, " + zipcodes["state"]
listofzipcodes=zipcodes["county_string"].unique().tolist()
counties.to_csv("counties.csv")
zipcodes.to_csv("zcs.csv")
fullcountylist = list(set(listofcounties) & set(listofzipcodes))
counties.head(1)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
#
#    Native           ...             OtherTransp  WorkAtHome  MeanCommute  \
# 0     0.4           ...                     1.3         1.8         26.5
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0     23986         73.6        20.9           5.5         0.0           7.6
#
#              county_string
# 0  Autauga County, Alabama
#
# [1 rows x 38 columns]

# %% [markdown]
# <h3>Part 1: County Setup</h3>
#
# In the framework portion, we established regions of the US that we will use later, created a new dataframe that holds out counties, and created a list to hold all the randomly generated countries. This will be more important later.

# %%
#creating regions
WC = ["Washington","Oregon","California","Nevada","Idaho"]
MW = ["Montana","Wyoming","North Dakota","South Dakota","Nebraska","Kansas","Minnesota","Iowa","Missouri",
      "Wisconsin","Illinois","Michigan","Indiana","Ohio","Kentucky"]
SW = ["Arizona","Utah","Colorado","New Mexico","Oklahoma","Texas"]
SE = ["Arkansas","Louisiana","Mississippi","Alabama","Tennessee","Virginia","West Virginia","North Carolina","South Carolina","Georgia","Florida"]
NE = ["District of Columbia","Pennsylvania","Maryland","Delaware","New Jersey","New York","Maine","New Hampshire","Vermont","Massachusetts","Rhode Island","Connecticut"]
counties["Region"]= np.where(counties["State"].isin(WC),'WC',
                    np.where(counties["State"].isin(MW),'MW',
                    np.where(counties["State"].isin(SW),'SW',
                    np.where(counties["State"].isin(SE),'SE',
                    np.where(counties["State"].isin(NE),'NE', 
                             'other')))))

# %%
#counties.groupby(["Region"]).sum()["TotalPop"]
cdf = pd.DataFrame(counties,columns=["county_string","Region"])
WClist = (cdf.groupby("Region").get_group("WC")["county_string"]).tolist()
MWlist = (cdf.groupby("Region").get_group("MW")["county_string"]).tolist()
SWlist = (cdf.groupby("Region").get_group("SW")["county_string"]).tolist()
SElist = (cdf.groupby("Region").get_group("SE")["county_string"]).tolist()
NElist = (cdf.groupby("Region").get_group("NE")["county_string"]).tolist()

sample_list = ["Mecklenburg County, North Carolina"]
sample_list.extend(random.sample(list(set(WClist) & set(fullcountylist)),10))
sample_list.extend(random.sample(list(set(MWlist) & set(fullcountylist)),10))
sample_list.extend(random.sample(list(set(SWlist) & set(fullcountylist)),10))
sample_list.extend(random.sample(list(set(SElist) & set(fullcountylist)),9))
sample_list.extend(random.sample(list(set(NElist) & set(fullcountylist)),10))
sample_list
# Out:
# ['Mecklenburg County, North Carolina',
#  'Carson City County, Nevada',
#  'Lake County, California',
#  'Clackamas County, Oregon',
#  'San Mateo County, California',
#  'Mendocino County, California',
#  'Kings County, California',
#  'Douglas County, Nevada',
#  'Napa County, California',
#  'Madera County, California',
#  'Benton County, Washington',
#  'Gratiot County, Michigan',
#  'Taney County, Missouri',
#  'Muskingum County, Ohio',
#  'Shelby County, Indiana',
#  'Linn County, Iowa',
#  'Tippecanoe County, Indiana',
#  'Monroe County, Wisconsin',
#  'Geauga County, Ohio',
#  'Burleigh County, North Dakota',
#  'Allegan County, Michigan',
#  'Van Zandt County, Texas',
#  'Jim Wells County, Texas',
#  'Arapahoe County, Colorado',
#  'Salt Lake County, Utah',
#  'Bernalillo County, New Mexico',
#  'Denton County, Texas',
#  'Montrose County, Colorado',
#  'Garfield County, Colorado',
#  'Brazos County, Texas',
#  'Apache County, Arizona',
#  'Horry County, South Carolina',
#  'Florence County, South Carolina',
#  'Escambia County, Florida',
#  'Madison County, Alabama',
#  'Cumberland County, North Carolina',
#  'Richmond County, Georgia',
#  'Halifax County, North Carolina',
#  'Jackson County, North Carolina',
#  'Washington County, Virginia',
#  'Clearfield County, Pennsylvania',
#  'Chautauqua County, New York',
#  'Chenango County, New York',
#  'Ocean County, New Jersey',
#  'Clinton County, New York',
#  'Hampden County, Massachusetts',
#  'Cattaraugus County, New York',
#  'Otsego County, New York',
#  'Camden County, New Jersey',
#  'Philadelphia County, Pennsylvania']

# %% [markdown]
# <h3>Part 1: Establishing the Main DataFrame</h3>
#
# After reading in the county data and creating regions, we established our primary dataframe. We named the dataframe res_df. This dataframe will be used throughout the project.

# %%
res_df = pd.DataFrame(columns=["name","zipcode","county_string","rating","review_count","category","price","region"])
res_df

vclist = []

# %% [markdown]
# <h3>Part 1: The Framework - Kyrus For Loop</h3>
#
# Kyrus was able to build the primary framework for our project. With multiple nested for loops, Kyrus was able to make the Yelp API call, loop through the first 50 pages for each restuarunt type, then red in that data and append it to the res_df dataframe.
#
# Kyrus also included a try/ecxcept option as a way to check or verify the code was working and pulling in the data correctly.

# %%
term = ["Italian","Mexican","Chinese","American (Traditional)","American (New)"]
r = 0
for c in sample_list:
    county_string = str(c)
    if 1==1:
        #we are allowed 5000 queries per 24 hours. if we run out, we can create another. till then, use this
        yelpkey="C8I4eLOGfKC0Ni9OwrjQXNjQW5MHDwB34C390sRP5KLXpEwWg7Dbk-Sbq5REVgF19GtJxe-oe2xciOGfouLPahK4O9kArrG40ZsxXOKyaZ1u-NeU7RGgeOipBf7DWnYx"
        #yelpkey="IXRN_1GI8f8J9Kj5O5GciqeyFSWR5RMh41_rADGy1KrtQ5ZABGGZEkWwot5mOka0NlzlNxXPmzYXLWk88oOV0N_YxD1MSW4kQRfJnFrwfHLtKrr2HcsjLo6uWBzAWnYx"
        if 1==1:
            
            for offset in range(0,20):
                
                response = requests.get(url="https://api.yelp.com/v3/businesses/search", 
                       params= {"location": county_string, "limit":"50", "offset": offset*50}, 
                       headers={'Authorization': 'bearer %s' % yelpkey})
                responsejson = response.json()
                print(offset*50)
                if 1==1:
                    count=0
                    for x in range(0,len(responsejson["businesses"])):
                        
                        try:
                            if((responsejson["businesses"][x]["review_count"] > 0)):
                                zc = int(responsejson["businesses"][x]["location"]["zip_code"])
                                
                                try:
                                    
                                    if (zipcodes.loc[zipcodes["zip_code"]==zc]["county_string"].tolist()[0]== county_string):
                                        for y in range(0,len(responsejson["businesses"][x]["categories"])):
                                            if 1==1:
                                                
                                                    
#                                                 print(  count,
#                                                         responsejson["businesses"][x]["name"],
#                                                         str(zc),
#                                                         county_string,
#                                                         responsejson["businesses"][x]["rating"],
#                                                         responsejson["businesses"][x]["review_count"],
#                                                         responsejson["businesses"][x]["categories"][y]["title"],
#                                                         responsejson["businesses"][x]["price"],
#                                                         "region")
                                                
                                                if str(responsejson["businesses"][x]["categories"][y]["title"]) in (term):
                                                    res_df.loc[r]=[responsejson["businesses"][x]["name"],
                                                        str(zc),
                                                        county_string,
                                                        responsejson["businesses"][x]["rating"],
                                                        responsejson["businesses"][x]["review_count"],
                                                        responsejson["businesses"][x]["categories"][y]["title"],
                                                        responsejson["businesses"][x]["price"],
                                                        "region"
                                                    ]
                                        
                                                    r += 1
                                        count += 1
                                        vclist.append(county_string)
                                            
                                            #except:
                                            #    print("")
                                            #    break
                                except:
                                    print("ERROR1")
                                #    break
                                    
                        except:
                            print("ERROR2")
                        #    break
                #except:
                #    print("ERROR3")
                #    break
    
                #print("End of list. Found", count, term, "restaurants in", county_string)
        #except:
        #    print("ERROR4: this one should never happen")
        #    break
# Out:
# 0
# 50
# 100
# ERROR1
# 150
# 200
# 250
# 300
# 350
# 400
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 450
# 500
# 550
# ERROR1
# ERROR1
# 600
# 650
# ERROR1
# 700
# ERROR1
# ERROR2
# ERROR1
# 750
# ERROR1
# 800
# 850
# ERROR1
# 900
# 950
# ERROR1
# ERROR1
# ERROR2
# 0
# 50
# 100
# ERROR1
# 150
# 200
# ERROR1
# ERROR1
# 250
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 300
# ERROR2
# ERROR1
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# 100
# 150
# ERROR1
# 200
# 250
# ERROR1
# 300
# ERROR1
# 350
# ERROR1
# 400
# ERROR1
# ERROR1
# 450
# ERROR2
# 500
# 550
# ERROR1
# ERROR1
# 600
# ERROR1
# 650
# ERROR1
# ERROR1
# 700
# ERROR1
# ERROR1
# ERROR1
# 750
# ERROR1
# 800
# 850
# ERROR1
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# ERROR2
# ERROR1
# 250
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# ERROR1
# 550
# 600
# ERROR1
# 650
# ERROR2
# 700
# 750
# ERROR2
# 800
# 850
# 900
# ERROR1
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# ERROR1
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 50
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR2
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# 50
# ERROR1
# ERROR1
# ERROR1
# 100
# ERROR1
# ERROR1
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# ERROR1
# ERROR1
# 150
# ERROR1
# 200
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 250
# ERROR1
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# ERROR1
# 250
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 300
# ERROR1
# 350
# ERROR1
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# ERROR1
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 200
# ERROR1
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR2
# ERROR1
# ERROR1
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR2
# 50
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# ERROR1
# 100
# ERROR1
# 150
# ERROR1
# 200
# ERROR1
# 250
# 300
# 350
# ERROR1
# 400
# 450
# ERROR1
# 500
# 550
# ERROR1
# 600
# ERROR1
# 650
# ERROR1
# 700
# 750
# ERROR1
# ERROR1
# ERROR1
# 800
# 850
# ERROR2
# ERROR1
# 900
# ERROR1
# 950
# ERROR1
# ERROR1
# ERROR1
# 0
# 50
# 100
# 150
# ERROR1
# 200
# ERROR2
# 250
# ERROR1
# 300
# 350
# 400
# 450
# ERROR1
# 500
# 550
# ERROR1
# 600
# ERROR1
# ERROR1
# 650
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 700
# ERROR2
# ERROR1
# ERROR1
# 750
# ERROR1
# 800
# ERROR2
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 850
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 900
# ERROR2
# ERROR1
# ERROR2
# 950
# ERROR1
# 0
# 50
# 100
# ERROR2
# ERROR1
# 150
# 200
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 250
# ERROR1
# ERROR1
# 300
# ERROR1
# ERROR1
# ERROR2
# ERROR1
# 350
# ERROR1
# ERROR1
# ERROR2
# ERROR1
# ERROR1
# ERROR1
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# ERROR1
# ERROR1
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# 200
# ERROR1
# 250
# 300
# ERROR1
# ERROR1
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# 200
# ERROR1
# ERROR1
# 250
# ERROR1
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# 100
# 150
# 200
# ERROR1
# ERROR1
# 250
# ERROR1
# ERROR1
# ERROR1
# 300
# ERROR1
# ERROR1
# 350
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 400
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 450
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 500
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 550
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 600
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR2
# 50
# ERROR1
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# ERROR2
# 300
# ERROR1
# 350
# 400
# 450
# 500
# ERROR1
# 550
# 600
# ERROR1
# 650
# 700
# 750
# 800
# ERROR1
# 850
# ERROR1
# ERROR1
# 900
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 950
# ERROR1
# 0
# 50
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# 150
# 200
# ERROR1
# ERROR2
# ERROR1
# 250
# ERROR1
# ERROR1
# 300
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 350
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# 50
# ERROR1
# ERROR1
# 100
# ERROR1
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# ERROR1
# ERROR1
# ERROR1
# 200
# ERROR1
# ERROR1
# 250
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 300
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 350
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 400
# ERROR1
# ERROR1
# ERROR1
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# 50
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 200
# ERROR1
# ERROR1
# ERROR1
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# ERROR1
# 250
# 300
# ERROR1
# ERROR1
# 350
# ERROR1
# ERROR1
# ERROR2
# ERROR1
# ERROR1
# ERROR1
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# 50
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# ERROR1
# 100
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 150
# ERROR1
# ERROR1
# ERROR1
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# ERROR1
# 300
# ERROR1
# 350
# ERROR1
# ERROR1
# 400
# ERROR1
# 450
# ERROR1
# ERROR1
# 500
# ERROR1
# 550
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 600
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 650
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 700
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# ERROR1
# ERROR1
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# ERROR1
# ERROR1
# 350
# ERROR1
# ERROR1
# ERROR1
# 400
# 450
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 500
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 550
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 600
# ERROR1
# ERROR1
# ERROR2
# ERROR1
# 650
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 700
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# ERROR1
# 750
# 800
# 850
# 900
# 950
# 0
# 50
# 100
# 150
# ERROR1
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# ERROR1
# 550
# 600
# ERROR1
# 650
# 700
# 750
# ERROR1
# 800
# ERROR1
# 850
# 900
# ERROR1
# 950

# %% [markdown]
# <h3>Part 1: Cleaning the Data</h3>
#
# After waiting forever for the Kyrus for loop to finish, we needed to clean up the data. Early on, we noticed that res_df displayed \$, \$\$, and \$\$\$ in the price column, but would not show \$\$\$\$. After several attempts, we decided to replace the dollar signs with equivalent numerical value. Thus, we ended up with the following:
#
# <ul>
# <li>\$ = 1 </li>
# <li>\$\$= 2 </li>
# <li>\$\$\$ = 3 </li>
# <li>\$\$\$\$ = 4 </li>
# </ul>
#
# Additionally, we realized the Yelp does not have an American category. Instead, Yelp uses American (New) and American (Traditional). After some research, we realized that we were not entirely sure what the exact difference between the two American sub-categories were, so we opted to merge the two category types into one - American.
#
# After these corrections, we saved the changes to the res_df dataframe.

# %%
res_df.to_csv("output201804080249.csv")
try:
    res_df.price.replace(["","$","$$","$$$","$$$$"],[0,1,2,3,4],inplace=True)
except:
    print("Already done")
try:
    res_df.category.replace(["American (New)","American (Traditional)"],["American","American"],inplace=True)
except:
    print("Already done")

res_df=res_df.drop_duplicates(subset=["name","zipcode","county_string","review_count","category"],keep="first")
res_df
# Out:
#                                              name zipcode  \
# 0                                  Cabo Fish Taco   28205
# 1                              Midwood Smokehouse   28205
# 2                        Sabor Latin Street Grill   28204
# 3                                Benny Pennello's   28205
# 4                                     JackBeagles   28205
# 5                       The Cellar At Duckworth's   28202
# 6                          Pinky's Westside Grill   28208
# 7                         The Fig Tree Restaurant   28204
# 8                         The Fig Tree Restaurant   28204
# 9                       VBGB Beer Hall and Garden   28206
# 10                               Dandelion Market   28202
# 11                             Growlers Pourhouse   28205
# 12                            Alexander Michael's   28202
# 13                Sabor Latin Street Grill - Noda   28205
# 14                                   Tupelo Honey   28203
# 15                             The King's Kitchen   28202
# 16                   Davidson Street Public House   28205
# 17    Three Amigos Mexican Restaurant and Cantina   28205
# 18                                       300 East   28203
# 19                               Rooster's Uptown   28202
# 20                                    Las Lupitas   28213
# 21                                        5Church   28202
# 22                          Good Food on Montford   28209
# 23                                   Mimosa Grill   28202
# 24                                     The Asbury   28202
# 25                                 Midnight Diner   28202
# 26                                 Mama Ricotta's   28204
# 27                                     Papi Queso   28202
# 28                  Lebowski's Neighborhood Grill   28203
# 29               Carpe Diem Restaurant & Caterers   28204
# ...                                           ...     ...
# 3823                                      Fiorino   19129
# 3824                                Veggie Lovers   19107
# 3825                        The Tavern Restaurant   19107
# 3826                                Pancho's Cafe   19123
# 3827                                      Mad Rex   19125
# 3828                                 Franks Pizza   19129
# 3829                                       Jansen   19119
# 3830                     Urban Village Brewing Co   19123
# 3831                                Los Camaradas   19146
# 3832                                El Azteca Uno   19106
# 3833                          Guacamole Mex-Grill   19143
# 3834                          Mac Mart Food Truck   19103
# 3835                        Noir Restaurant & Bar   19148
# 3836                                      Gnocchi   19147
# 3837                             Trolley Car Cafe   19129
# 3838                        Golden Empress Garden   19147
# 3839                               La Viola Ovest   19102
# 3840                                    Scarpetta   19103
# 3841                                    Scarpetta   19103
# 3842                                Taylor's Cafe   19128
# 3843                 Union League of Philadelphia   19102
# 3844                               The Adobe Cafe   19128
# 3845                                Mr Joe's Cafe   19147
# 3846                          Lazos Pizza & Grill   19130
# 3847                          Lazos Pizza & Grill   19130
# 3848                       Marathon On the Square   19103
# 3849                                 The Gaslight   19106
# 3850                           Three Monkeys Cafe   19114
# 3851                             Valley Green Inn   19128
# 3852                           Tavern On the Hill   19118
#
#                            county_string  rating review_count  category  \
# 0     Mecklenburg County, North Carolina     4.0          989   Mexican
# 1     Mecklenburg County, North Carolina     4.5         1281  American
# 2     Mecklenburg County, North Carolina     4.5          684   Mexican
# 3     Mecklenburg County, North Carolina     4.0          234   Italian
# 4     Mecklenburg County, North Carolina     4.0          292  American
# 5     Mecklenburg County, North Carolina     4.5          361  American
# 6     Mecklenburg County, North Carolina     4.0          856  American
# 7     Mecklenburg County, North Carolina     4.5          343  American
# 8     Mecklenburg County, North Carolina     4.5          343   Italian
# 9     Mecklenburg County, North Carolina     4.5          326  American
# 10    Mecklenburg County, North Carolina     4.0          553  American
# 11    Mecklenburg County, North Carolina     4.0          202  American
# 12    Mecklenburg County, North Carolina     4.5          331  American
# 13    Mecklenburg County, North Carolina     4.5          157   Mexican
# 14    Mecklenburg County, North Carolina     4.0         1180  American
# 15    Mecklenburg County, North Carolina     4.0          484  American
# 16    Mecklenburg County, North Carolina     4.0          136  American
# 17    Mecklenburg County, North Carolina     4.0          375   Mexican
# 18    Mecklenburg County, North Carolina     4.0          583  American
# 19    Mecklenburg County, North Carolina     4.0          402  American
# 20    Mecklenburg County, North Carolina     4.5           49   Mexican
# 21    Mecklenburg County, North Carolina     3.5          575  American
# 22    Mecklenburg County, North Carolina     4.5          583  American
# 23    Mecklenburg County, North Carolina     4.0          427  American
# 24    Mecklenburg County, North Carolina     4.0          205  American
# 25    Mecklenburg County, North Carolina     4.0          613  American
# 26    Mecklenburg County, North Carolina     4.0          415   Italian
# 27    Mecklenburg County, North Carolina     4.5          127  American
# 28    Mecklenburg County, North Carolina     4.5          336  American
# 29    Mecklenburg County, North Carolina     4.0          174  American
# ...                                  ...     ...          ...       ...
# 3823   Philadelphia County, Pennsylvania     4.5          247   Italian
# 3824   Philadelphia County, Pennsylvania     3.5          136   Chinese
# 3825   Philadelphia County, Pennsylvania     4.5           63  American
# 3826   Philadelphia County, Pennsylvania     4.5           44   Mexican
# 3827   Philadelphia County, Pennsylvania     4.0          172  American
# 3828   Philadelphia County, Pennsylvania     4.0           84   Italian
# 3829   Philadelphia County, Pennsylvania     4.5           71  American
# 3830   Philadelphia County, Pennsylvania     4.0           85  American
# 3831   Philadelphia County, Pennsylvania     4.0          119   Mexican
# 3832   Philadelphia County, Pennsylvania     3.5          211   Mexican
# 3833   Philadelphia County, Pennsylvania     4.0          115   Mexican
# 3834   Philadelphia County, Pennsylvania     4.0           80  American
# 3835   Philadelphia County, Pennsylvania     4.0          109   Italian
# 3836   Philadelphia County, Pennsylvania     4.0          148   Italian
# 3837   Philadelphia County, Pennsylvania     3.5          184  American
# 3838   Philadelphia County, Pennsylvania     3.5          159   Chinese
# 3839   Philadelphia County, Pennsylvania     3.5          175   Italian
# 3840   Philadelphia County, Pennsylvania     4.0          116   Italian
# 3841   Philadelphia County, Pennsylvania     4.0          116  American
# 3842   Philadelphia County, Pennsylvania     3.5          115  American
# 3843   Philadelphia County, Pennsylvania     4.0           58  American
# 3844   Philadelphia County, Pennsylvania     3.5          258   Mexican
# 3845   Philadelphia County, Pennsylvania     4.5           57   Italian
# 3846   Philadelphia County, Pennsylvania     4.0          131  American
# 3847   Philadelphia County, Pennsylvania     4.0          131   Italian
# 3848   Philadelphia County, Pennsylvania     3.5          203  American
# 3849   Philadelphia County, Pennsylvania     3.5          207  American
# 3850   Philadelphia County, Pennsylvania     3.5          251  American
# 3851   Philadelphia County, Pennsylvania     3.5          153  American
# 3852   Philadelphia County, Pennsylvania     4.0          110  American
#
#       price  region
# 0         2  region
# 1         2  region
# 2         1  region
# 3         1  region
# 4         1  region
# 5         2  region
# 6         1  region
# 7         3  region
# 8         3  region
# 9         2  region
# 10        2  region
# 11        2  region
# 12        2  region
# 13        1  region
# 14        2  region
# 15        2  region
# 16        2  region
# 17        1  region
# 18        2  region
# 19        2  region
# 20        1  region
# 21        2  region
# 22        2  region
# 23        2  region
# 24        2  region
# 25        1  region
# 26        2  region
# 27        1  region
# 28        2  region
# 29        3  region
# ...     ...     ...
# 3823      2  region
# 3824      2  region
# 3825      2  region
# 3826      1  region
# 3827      2  region
# 3828      1  region
# 3829      3  region
# 3830      2  region
# 3831      2  region
# 3832      2  region
# 3833      1  region
# 3834      1  region
# 3835      2  region
# 3836      2  region
# 3837      2  region
# 3838      1  region
# 3839      2  region
# 3840      3  region
# 3841      3  region
# 3842      2  region
# 3843      4  region
# 3844      2  region
# 3845      2  region
# 3846      1  region
# 3847      1  region
# 3848      2  region
# 3849      2  region
# 3850      2  region
# 3851      2  region
# 3852      2  region
#
# [3831 rows x 8 columns]

# %%
rvc = pd.DataFrame(vclist, columns=["a"])["a"].value_counts().reset_index()
rvc.columns = ["county_string","total restaurants in county"]
rvc
counties = counties.merge(rvc, how="left", on="county_string")

# %% [markdown]
# <h3>Part 1: adding monica's things here</h3>

# %%
res_df.groupby("category").mean().plot(kind="bar",figsize=(16,9))
plt.xlabel("Category")
plt.ylabel("Ratings / Price")
plt.title("Comparing Price and Ratings Per Restaurant Type")
plt.savefig("Comparing_price_and_ratingcourt.png")
plt.show()

# %%
#merge res. data with county data
merged=pd.merge(res_df,counties,how="left",on="county_string")
#only bringing in the fields we need
newdf1=merged[["category","Region","county_string","price","rating","review_count","Income"]]
newdf=newdf1.groupby(["category","Region","price","rating","Income"])["review_count"].sum()
newdf.to_csv("newdf1.csv",header=True)
newdf=pd.read_csv("newdf1.csv")
newdf.head()
# Out:
#    category Region  price  rating   Income  review_count
# 0  American     MW      1     2.0  41130.0             3
# 1  American     MW      1     2.0  45932.0            31
# 2  American     MW      1     2.0  59322.0            18
# 3  American     MW      1     2.5  41130.0             7
# 4  American     MW      1     2.5  45932.0            58

# %%
newdf5=newdf[["category","Region","price","rating"]]
newdf6=newdf[["category","Region","review_count"]]
newdf6["Incomecalc"]=newdf["Income"]
newdf5.head()
# Out:
# C:\Users\kfw32\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    category Region  price  rating
# 0  American     MW      1     2.0
# 1  American     MW      1     2.0
# 2  American     MW      1     2.0
# 3  American     MW      1     2.5
# 4  American     MW      1     2.5

# %%
newdf5.groupby("category").mean().plot(kind="bar",figsize=(16,9))
plt.xlabel("Food category")
plt.ylabel("Ratings and Price")
plt.title("Comparing Price and Rating by Food Category")
plt.text(5,2, "", fontsize=12)
plt.savefig("Comparing_price_and_ratingcount.png")
plt.show()

# %%
newdf5.groupby("Region").mean().plot(kind="bar",figsize=(16,9))
plt.xlabel("Food category")
plt.ylabel("Ratings and Price")
plt.title("Comparing Price and Rating by Region")
plt.text(5,2, "", fontsize=12)
plt.savefig("Comparing_price_and_rating_count.png")
plt.show()

# %%
#plt.xlabel("Region")
#plt.ylabel("Review Count and Income") #to change to double y axis
fig=plt.figure()
ax1=fig.add_subplot(111)
ax2=ax1.twinx()
newdf6.groupby("Region").mean()["Incomecalc"].plot(kind="bar",ax=ax1, width=.25,position=1, color="green")
newdf6.groupby("Region").mean()["review_count"].plot(kind="bar",ax=ax2, width=.25, position=0, color="orange")
ax1.set_ylabel("Incomecalc")
ax2.set_ylabel("review_count")
plt.title("Comparing Average Income With Review Count")
plt.text(5,2, "", fontsize=12)
plt.savefig("ReviewVsIncome.png")
plt.show()

# %%
sns.swarmplot(x="price",y="rating",data=newdf5, hue="Region")
plt.title("Human Behavior Comparison: Price range and average reviews by region")
plt.text(5,2, "", fontsize=12)
plt.show()

# %%
sns.swarmplot(x="price",y="rating",data=newdf5, hue="category")
plt.title("Human Behavior Comparison: Price range and average reviews by restaurant type")
plt.text(5,2, "", fontsize=12)
plt.show()

# %% [markdown]
# <h3>Part 1: Merging Data</h3>
#
# Since a large part of our project revolved around correlationg geograpic location and Yelp restaurant data, we needed to merge all the necessary information into one larger dataframe. Thus, we merged res_df with our counties data on the county_string column. This allowed us to pull in and use all the data from both sources.
#
# Up until this point, if you noticed above, we had not inserted our regions, only created a placeholder column. In merging the two datasets, we were also able to populate our region column accordingly.
#
# We then printed res_df as a check to verify contents.

# %%
res_df= pd.merge(res_df,counties,how="left",on="county_string")
res_df.head()
# Out:
#                        name zipcode                       county_string  \
# 0            Cabo Fish Taco   28205  Mecklenburg County, North Carolina
# 1        Midwood Smokehouse   28205  Mecklenburg County, North Carolina
# 2  Sabor Latin Street Grill   28204  Mecklenburg County, North Carolina
# 3          Benny Pennello's   28205  Mecklenburg County, North Carolina
# 4               JackBeagles   28205  Mecklenburg County, North Carolina
#
#    rating review_count  category  price  region  CensusId           State  \
# 0     4.0          989   Mexican      2  region     37119  North Carolina
# 1     4.5         1281  American      2  region     37119  North Carolina
# 2     4.5          684   Mexican      1  region     37119  North Carolina
# 3     4.0          234   Italian      1  region     37119  North Carolina
# 4     4.0          292  American      1  region     37119  North Carolina
#
#               ...              WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0             ...                     6.1         25.3    502455         86.0
# 1             ...                     6.1         25.3    502455         86.0
# 2             ...                     6.1         25.3    502455         86.0
# 3             ...                     6.1         25.3    502455         86.0
# 4             ...                     6.1         25.3    502455         86.0
#
#    PublicWork  SelfEmployed  FamilyWork  Unemployment  Region  \
# 0         9.1           4.8         0.1           8.9      SE
# 1         9.1           4.8         0.1           8.9      SE
# 2         9.1           4.8         0.1           8.9      SE
# 3         9.1           4.8         0.1           8.9      SE
# 4         9.1           4.8         0.1           8.9      SE
#
#    total restaurants in county
# 0                        982.0
# 1                        982.0
# 2                        982.0
# 3                        982.0
# 4                        982.0
#
# [5 rows x 47 columns]

# %% [markdown]
# <h3>IDK - KYRUS can fill this part in. </h3>
# <h3>Part 2: Examining category distribution across the US </h3>

# %%
itadf = res_df.groupby(res_df["category"]).get_group("Italian")
mexdf = res_df.groupby(res_df["category"]).get_group("Mexican")
chndf = res_df.groupby(res_df["category"]).get_group("Chinese")
usadf = res_df.groupby(res_df["category"]).get_group("American")
res_df
# Out:
#                                              name zipcode  \
# 0                                  Cabo Fish Taco   28205
# 1                              Midwood Smokehouse   28205
# 2                        Sabor Latin Street Grill   28204
# 3                                Benny Pennello's   28205
# 4                                     JackBeagles   28205
# 5                       The Cellar At Duckworth's   28202
# 6                          Pinky's Westside Grill   28208
# 7                         The Fig Tree Restaurant   28204
# 8                         The Fig Tree Restaurant   28204
# 9                       VBGB Beer Hall and Garden   28206
# 10                               Dandelion Market   28202
# 11                             Growlers Pourhouse   28205
# 12                            Alexander Michael's   28202
# 13                Sabor Latin Street Grill - Noda   28205
# 14                                   Tupelo Honey   28203
# 15                             The King's Kitchen   28202
# 16                   Davidson Street Public House   28205
# 17    Three Amigos Mexican Restaurant and Cantina   28205
# 18                                       300 East   28203
# 19                               Rooster's Uptown   28202
# 20                                    Las Lupitas   28213
# 21                                        5Church   28202
# 22                          Good Food on Montford   28209
# 23                                   Mimosa Grill   28202
# 24                                     The Asbury   28202
# 25                                 Midnight Diner   28202
# 26                                 Mama Ricotta's   28204
# 27                                     Papi Queso   28202
# 28                  Lebowski's Neighborhood Grill   28203
# 29               Carpe Diem Restaurant & Caterers   28204
# ...                                           ...     ...
# 3801                                      Fiorino   19129
# 3802                                Veggie Lovers   19107
# 3803                        The Tavern Restaurant   19107
# 3804                                Pancho's Cafe   19123
# 3805                                      Mad Rex   19125
# 3806                                 Franks Pizza   19129
# 3807                                       Jansen   19119
# 3808                     Urban Village Brewing Co   19123
# 3809                                Los Camaradas   19146
# 3810                                El Azteca Uno   19106
# 3811                          Guacamole Mex-Grill   19143
# 3812                          Mac Mart Food Truck   19103
# 3813                        Noir Restaurant & Bar   19148
# 3814                                      Gnocchi   19147
# 3815                             Trolley Car Cafe   19129
# 3816                        Golden Empress Garden   19147
# 3817                               La Viola Ovest   19102
# 3818                                    Scarpetta   19103
# 3819                                    Scarpetta   19103
# 3820                                Taylor's Cafe   19128
# 3821                 Union League of Philadelphia   19102
# 3822                               The Adobe Cafe   19128
# 3823                                Mr Joe's Cafe   19147
# 3824                          Lazos Pizza & Grill   19130
# 3825                          Lazos Pizza & Grill   19130
# 3826                       Marathon On the Square   19103
# 3827                                 The Gaslight   19106
# 3828                           Three Monkeys Cafe   19114
# 3829                             Valley Green Inn   19128
# 3830                           Tavern On the Hill   19118
#
#                            county_string  rating review_count  category  \
# 0     Mecklenburg County, North Carolina     4.0          989   Mexican
# 1     Mecklenburg County, North Carolina     4.5         1281  American
# 2     Mecklenburg County, North Carolina     4.5          684   Mexican
# 3     Mecklenburg County, North Carolina     4.0          234   Italian
# 4     Mecklenburg County, North Carolina     4.0          292  American
# 5     Mecklenburg County, North Carolina     4.5          361  American
# 6     Mecklenburg County, North Carolina     4.0          856  American
# 7     Mecklenburg County, North Carolina     4.5          343  American
# 8     Mecklenburg County, North Carolina     4.5          343   Italian
# 9     Mecklenburg County, North Carolina     4.5          326  American
# 10    Mecklenburg County, North Carolina     4.0          553  American
# 11    Mecklenburg County, North Carolina     4.0          202  American
# 12    Mecklenburg County, North Carolina     4.5          331  American
# 13    Mecklenburg County, North Carolina     4.5          157   Mexican
# 14    Mecklenburg County, North Carolina     4.0         1180  American
# 15    Mecklenburg County, North Carolina     4.0          484  American
# 16    Mecklenburg County, North Carolina     4.0          136  American
# 17    Mecklenburg County, North Carolina     4.0          375   Mexican
# 18    Mecklenburg County, North Carolina     4.0          583  American
# 19    Mecklenburg County, North Carolina     4.0          402  American
# 20    Mecklenburg County, North Carolina     4.5           49   Mexican
# 21    Mecklenburg County, North Carolina     3.5          575  American
# 22    Mecklenburg County, North Carolina     4.5          583  American
# 23    Mecklenburg County, North Carolina     4.0          427  American
# 24    Mecklenburg County, North Carolina     4.0          205  American
# 25    Mecklenburg County, North Carolina     4.0          613  American
# 26    Mecklenburg County, North Carolina     4.0          415   Italian
# 27    Mecklenburg County, North Carolina     4.5          127  American
# 28    Mecklenburg County, North Carolina     4.5          336  American
# 29    Mecklenburg County, North Carolina     4.0          174  American
# ...                                  ...     ...          ...       ...
# 3801   Philadelphia County, Pennsylvania     4.5          247   Italian
# 3802   Philadelphia County, Pennsylvania     3.5          136   Chinese
# 3803   Philadelphia County, Pennsylvania     4.5           63  American
# 3804   Philadelphia County, Pennsylvania     4.5           44   Mexican
# 3805   Philadelphia County, Pennsylvania     4.0          172  American
# 3806   Philadelphia County, Pennsylvania     4.0           84   Italian
# 3807   Philadelphia County, Pennsylvania     4.5           71  American
# 3808   Philadelphia County, Pennsylvania     4.0           85  American
# 3809   Philadelphia County, Pennsylvania     4.0          119   Mexican
# 3810   Philadelphia County, Pennsylvania     3.5          211   Mexican
# 3811   Philadelphia County, Pennsylvania     4.0          115   Mexican
# 3812   Philadelphia County, Pennsylvania     4.0           80  American
# 3813   Philadelphia County, Pennsylvania     4.0          109   Italian
# 3814   Philadelphia County, Pennsylvania     4.0          148   Italian
# 3815   Philadelphia County, Pennsylvania     3.5          184  American
# 3816   Philadelphia County, Pennsylvania     3.5          159   Chinese
# 3817   Philadelphia County, Pennsylvania     3.5          175   Italian
# 3818   Philadelphia County, Pennsylvania     4.0          116   Italian
# 3819   Philadelphia County, Pennsylvania     4.0          116  American
# 3820   Philadelphia County, Pennsylvania     3.5          115  American
# 3821   Philadelphia County, Pennsylvania     4.0           58  American
# 3822   Philadelphia County, Pennsylvania     3.5          258   Mexican
# 3823   Philadelphia County, Pennsylvania     4.5           57   Italian
# 3824   Philadelphia County, Pennsylvania     4.0          131  American
# 3825   Philadelphia County, Pennsylvania     4.0          131   Italian
# 3826   Philadelphia County, Pennsylvania     3.5          203  American
# 3827   Philadelphia County, Pennsylvania     3.5          207  American
# 3828   Philadelphia County, Pennsylvania     3.5          251  American
# 3829   Philadelphia County, Pennsylvania     3.5          153  American
# 3830   Philadelphia County, Pennsylvania     4.0          110  American
#
#       price  region  CensusId           State             ...               \
# 0         2  region     37119  North Carolina             ...
# 1         2  region     37119  North Carolina             ...
# 2         1  region     37119  North Carolina             ...
# 3         1  region     37119  North Carolina             ...
# 4         1  region     37119  North Carolina             ...
# 5         2  region     37119  North Carolina             ...
# 6         1  region     37119  North Carolina             ...
# 7         3  region     37119  North Carolina             ...
# 8         3  region     37119  North Carolina             ...
# 9         2  region     37119  North Carolina             ...
# 10        2  region     37119  North Carolina             ...
# 11        2  region     37119  North Carolina             ...
# 12        2  region     37119  North Carolina             ...
# 13        1  region     37119  North Carolina             ...
# 14        2  region     37119  North Carolina             ...
# 15        2  region     37119  North Carolina             ...
# 16        2  region     37119  North Carolina             ...
# 17        1  region     37119  North Carolina             ...
# 18        2  region     37119  North Carolina             ...
# 19        2  region     37119  North Carolina             ...
# 20        1  region     37119  North Carolina             ...
# 21        2  region     37119  North Carolina             ...
# 22        2  region     37119  North Carolina             ...
# 23        2  region     37119  North Carolina             ...
# 24        2  region     37119  North Carolina             ...
# 25        1  region     37119  North Carolina             ...
# 26        2  region     37119  North Carolina             ...
# 27        1  region     37119  North Carolina             ...
# 28        2  region     37119  North Carolina             ...
# 29        3  region     37119  North Carolina             ...
# ...     ...     ...       ...             ...             ...
# 3801      2  region     42101    Pennsylvania             ...
# 3802      2  region     42101    Pennsylvania             ...
# 3803      2  region     42101    Pennsylvania             ...
# 3804      1  region     42101    Pennsylvania             ...
# 3805      2  region     42101    Pennsylvania             ...
# 3806      1  region     42101    Pennsylvania             ...
# 3807      3  region     42101    Pennsylvania             ...
# 3808      2  region     42101    Pennsylvania             ...
# 3809      2  region     42101    Pennsylvania             ...
# 3810      2  region     42101    Pennsylvania             ...
# 3811      1  region     42101    Pennsylvania             ...
# 3812      1  region     42101    Pennsylvania             ...
# 3813      2  region     42101    Pennsylvania             ...
# 3814      2  region     42101    Pennsylvania             ...
# 3815      2  region     42101    Pennsylvania             ...
# 3816      1  region     42101    Pennsylvania             ...
# 3817      2  region     42101    Pennsylvania             ...
# 3818      3  region     42101    Pennsylvania             ...
# 3819      3  region     42101    Pennsylvania             ...
# 3820      2  region     42101    Pennsylvania             ...
# 3821      4  region     42101    Pennsylvania             ...
# 3822      2  region     42101    Pennsylvania             ...
# 3823      2  region     42101    Pennsylvania             ...
# 3824      1  region     42101    Pennsylvania             ...
# 3825      1  region     42101    Pennsylvania             ...
# 3826      2  region     42101    Pennsylvania             ...
# 3827      2  region     42101    Pennsylvania             ...
# 3828      2  region     42101    Pennsylvania             ...
# 3829      2  region     42101    Pennsylvania             ...
# 3830      2  region     42101    Pennsylvania             ...
#
#      WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0           6.1         25.3    502455         86.0         9.1           4.8
# 1           6.1         25.3    502455         86.0         9.1           4.8
# 2           6.1         25.3    502455         86.0         9.1           4.8
# 3           6.1         25.3    502455         86.0         9.1           4.8
# 4           6.1         25.3    502455         86.0         9.1           4.8
# 5           6.1         25.3    502455         86.0         9.1           4.8
# 6           6.1         25.3    502455         86.0         9.1           4.8
# 7           6.1         25.3    502455         86.0         9.1           4.8
# 8           6.1         25.3    502455         86.0         9.1           4.8
# 9           6.1         25.3    502455         86.0         9.1           4.8
# 10          6.1         25.3    502455         86.0         9.1           4.8
# 11          6.1         25.3    502455         86.0         9.1           4.8
# 12          6.1         25.3    502455         86.0         9.1           4.8
# 13          6.1         25.3    502455         86.0         9.1           4.8
# 14          6.1         25.3    502455         86.0         9.1           4.8
# 15          6.1         25.3    502455         86.0         9.1           4.8
# 16          6.1         25.3    502455         86.0         9.1           4.8
# 17          6.1         25.3    502455         86.0         9.1           4.8
# 18          6.1         25.3    502455         86.0         9.1           4.8
# 19          6.1         25.3    502455         86.0         9.1           4.8
# 20          6.1         25.3    502455         86.0         9.1           4.8
# 21          6.1         25.3    502455         86.0         9.1           4.8
# 22          6.1         25.3    502455         86.0         9.1           4.8
# 23          6.1         25.3    502455         86.0         9.1           4.8
# 24          6.1         25.3    502455         86.0         9.1           4.8
# 25          6.1         25.3    502455         86.0         9.1           4.8
# 26          6.1         25.3    502455         86.0         9.1           4.8
# 27          6.1         25.3    502455         86.0         9.1           4.8
# 28          6.1         25.3    502455         86.0         9.1           4.8
# 29          6.1         25.3    502455         86.0         9.1           4.8
# ...         ...          ...       ...          ...         ...           ...
# 3801        3.1         32.5    640661         82.9        13.0           4.0
# 3802        3.1         32.5    640661         82.9        13.0           4.0
# 3803        3.1         32.5    640661         82.9        13.0           4.0
# 3804        3.1         32.5    640661         82.9        13.0           4.0
# 3805        3.1         32.5    640661         82.9        13.0           4.0
# 3806        3.1         32.5    640661         82.9        13.0           4.0
# 3807        3.1         32.5    640661         82.9        13.0           4.0
# 3808        3.1         32.5    640661         82.9        13.0           4.0
# 3809        3.1         32.5    640661         82.9        13.0           4.0
# 3810        3.1         32.5    640661         82.9        13.0           4.0
# 3811        3.1         32.5    640661         82.9        13.0           4.0
# 3812        3.1         32.5    640661         82.9        13.0           4.0
# 3813        3.1         32.5    640661         82.9        13.0           4.0
# 3814        3.1         32.5    640661         82.9        13.0           4.0
# 3815        3.1         32.5    640661         82.9        13.0           4.0
# 3816        3.1         32.5    640661         82.9        13.0           4.0
# 3817        3.1         32.5    640661         82.9        13.0           4.0
# 3818        3.1         32.5    640661         82.9        13.0           4.0
# 3819        3.1         32.5    640661         82.9        13.0           4.0
# 3820        3.1         32.5    640661         82.9        13.0           4.0
# 3821        3.1         32.5    640661         82.9        13.0           4.0
# 3822        3.1         32.5    640661         82.9        13.0           4.0
# 3823        3.1         32.5    640661         82.9        13.0           4.0
# 3824        3.1         32.5    640661         82.9        13.0           4.0
# 3825        3.1         32.5    640661         82.9        13.0           4.0
# 3826        3.1         32.5    640661         82.9        13.0           4.0
# 3827        3.1         32.5    640661         82.9        13.0           4.0
# 3828        3.1         32.5    640661         82.9        13.0           4.0
# 3829        3.1         32.5    640661         82.9        13.0           4.0
# 3830        3.1         32.5    640661         82.9        13.0           4.0
#
#       FamilyWork  Unemployment  Region  total restaurants in county
# 0            0.1           8.9      SE                        982.0
# 1            0.1           8.9      SE                        982.0
# 2            0.1           8.9      SE                        982.0
# 3            0.1           8.9      SE                        982.0
# 4            0.1           8.9      SE                        982.0
# 5            0.1           8.9      SE                        982.0
# 6            0.1           8.9      SE                        982.0
# 7            0.1           8.9      SE                        982.0
# 8            0.1           8.9      SE                        982.0
# 9            0.1           8.9      SE                        982.0
# 10           0.1           8.9      SE                        982.0
# 11           0.1           8.9      SE                        982.0
# 12           0.1           8.9      SE                        982.0
# 13           0.1           8.9      SE                        982.0
# 14           0.1           8.9      SE                        982.0
# 15           0.1           8.9      SE                        982.0
# 16           0.1           8.9      SE                        982.0
# 17           0.1           8.9      SE                        982.0
# 18           0.1           8.9      SE                        982.0
# 19           0.1           8.9      SE                        982.0
# 20           0.1           8.9      SE                        982.0
# 21           0.1           8.9      SE                        982.0
# 22           0.1           8.9      SE                        982.0
# 23           0.1           8.9      SE                        982.0
# 24           0.1           8.9      SE                        982.0
# 25           0.1           8.9      SE                        982.0
# 26           0.1           8.9      SE                        982.0
# 27           0.1           8.9      SE                        982.0
# 28           0.1           8.9      SE                        982.0
# 29           0.1           8.9      SE                        982.0
# ...          ...           ...     ...                          ...
# 3801         0.1          13.9      NE                        992.0
# 3802         0.1          13.9      NE                        992.0
# 3803         0.1          13.9      NE                        992.0
# 3804         0.1          13.9      NE                        992.0
# 3805         0.1          13.9      NE                        992.0
# 3806         0.1          13.9      NE                        992.0
# 3807         0.1          13.9      NE                        992.0
# 3808         0.1          13.9      NE                        992.0
# 3809         0.1          13.9      NE                        992.0
# 3810         0.1          13.9      NE                        992.0
# 3811         0.1          13.9      NE                        992.0
# 3812         0.1          13.9      NE                        992.0
# 3813         0.1          13.9      NE                        992.0
# 3814         0.1          13.9      NE                        992.0
# 3815         0.1          13.9      NE                        992.0
# 3816         0.1          13.9      NE                        992.0
# 3817         0.1          13.9      NE                        992.0
# 3818         0.1          13.9      NE                        992.0
# 3819         0.1          13.9      NE                        992.0
# 3820         0.1          13.9      NE                        992.0
# 3821         0.1          13.9      NE                        992.0
# 3822         0.1          13.9      NE                        992.0
# 3823         0.1          13.9      NE                        992.0
# 3824         0.1          13.9      NE                        992.0
# 3825         0.1          13.9      NE                        992.0
# 3826         0.1          13.9      NE                        992.0
# 3827         0.1          13.9      NE                        992.0
# 3828         0.1          13.9      NE                        992.0
# 3829         0.1          13.9      NE                        992.0
# 3830         0.1          13.9      NE                        992.0
#
# [3831 rows x 47 columns]

# %% [markdown]
# <h3>IDK - KYRUS can fill this part in. </h3>
# <h3>Part 2: Examining category distribution across the US </h3>

# %%
TOTAL_price_avg = res_df.groupby(["price"]).mean()
rescount = res_df.groupby(["county_string"]).count()["name"].reset_index()
rescount.columns=['county_string', 'restaurant_count']
TOTAL_county_reviews = res_df.groupby(["county_string"]).review_count.sum().reset_index()
TOTAL_county_reviews.columns=["county_string","review_count"]
TOTAL_county_avg = res_df.groupby(res_df["county_string"]).mean().reset_index()

county_stats = TOTAL_county_avg.merge(TOTAL_county_reviews, on="county_string")
csdf = county_stats.merge(counties, on="county_string")
c_df = rescount.merge(csdf, on="county_string")
c_df.head()
# Out:
#                    county_string  restaurant_count    rating     price  \
# 0       Allegan County, Michigan                20  3.625000  2.000000
# 1         Apache County, Arizona                 3  3.333333  1.666667
# 2      Benton County, Washington                40  3.600000  1.525000
# 3  Bernalillo County, New Mexico               324  3.537037  1.524691
# 4           Brazos County, Texas               160  3.421875  1.443750
#
#    CensusId_x  TotalPop_x     Men_x   Women_x  Hispanic_x  White_x  \
# 0     26005.0    112837.0   56205.0   56632.0         7.0     89.1
# 1      4001.0     72124.0   35663.0   36461.0         6.3     19.3
# 2     53005.0    184930.0   92396.0   92534.0        20.0     72.6
# 3     35001.0    673943.0  330578.0  343365.0        48.7     40.4
# 4     48041.0    205271.0  104060.0  101211.0        24.4     57.6
#
#                ...                WorkAtHome_y  MeanCommute_y  Employed_y  \
# 0              ...                         4.1           24.2       51081
# 1              ...                         6.3           28.8       18334
# 2              ...                         3.8           21.7       82427
# 3              ...                         4.1           21.6      307756
# 4              ...                         2.9           17.7       98294
#
#    PrivateWork_y  PublicWork_y  SelfEmployed_y  FamilyWork_y  Unemployment_y  \
# 0           85.2           8.2             6.4           0.2             6.1
# 1           50.2          45.0             4.7           0.1            18.2
# 2           78.6          16.9             4.3           0.1             6.9
# 3           74.0          20.1             5.6           0.2             8.4
# 4           68.3          25.6             5.8           0.2             6.4
#
#    Region  total restaurants in county_y
# 0      MW                           58.0
# 1      SW                           16.0
# 2      WC                          134.0
# 3      SW                          969.0
# 4      SW                          579.0
#
# [5 rows x 80 columns]

# %%
comp_df = pd.DataFrame(columns=["Italian","Mexican","Chinese","American","county_string"])
for current_county in sample_list:
    #current_county="Mecklenburg County, North Carolina"
    try:
        cc= res_df.groupby(res_df["county_string"]).get_group(current_county)
        ccbreakdown = pd.DataFrame(cc["category"].value_counts()).T.reset_index()
        ccrate = pd.DataFrame(cc["rating"].value_counts()).T.reset_index()
        ccbreakdown["county_string"]=current_county
        cc_price_avg = cc.groupby(res_df["price"]).mean()
        cc_price_count = pd.DataFrame(cc["price"].value_counts())
        comp_df = comp_df.append(ccbreakdown)
    except:
        print("No data found for ", current_county)
comp_df = comp_df.reset_index()
del comp_df["index"]
del comp_df["level_0"]
comp_df
# Out:
# No data found for  Douglas County, Nevada
# No data found for  Arapahoe County, Colorado
#    American Chinese Italian Mexican                       county_string
# 0       183      34      45      72  Mecklenburg County, North Carolina
# 1        28       7       6      25          Carson City County, Nevada
# 2         4       2     NaN       1             Lake County, California
# 3        20       1       2       9            Clackamas County, Oregon
# 4        24       4       7      42        San Mateo County, California
# 5         2       2     NaN       6        Mendocino County, California
# 6        18      13       4      39            Kings County, California
# 7        23       1       9       3             Napa County, California
# 8         6       1     NaN       4           Madera County, California
# 9        14       5       5      16           Benton County, Washington
# 10        2       1     NaN       1            Gratiot County, Michigan
# 11        1       1     NaN       1              Taney County, Missouri
# 12       23       4       6       6              Muskingum County, Ohio
# 13       18       3       4       5              Shelby County, Indiana
# 14       40       8      10      23                   Linn County, Iowa
# 15       54      20      13      33          Tippecanoe County, Indiana
# 16        2       2       1       2            Monroe County, Wisconsin
# 17       13       3       2       3                 Geauga County, Ohio
# 18       24       6       8      11       Burleigh County, North Dakota
# 19       17     NaN       2       1            Allegan County, Michigan
# 20        8       1       2      11             Van Zandt County, Texas
# 21      NaN     NaN       1       4             Jim Wells County, Texas
# 22      143      55      51      92              Salt Lake County, Utah
# 23      124      35      27     138       Bernalillo County, New Mexico
# 24       50      14      20      46                Denton County, Texas
# 25       10       2       1      11           Montrose County, Colorado
# 26       28       7       6      24           Garfield County, Colorado
# 27       58      24      14      64                Brazos County, Texas
# 28      NaN       1     NaN       2              Apache County, Arizona
# 29      219      21      62      36        Horry County, South Carolina
# 30       40      16       7      18     Florence County, South Carolina
# 31       19       7       7       7            Escambia County, Florida
# 32       52      14      10      31             Madison County, Alabama
# 33       26       8       7       9   Cumberland County, North Carolina
# 34       45      27       9      13            Richmond County, Georgia
# 35       17       2       5       3      Halifax County, North Carolina
# 36        2     NaN       1       2      Jackson County, North Carolina
# 37       14       1       3       3         Washington County, Virginia
# 38        6       3       4     NaN     Clearfield County, Pennsylvania
# 39        8     NaN       3     NaN         Chautauqua County, New York
# 40        5       2       4     NaN           Chenango County, New York
# 41       20       5      22       4            Ocean County, New Jersey
# 42       24       5       8       5            Clinton County, New York
# 43       94      44      51      21       Hampden County, Massachusetts
# 44        9     NaN       1       1        Cattaraugus County, New York
# 45       14       1       5       1             Otsego County, New York
# 46       54      46      69      22           Camden County, New Jersey
# 47      188      33     100      51   Philadelphia County, Pennsylvania

# %% [markdown]
# <h3>Part 2: Examining category distribution across the US </h3>
#
# Next, Kyrus generated a for loop to create multiple pie charts representing the categorical breakdown by count

# %%
fig, axes = plt.subplots(3,3,figsize= (16,9))
for i, (idx, row) in enumerate(comp_df.set_index("county_string").iterrows()):
    try:
        ax = axes[i // 3, i % 3]
        row = row[row.gt(row.sum()*.01)]
        ax.pie(row, labels=row.index)
        ax.set_title(idx)
    except:
        print()
fig.subplots_adjust(wspace=1)

# %%
scatterplot_df=pd.DataFrame(columns=["county_string","Number of Restaurants"])
scatterplot_df["Number of Restaurants"] = rvc["total restaurants in county"] #pd.DataFrame(res_df["county_string"].value_counts().reset_index()["county_string"])
scatterplot_df["county_string"] = pd.DataFrame(res_df["county_string"].value_counts().reset_index()["index"])
scpri=counties[["Region","Income","TotalPop","county_string"]]
scatterplot_df= scatterplot_df.merge(scpri, how="left",on="county_string")
scatterplot_df=scatterplot_df.set_index("county_string")
scatterplot_df = scatterplot_df.loc[scatterplot_df["Number of Restaurants"]>= 10]
scatterplot_SE=scatterplot_df.groupby("Region").get_group("SE")
scatterplot_SW=scatterplot_df.groupby("Region").get_group("SW")
scatterplot_WC=scatterplot_df.groupby("Region").get_group("WC")
scatterplot_MW=scatterplot_df.groupby("Region").get_group("MW")
scatterplot_NE=scatterplot_df.groupby("Region").get_group("NE")
scatterplot_df
# Out:
#                                     Number of Restaurants Region   Income  \
# county_string
# Philadelphia County, Pennsylvania                     992     NE  38253.0
# Salt Lake County, Utah                                982     SW  62117.0
# Horry County, South Carolina                          980     SE  43299.0
# Mecklenburg County, North Carolina                    969     SE  56854.0
# Bernalillo County, New Mexico                         778     SW  47725.0
# Hampden County, Massachusetts                         659     NE  50461.0
# Camden County, New Jersey                             579     NE  62185.0
# Brazos County, Texas                                  537     SW  39808.0
# Denton County, Texas                                  398     SW  75050.0
# Tippecanoe County, Indiana                            395     MW  45932.0
# Madison County, Alabama                               375     SE  57993.0
# Richmond County, Georgia                              333     SE  37424.0
# Linn County, Iowa                                     257     MW  59322.0
# Florence County, South Carolina                       253     SE  42080.0
# San Mateo County, California                          251     WC  93623.0
# Kings County, California                              208     WC  46481.0
# Carson City County, Nevada                            184     WC  47668.0
# Garfield County, Colorado                             178     SW  56590.0
# Ocean County, New Jersey                              153     NE  61994.0
# Cumberland County, North Carolina                     141     SE  44171.0
# Burleigh County, North Dakota                         140     MW  65254.0
# Clinton County, New York                              134     NE  49930.0
# Benton County, Washington                             120     WC  60251.0
# Escambia County, Florida                              113     SE  45390.0
# Muskingum County, Ohio                                109     MW  41130.0
# Napa County, California                                90     WC  71379.0
# Clackamas County, Oregon                               78     WC  65965.0
# Shelby County, Indiana                                 75     MW  53584.0
# Halifax County, North Carolina                         75     SE  32245.0
# Montrose County, Colorado                              73     SW  43999.0
# Van Zandt County, Texas                                73     SW  44002.0
# Washington County, Virginia                            59     SE  43310.0
# Otsego County, New York                                58     NE  48588.0
# Geauga County, Ohio                                    54     MW  72430.0
# Allegan County, Michigan                               46     MW  54264.0
# Clearfield County, Pennsylvania                        37     NE  42257.0
# Cattaraugus County, New York                           36     NE  42601.0
# Chenango County, New York                              34     NE  45668.0
# Madera County, California                              34     WC  45073.0
# Chautauqua County, New York                            32     NE  42993.0
# Mendocino County, California                           31     WC  42980.0
# Monroe County, Wisconsin                               30     MW  50694.0
# Lake County, California                                30     WC  35578.0
# Jackson County, North Carolina                         23     SE  38015.0
# Jim Wells County, Texas                                22     SW  42986.0
# Gratiot County, Michigan                               18     MW  41912.0
# Apache County, Arizona                                 16     SW  31757.0
# Taney County, Missouri                                 16     MW  38357.0
#
#                                      TotalPop
# county_string
# Philadelphia County, Pennsylvania   1555072.0
# Salt Lake County, Utah              1078958.0
# Horry County, South Carolina         290730.0
# Mecklenburg County, North Carolina   990288.0
# Bernalillo County, New Mexico        673943.0
# Hampden County, Massachusetts        468041.0
# Camden County, New Jersey            511998.0
# Brazos County, Texas                 205271.0
# Denton County, Texas                 731851.0
# Tippecanoe County, Indiana           180952.0
# Madison County, Alabama              346438.0
# Richmond County, Georgia             201291.0
# Linn County, Iowa                    216640.0
# Florence County, South Carolina      138330.0
# San Mateo County, California         748731.0
# Kings County, California             150998.0
# Carson City County, Nevada            54482.0
# Garfield County, Colorado             57076.0
# Ocean County, New Jersey             583450.0
# Cumberland County, North Carolina    324603.0
# Burleigh County, North Dakota         88223.0
# Clinton County, New York              81685.0
# Benton County, Washington            184930.0
# Escambia County, Florida             306327.0
# Muskingum County, Ohio                86016.0
# Napa County, California              140295.0
# Clackamas County, Oregon             389438.0
# Shelby County, Indiana                44441.0
# Halifax County, North Carolina        53407.0
# Montrose County, Colorado             40815.0
# Van Zandt County, Texas               52736.0
# Washington County, Virginia           54759.0
# Otsego County, New York               61399.0
# Geauga County, Ohio                   93874.0
# Allegan County, Michigan             112837.0
# Clearfield County, Pennsylvania       81343.0
# Cattaraugus County, New York          78962.0
# Chenango County, New York             49549.0
# Madera County, California            153187.0
# Chautauqua County, New York          132646.0
# Mendocino County, California          87544.0
# Monroe County, Wisconsin              45274.0
# Lake County, California               64158.0
# Jackson County, North Carolina        40812.0
# Jim Wells County, Texas               41461.0
# Gratiot County, Michigan              41878.0
# Apache County, Arizona                72124.0
# Taney County, Missouri                53555.0

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.set_title("Number of restaurants vs population")
ax.set_xlabel("Population")
ax.set_ylabel("Number of restaurants in county")
ax.scatter(scatterplot_SW["TotalPop"],y=scatterplot_SW["Number of Restaurants"], c="red", alpha=.75,
                marker="v", edgecolors="black", linewidths=2.5, s=(scatterplot_df["Income"]/25-1000))
ax.scatter(scatterplot_WC["TotalPop"],y=scatterplot_WC["Number of Restaurants"], c="green", alpha=.75,
                marker="s", edgecolors="black", linewidths=2.5, s=(scatterplot_df["Income"]-25000)/25)
ax.scatter(scatterplot_MW["TotalPop"],y=scatterplot_MW["Number of Restaurants"], c="yellow", alpha=.75,
                marker="h", edgecolors="black", linewidths=2.5, s=(scatterplot_df["Income"]-25000)/25)
ax.scatter(scatterplot_NE["TotalPop"],y=scatterplot_NE["Number of Restaurants"], c="gray", alpha=.75,
                marker="X", edgecolors="black", linewidths=2.5, s=(scatterplot_df["Income"]-25000)/25)
ax.scatter(scatterplot_SE["TotalPop"],y=scatterplot_SE["Number of Restaurants"], c="blue", alpha=.75,
                marker="o", edgecolors="black", linewidths=2.5, s=(scatterplot_df["Income"]-25000)/25)
plt.xlim(0,1000000)
ax.legend(markerscale=.5,fancybox=True, edgecolor="black",labelspacing=1.5,
          labels=["Southwest","West","Midwest","Northeast","Southeast"], 
          loc="lower right",title="Marker size indicates income level",)

plt.show()

# %% [markdown]
# ## plt.show()

# %% [markdown]
# <h3>Part 3: Examining price breakdown based on region and restaurant category</h3>
#
# <b>The RQ:</b> How does price rating (\$, \$\$, \$\$\$, \$\$\$\$) breakdown for our randomly pulled cities? What is a the price rating breakdown by specific region and restaurant category? We expect higher income regions to have higher priced restaurants - ex: we would expect New York County  to have more 4\$ restaurants than a given county in the Midwest. We will see if the data of our randomly selected cities shows an even or uneven distribution based on price breakdown by category and by region.
#
# ---------------------------------
#
# After examining the categorical breakdown based on county, we moved on to determine the price breakdown by both region and restaurant category.
#
# This was Randi's portion of the project. We ran into some tricky stuff with the stacked bar charts. The primary issue was that the each bar's list needed to be the same length, that was fine, except when there was a restaurant for every price braket. Also, in all of her research Randi could not find how to make the stacked bars dynamic. In all the examples she found, the bar values were created manually. This is fine if you have a small dataset that you do not intend to run over and over again; however, this was not ideal for this project.
#
# <b>With some help from Mirko, Ryan, and Caleb, we figured it out! </b>
#
# First, we needed to define this list we would be looping through. For the first chart, Number of \$ per Category, we created a list named labels that contained all the different restaurant categories. Then, we created a second list with four empty lists. These four empty lists would represet 1\$, 2\$, 3\$, and 4\$. We then looped through our category list and found the count for each of the dollar ratings in said category. Once the loop determined how many 1\$, 2\$, 3\$, and 4\$ there were in each category it appended it to the corresponding empty list. If we did not find a 1\$, 2\$, 3\$, and 4\$ for a particular restaurant category, then the except argument kicked-in and instead appended a zero. Again, the goal was to make each of the four lists the same length.
#
# In the end, we ended up with a list corresponding to 1\$, 2\$, 3\$, and 4\$, with ratings per restaurant category.
#
# Once we created this loop and stored the counts in lists, we could call these lists in our chart creation; thereby, making the charts dynamic, changing with the number of pulls.

# %%
# Established the restaurant categories we will loop through
labels = ["Italian","Mexican","Chinese","American"]

# Create and list of empty lists that will hold the count for $, $$, $$$, $$$$ per restaurant category
bars =[[],[],[],[]]

# Will first loop through the restaurant categories
for label in labels:
    df= res_df.loc[res_df["category"]==label, :]
    counts = df["price"].value_counts()
    
    # Now will loop through the price ranges and if there is a price, it will append it to the matching empty list
    # If there is no restaurant in that price range, then the we will use the except and append a zero
    for price in range(1,5):
        try:
            bars[price-1].append(counts[price])
        except: 
            bars[price-1].append(0)

# Check
print(bars[1])
# Out:
# [446, 300, 204, 1158]

# %%
from matplotlib import rc

# Establish our seaborn settings 
sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})

# set fig size
figsize= (100, 100, 50)
 
# Values for each stacked bar based on our above for loop 
# This make the bar values dynamic so we do not have to manually set the values 
bars1 = bars[0]
bars2 = bars[1]
bars3 = bars[2]
bars4 = bars[3]
x = np.arange(len(bars1))

# Plot our four bars from above values
four_dolla=plt.bar(x, bars4, color="plum")
three_dolla=plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dolla=plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dolla=plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

# Set our xticks based on categories
plt.xticks(x, ["Italian","Mexican","Chinese","American"])

# Set our grid
plt.grid(axis='y')

# Set graph labels 
plt.xlabel("Category")
plt.ylabel('Count')
plt.title('Number of $ per Category')
    
# Set our legend
plt.legend((four_dolla[0], three_dolla[0],two_dolla[0], one_dolla[0]), ('4$', '3$','2$', '1$'), loc="best")


# Show graphic
plt.show()

# Save image
plt.savefig("stacked.png")

# %%
# Established the regions we will loop through
region = ["NE","MW","WC","SW","SE"]

# Create and list of empty lists that will hold the count for $, $$, $$$, $$$$ per region
r_bars =[[],[],[],[]]

# Will first loop through the regions
for r in region:
    reg_bars= res_df.loc[res_df["Region"]==r, :]
    reg_counts = reg_bars["price"].value_counts()
    
    # Now will loop through the price ranges and if there is a price, it will append it to the matching empty list
    # If there is no restaurant in that price range, then the we will use the except and append a zero
    for price in range(1,5):
        try:
            r_bars[price-1].append(reg_counts[price])
        except: 
            r_bars[price-1].append(0)

# Check            
print(r_bars)
# Out:
# [[264, 152, 163, 496, 467], [589, 211, 166, 548, 594], [70, 11, 18, 29, 32], [10, 0, 6, 1, 4]]

# %%
# Establish our seaborn settings 
sns.set()
# orgPalette = sns.color_palette("Set2", len(res_by_price))
# sns.set_palette(orgPalette)
sns.set_style("whitegrid", {'legend.frameon':False})

# set fig size
figsize= (100, 100, 50)

# Values for each stacked bar based on our above for loop 
# This make the bar values dynamic so we do not have to manually set the values 
bars1 = r_bars[0]
bars2 = r_bars[1]
bars3 = r_bars[2]
bars4 = r_bars[3]
x = np.arange(len(bars1))

# Plot our four bars from above values
four_dol = plt.bar(x, bars4, color="plum")
three_dol =plt.bar(x, bars3, color="darkblue", bottom=bars4)
two_dol =plt.bar(x, bars2, color="turquoise", bottom=list(map(lambda x,y: x+y, bars3,bars4)))
one_dol =plt.bar(x, bars1, color="darkorange", bottom=list(map(lambda x,y,z: x+y+z, bars3,bars4,bars2)))

# Set our xticks based on categories
plt.xticks(x, ["NE","MW","WC","SW","SE"])

# Set our grid
plt.grid(axis='y')

# Set graph labels 
plt.xlabel("Region")
plt.ylabel('Price Count')
plt.title('Number of $ per Region')

# Set graph legend 
plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")

# Show graphic
plt.show()

# Save image
plt.savefig("stacked2.png")

# %% [markdown]
# <h3>Part 3: Pie Chart</h3>
#
# With the dynamic stacked bar charts created, we thought it was relevant to also see the count of each dollar amount when comparing the counts by region or category. Thus, we created a pie chart (also dynamic) that shows the total of each restaurant category by dollar.

# %%
# Check our sums for pie chart
print(sum(bars1))
print(sum(bars2))
print(sum(bars3))
print(sum(bars4))
# Out:
# 1542
# 2108
# 160
# 21

# %%
# Establish the auto percents
# Create definitions 
def make_autopct(sizes):
    def my_autopct(pct):
        total = sum(sizes)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:

# Establish our seaborn settings 
sns.set()
orgPalette = sns.color_palette("Set2")
sns.set_palette(orgPalette)
# sns.set_style("", {'legend.frameon':False})

# set fig size
plt.figure(figsize=(20,20))

# Set our labels, sizes, and explode values 
# We won't use labels because we will create a legend instead, but we could easily assign the labels

#labels = '4$', '3$','2$', '1$'
sizes = [sum(bars1),sum(bars2),sum(bars3),sum(bars4)]
explode = (0.03, 0.03, 0.03, 0.5)  # only "explode" the 2nd slice 


# Plot our pie chart with total sums by $ breakdown and place the percetages 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, colors=orgPalette, autopct=make_autopct(sizes),
        shadow=True, startangle=90) 

# Equal aspect ratio ensures that pie is drawn as a circle.
ax1.axis('equal')  

# Set graph title 
plt.title('Sum of each $ Amount')

# Set graph legend 
plt.legend((four_dol[0], three_dol[0],two_dol[0], one_dol[0]), ('4$', '3$','2$', '1$'), loc="best")


# Show graphic
plt.show()

# Save image
plt.savefig("pie_chart.jpg")

# %% [markdown]
# <h3>Part 4: MONICA</h3>

# %% [markdown]
# <h3>Part 5: CATHERINE</h3>

# %% [markdown]
# <h3>Part 6: Conclusions</h3>

# %% [markdown]
# <h3>Part 7: Limitations</h3>
#
# Initially, we wanted to find out if there wass there a relationship between income and type of dining (ie dine-in, carry-out, delivery)? Is this based on the number of restaurants that provide these options?
#
#
# Unfortunately, this didn’t work due to Yelp API limitations. Acoording to their website, currently, the transaction endpoint is "only supports food delivery in the US."
#
# Since the current Yelp Fusion API only supports the delivery option it isn’t very helpful for comparison or analysis purposes.

# %% [markdown]
# <h3>Part 8: If only we had more time...</h3>
#
# <ul>
# <li>Attempt to match user category input with local restaurant </li>
# <li>"Build a lunch recommendation Slack bot that can pull highest rated Yelp places around your location. You can build the script to respond to user input (ex. “Chinese, $”) or generate top-rated places randomly." This was just too ambitious for our timeframe </li>
# </ul>
